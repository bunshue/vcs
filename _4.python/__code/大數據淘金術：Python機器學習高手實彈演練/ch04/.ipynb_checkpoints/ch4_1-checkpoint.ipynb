# %%
# -*- coding:utf-8 -*-

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 4.1.2  散點圖與氣泡圖

# %%
# 散點圖
x = np.random.rand(50) * 20 # 隨機生成50個點，x軸取值範圍0-20
y = np.random.rand(50) * 10 # 隨機生成50個點，y軸取值範圍0-10
plt.plot(x, y, 'o') # 用'o'指定繪製點圖
plt.show()

# %%
# 氣泡圖
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N) # 點的顏色
area = (30 * np.random.rand(N))**2  # 點的半徑
plt.scatter(x, y, s=area, c=colors, alpha=0.5) # 由於點可能疊加，設置透明度爲0.5
plt.show()

# %% [markdown]
# ### 4.1.3  線圖

# %%
# 對比線圖

x = np.arange(0.0, 2.0, 0.01) # 生成範圍從0.0-2.0，步長爲0.01的數組
y = np.sin(2 * np.pi * x)
z = np.cos(2 * np.pi * x)
plt.plot(x, y) # 繪製實線
plt.plot(x, z, '--') # 繪製虛線
plt.grid(True, linestyle='-.') # 設置背景網格
plt.show()

# %%
# 時序圖
import pandas as pd
import matplotlib.dates as mdates

x = ['20170808210000' ,'20170808210100' ,'20170808210200' ,'20170808210300'
     ,'20170808210400' ,'20170808210500' ,'20170808210600' ,'20170808210700'
     ,'20170808210800' ,'20170808210900']

x = pd.to_datetime(x)
y = [3900.0,  3903.0,  3891.0,  3888.0,  3893.0,
     3899.0,  3906.0,  3914.0,  3911.0,  3912.0]

plt.plot(x, y)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m-%d %H:%M')) # 設置時間顯示格式
plt.gcf().autofmt_xdate() # 自動旋轉角度，以避免重疊
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### 4.1.4  柱圖

# %%
# 柱圖

data = {'apples': 10, 'oranges': 15, 'lemons': 5, 'limes': 20}
plt.bar(list(data.keys()), list(data.values()))
# Out:
# <BarContainer object of 4 artists>

# %%
# 條形圖
data = {'apples': 10, 'oranges': 15, 'lemons': 5, 'limes': 20}
error = [3, 4, 2, 7] 
plt.barh(list(data.keys()), list(data.values()), xerr=error, align='center', 
        color='green', ecolor='black')
plt.show()

# %%
# 堆疊圖
y1 = (20, 35, 30, 35, 27)
y2 = (25, 32, 34, 20, 25)
x = np.arange(len(y1))
width = 0.35
p1 = plt.bar(x, y1, width)
p2 = plt.bar(x, y2, width, bottom=y1) # 堆疊圖
plt.show()

# %%
# 直方圖
x = np.random.rand(50, 2) # 產生共兩組，每組50個隨機數,
plt.hist(x)
# Out:
# ([array([ 3.,  5.,  3.,  4.,  3.,  6.,  6., 10.,  7.,  3.]),
#   array([6., 2., 8., 2., 9., 2., 8., 6., 1., 6.])],
#  array([0.01876763, 0.11627799, 0.21378835, 0.31129871, 0.40880908,
#         0.50631944, 0.6038298 , 0.70134016, 0.79885052, 0.89636088,
#         0.99387125]),
#  <a list of 2 Lists of Patches objects>)

# %% [markdown]
# ### 4.1.5  餅圖

# %%
data = {'apples': 10, 'oranges': 15, 'lemons': 5, 'limes': 20}
explode = (0, 0.1, 0, 0)  # 向外擴展顯示的區域
plt.pie(data.values(), explode=explode, labels=data.keys(), autopct='%1.1f%%',
        shadow=True, startangle=90)
plt.axis('equal') # 設置餅圖爲正圓形
plt.show()

# %% [markdown]
# ### 4.1.6  箱線圖和小提琴圖

# %%
# 箱線圖

data = np.random.rand(20, 5) # 生成5個維度數據，每組20個
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f9aa6203198>,
#   <matplotlib.lines.Line2D at 0x7f9aa6203550>,
#   <matplotlib.lines.Line2D at 0x7f9aa620b940>,
#   <matplotlib.lines.Line2D at 0x7f9aa620bc88>,
#   <matplotlib.lines.Line2D at 0x7f9aa61a60b8>,
#   <matplotlib.lines.Line2D at 0x7f9aa61a6400>,
#   <matplotlib.lines.Line2D at 0x7f9aa61b27f0>,
#   <matplotlib.lines.Line2D at 0x7f9aa61b2b38>,
#   <matplotlib.lines.Line2D at 0x7f9aa61bef28>,
#   <matplotlib.lines.Line2D at 0x7f9aa61cb2b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f9aa6203898>,
#   <matplotlib.lines.Line2D at 0x7f9aa6203be0>,
#   <matplotlib.lines.Line2D at 0x7f9aa620bfd0>,
#   <matplotlib.lines.Line2D at 0x7f9aa6219358>,
#   <matplotlib.lines.Line2D at 0x7f9aa61a6748>,
#   <matplotlib.lines.Line2D at 0x7f9aa61a6a90>,
#   <matplotlib.lines.Line2D at 0x7f9aa61b2e80>,
#   <matplotlib.lines.Line2D at 0x7f9aa61be208>,
#   <matplotlib.lines.Line2D at 0x7f9aa61cb5f8>,
#   <matplotlib.lines.Line2D at 0x7f9aa61cb940>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f9aa6203048>,
#   <matplotlib.lines.Line2D at 0x7f9aa620b5c0>,
#   <matplotlib.lines.Line2D at 0x7f9aa6219cf8>,
#   <matplotlib.lines.Line2D at 0x7f9aa61b2470>,
#   <matplotlib.lines.Line2D at 0x7f9aa61beba8>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f9aa6203f28>,
#   <matplotlib.lines.Line2D at 0x7f9aa62196a0>,
#   <matplotlib.lines.Line2D at 0x7f9aa61a6dd8>,
#   <matplotlib.lines.Line2D at 0x7f9aa61be550>,
#   <matplotlib.lines.Line2D at 0x7f9aa61cbc88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f9aa620b2b0>,
#   <matplotlib.lines.Line2D at 0x7f9aa62199e8>,
#   <matplotlib.lines.Line2D at 0x7f9aa61b2160>,
#   <matplotlib.lines.Line2D at 0x7f9aa61be898>,
#   <matplotlib.lines.Line2D at 0x7f9aa61cbfd0>],
#  'means': []}

# %%
# 小提琴圖
data = np.random.rand(20, 5)
plt.violinplot(data,showmeans=False,showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7f9aa618ec88>,
#   <matplotlib.collections.PolyCollection at 0x7f9aa61389b0>,
#   <matplotlib.collections.PolyCollection at 0x7f9aa6138c50>,
#   <matplotlib.collections.PolyCollection at 0x7f9aa6138eb8>,
#   <matplotlib.collections.PolyCollection at 0x7f9aa6149160>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7f9aa6138780>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7f9aa61496d8>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7f9aa6149a20>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x7f9aa6149d68>}

# %% [markdown]
# ### 4.1.7  三維圖

# %%
# 三維散點圖
from mpl_toolkits.mplot3d import Axes3D

data = np.random.rand(50, 3) # 生成三維數據，每維50個
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(data[:, 0], data[:, 1], data[:, 2])
ax.set_zlabel('Z')
ax.set_ylabel('Y')
ax.set_xlabel('X')
plt.show()

# %%
# 三維柱圖

from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)
_x = np.arange(4)
_y = np.arange(5)
_xx, _yy = np.meshgrid(_x, _y) # 生成網格點座標矩陣
x, y = _xx.ravel(), _yy.ravel() # 展開爲一維數組

top = x + y
bottom = np.zeros_like(top) # 與top數組形狀一樣，內容全部爲0
width = depth = 1

ax.bar3d(x, y, bottom, width, depth, top, shade=True)
plt.show()

# %%
# 三維曲面圖和等高線圖

from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm)
ax.contourf(X,Y,Z,zdir='z',offset=-2) # 把等高線向z軸投射
ax.set_zlim(-2,2) # 設置z軸範圍
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %% [markdown]
# ### 4.1.8  Matplotlib繪圖區域

# %%
fig = plt.figure(figsize = (8,6))  # 8x6英寸
fig.suptitle("Title 1") # 主標題
ax1 = plt.subplot(221) # 整體爲兩行兩列，創建其中的第一個子圖
ax1.set_title('Title 2',fontsize=12,color='y')  # 子標題
ax1.plot([1,2,3,4,5])
ax2 = plt.subplot(222)
ax2.plot([5,4,3,2,1])
ax3 = plt.subplot(223)
ax3.plot([1,2,3,3,3])
ax4 = plt.subplot(224)
ax4.plot([5,4,3,3,3])

# %%
fig = plt.figure(figsize = (9,6))
ax1 = plt.subplot2grid((3,3), (0,0), colspan = 2)
ax2 = plt.subplot2grid((3,3), (0,2), rowspan = 2) 
ax3 = plt.subplot2grid((3,3), (1,0), rowspan = 2) 
ax4 = plt.subplot2grid((3,3), (1,1)) # rowspan/colspan默認爲1 
ax5 = plt.subplot2grid((3,3), (2,1), colspan = 2) 
ax5.plot([1,2,3,4,1])
plt.show()

# %% [markdown]
# ### 4.1.9  文字顯示問題

# %%
from os import path
from matplotlib.font_manager import fontManager
for i in fontManager.ttflist:
    print(i.fname, i.name)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymBol.ttf STIXSizeOneSym
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-BoldOblique.ttf DejaVu Sans Mono
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/simhei.ttf SimHei
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif.ttf DejaVu Serif
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymBol.ttf STIXSizeTwoSym
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/cmtt10.ttf cmtt10
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/cmr10.ttf cmr10
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBolIta.ttf STIXNonUnicode
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymBol.ttf STIXSizeThreeSym
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymBol.ttf STIXSizeFourSym
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Oblique.ttf DejaVu Sans Mono
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/cmex10.ttf cmex10
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralItalic.ttf STIXGeneral
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFiveSymReg.ttf STIXSizeFiveSym
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Bold.ttf DejaVu Sans
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/cmss10.ttf cmss10
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBolIta.ttf STIXGeneral
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/cmmi10.ttf cmmi10
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniIta.ttf STIXNonUnicode
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono.ttf DejaVu Sans Mono
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Italic.ttf DejaVu Serif
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerifDisplay.ttf DejaVu Serif Display
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymReg.ttf STIXSizeOneSym
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Bold.ttf DejaVu Serif
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymReg.ttf STIXSizeFourSym
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-BoldItalic.ttf DejaVu Serif
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf DejaVu Sans
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/cmsy10.ttf cmsy10
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymReg.ttf STIXSizeTwoSym
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUni.ttf STIXNonUnicode
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Bold.ttf DejaVu Sans Mono
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansDisplay.ttf DejaVu Sans Display
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBol.ttf STIXGeneral
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Oblique.ttf DejaVu Sans
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBol.ttf STIXNonUnicode
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/cmb10.ttf cmb10
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneral.ttf STIXGeneral
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymReg.ttf STIXSizeThreeSym
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-BoldOblique.ttf DejaVu Sans
# /usr/share/fonts/opentype/noto/NotoSansCJK-Thin.ttc Noto Sans CJK JP
# /usr/share/fonts/truetype/nanum/NanumMyeongjo.ttf NanumMyeongjo
# /usr/share/fonts/truetype/kacst/KacstQurn.ttf KacstQurn
# /usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-MI.ttf Ubuntu
# /usr/share/fonts/truetype/kacst/KacstPen.ttf KacstPen
# /usr/share/fonts/truetype/freefont/FreeMonoBoldOblique.ttf FreeMono
# /usr/share/fonts/opentype/noto/NotoSansCJK-Bold.ttc Noto Sans CJK JP
# /usr/share/fonts/opentype/noto/NotoSansCJK-Light.ttc Noto Sans CJK JP
# /usr/share/fonts/truetype/tlwg/Purisa.ttf Purisa
# /usr/share/fonts/opentype/stix/STIXGeneral-Bold.otf STIXGeneral
# /usr/share/fonts/truetype/ubuntu-font-family/UbuntuMono-B.ttf Ubuntu Mono
# /usr/share/fonts/opentype/stix/STIXIntegralsD-Bold.otf STIXIntegralsD
# /usr/share/fonts/truetype/tlwg/TlwgMono-BoldOblique.ttf Tlwg Mono
# /usr/share/fonts/truetype/ttf-khmeros-core/KhmerOS.ttf Khmer OS
# /usr/share/fonts/truetype/tlwg/TlwgTypewriter-Bold.ttf Tlwg Typewriter
# /usr/share/fonts/truetype/liberation/LiberationMono-Italic.ttf Liberation Mono
# /usr/share/fonts/truetype/arphic/ukai.ttc AR PL UKai CN
# /usr/share/fonts/truetype/freefont/FreeMono.ttf FreeMono
# /usr/share/fonts/truetype/tlwg/TlwgTypo-Bold.ttf Tlwg Typo
# /usr/share/fonts/truetype/tlwg/Norasi-Oblique.ttf Norasi
# /usr/share/fonts/truetype/tlwg/Laksaman-Italic.ttf Laksaman
# /usr/share/fonts/truetype/ancient-scripts/Symbola_hint.ttf Symbola
# /usr/share/fonts/truetype/padauk/Padauk-bookbold.ttf Padauk Book
# /usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-M.ttf Ubuntu
# /usr/share/fonts/truetype/padauk/Padauk-bold.ttf Padauk
# /usr/share/fonts/truetype/freefont/FreeSans.ttf FreeSans
# /usr/share/fonts/truetype/freefont/FreeSansOblique.ttf FreeSans
# /usr/share/fonts/truetype/tlwg/Laksaman.ttf Laksaman
# /usr/share/fonts/truetype/tlwg/Kinnari-BoldItalic.ttf Kinnari
# /usr/share/fonts/truetype/kacst-one/KacstOne-Bold.ttf KacstOne
# /usr/share/fonts/opentype/stix/STIXSizeThreeSym-Regular.otf STIXSizeThreeSym
# /usr/share/fonts/truetype/liberation/LiberationSansNarrow-Bold.ttf Liberation Sans Narrow
# /usr/share/fonts/truetype/kacst/KacstDigital.ttf KacstDigital
# /usr/share/fonts/truetype/tlwg/TlwgTypist-Bold.ttf Tlwg Typist
# /usr/share/fonts/opentype/stix/STIXIntegralsSm-Bold.otf STIXIntegralsSm
# /usr/share/fonts/opentype/stix/STIXGeneral-BoldItalic.otf STIXGeneral
# /usr/share/fonts/truetype/tlwg/Kinnari-Oblique.ttf Kinnari
# /usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-RI.ttf Ubuntu
# /usr/share/fonts/truetype/tlwg/Loma-Bold.ttf Loma
# /usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-BI.ttf Ubuntu
# /usr/share/fonts/truetype/kacst/mry_KacstQurn.ttf mry_KacstQurn
# /usr/share/fonts/truetype/tlwg/Kinnari-Bold.ttf Kinnari
# /usr/share/fonts/truetype/openoffice/opens___.ttf OpenSymbol
# /usr/share/fonts/truetype/tlwg/Umpush-BoldOblique.ttf Umpush
# /usr/share/fonts/opentype/stix/STIXSizeFourSym-Bold.otf STIXSizeFourSym
# /usr/share/fonts/truetype/tlwg/Umpush-Oblique.ttf Umpush
# /usr/share/fonts/truetype/ubuntu-font-family/UbuntuMono-RI.ttf Ubuntu Mono
# /usr/share/fonts/truetype/freefont/FreeSerifBoldItalic.ttf FreeSerif
# /usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf NanumMyeongjo
# /usr/share/fonts/truetype/tlwg/TlwgMono.ttf Tlwg Mono
# /usr/share/fonts/truetype/liberation/LiberationMono-Regular.ttf Liberation Mono
# /usr/share/fonts/truetype/arphic/uming.ttc AR PL UMing CN
# /usr/share/fonts/truetype/freefont/FreeSerif.ttf FreeSerif
# /usr/share/fonts/truetype/tlwg/Garuda.ttf Garuda
# /usr/share/fonts/opentype/noto/NotoSansCJK-Medium.ttc Noto Sans CJK JP
# /usr/share/fonts/opentype/stix-word/STIX-Bold.otf STIX
# /usr/share/fonts/truetype/liberation/LiberationSans-Bold.ttf Liberation Sans
# /usr/share/fonts/truetype/kacst/KacstDecorative.ttf KacstDecorative
# /usr/share/fonts/truetype/tlwg/TlwgTypewriter-BoldOblique.ttf Tlwg Typewriter
# /usr/share/fonts/truetype/tlwg/Loma.ttf Loma
# /usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf NanumBarunGothic
# /usr/share/fonts/truetype/liberation/LiberationSerif-Bold.ttf Liberation Serif
# /usr/share/fonts/truetype/tlwg/Sawasdee-BoldOblique.ttf Sawasdee
# /usr/share/fonts/truetype/ubuntu-font-family/UbuntuMono-BI.ttf Ubuntu Mono
# /usr/share/fonts/opentype/noto/NotoSansCJK-DemiLight.ttc Noto Sans CJK JP
# /usr/share/fonts/truetype/tlwg/Sawasdee.ttf Sawasdee
# /usr/share/fonts/opentype/stix/STIXSizeTwoSym-Regular.otf STIXSizeTwoSym
# /usr/share/fonts/truetype/tlwg/TlwgTypo-BoldOblique.ttf Tlwg Typo
# /usr/share/fonts/truetype/tlwg/TlwgTypist-BoldOblique.ttf Tlwg Typist
# /usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-LI.ttf Ubuntu
# /usr/share/fonts/truetype/tlwg/Umpush-Bold.ttf Umpush
# /usr/share/fonts/truetype/tlwg/Kinnari-BoldOblique.ttf Kinnari
# /usr/share/fonts/opentype/stix/STIXIntegralsUp-Bold.otf STIXIntegralsUp
# /usr/share/fonts/truetype/tlwg/Purisa-Bold.ttf Purisa
# /usr/share/fonts/truetype/tlwg/Garuda-BoldOblique.ttf Garuda
# /usr/share/fonts/truetype/ubuntu-font-family/UbuntuMono-R.ttf Ubuntu Mono
# /usr/share/fonts/truetype/kacst/KacstTitle.ttf KacstTitle
# /usr/share/fonts/truetype/kacst/KacstFarsi.ttf KacstFarsi
# /usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-R.ttf Ubuntu
# /usr/share/fonts/truetype/tlwg/Kinnari.ttf Kinnari
# /usr/share/fonts/truetype/kacst/KacstLetter.ttf KacstLetter
# /usr/share/fonts/truetype/ttf-khmeros-core/KhmerOSsys.ttf Khmer OS System
# /usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-B.ttf Ubuntu
# /usr/share/fonts/truetype/kacst-one/KacstOne.ttf KacstOne
# /usr/share/fonts/opentype/stix/STIXIntegralsUpSm-Bold.otf STIXIntegralsUpSm
# /usr/share/fonts/truetype/liberation/LiberationSansNarrow-BoldItalic.ttf Liberation Sans Narrow
# /usr/share/fonts/truetype/fonts-japanese-gothic.ttf TakaoPGothic
# /usr/share/fonts/opentype/stix/STIXIntegralsUpSm-Regular.otf STIXIntegralsUpSm
# /usr/share/fonts/opentype/noto/NotoSansCJK-Regular.ttc Noto Sans CJK JP
# /usr/share/fonts/truetype/fonts-guru-extra/Saab.ttf Saab
# /usr/share/fonts/truetype/nanum/NanumGothicBold.ttf NanumGothic
# /usr/share/fonts/truetype/tlwg/Sawasdee-Oblique.ttf Sawasdee
# /usr/share/fonts/opentype/stix/STIXIntegralsUpD-Bold.otf STIXIntegralsUpD
# /usr/share/fonts/truetype/tlwg/Umpush-LightOblique.ttf Umpush
# /usr/share/fonts/truetype/liberation/LiberationSansNarrow-Italic.ttf Liberation Sans Narrow
# /usr/share/fonts/truetype/lao/Phetsarath_OT.ttf Phetsarath OT
# /usr/share/fonts/truetype/tlwg/Waree-Bold.ttf Waree
# /usr/share/fonts/truetype/sinhala/lklug.ttf LKLUG
# /usr/share/fonts/truetype/freefont/FreeSerifBold.ttf FreeSerif
# /usr/share/fonts/opentype/stix/STIXIntegralsUpD-Regular.otf STIXIntegralsUpD
# /usr/share/fonts/truetype/liberation/LiberationSans-Regular.ttf Liberation Sans
# /usr/share/fonts/truetype/liberation/LiberationSansNarrow-Regular.ttf Liberation Sans Narrow
# /usr/share/fonts/truetype/liberation/LiberationSerif-Regular.ttf Liberation Serif
# /usr/share/fonts/truetype/tlwg/TlwgTypist.ttf Tlwg Typist
# /usr/share/fonts/truetype/tlwg/TlwgMono-Oblique.ttf Tlwg Mono
# /usr/share/fonts/truetype/tlwg/Purisa-BoldOblique.ttf Purisa
# /usr/share/fonts/truetype/kacst/KacstBook.ttf KacstBook
# /usr/share/fonts/opentype/stix/STIXVariants-Bold.otf STIXVariants
# /usr/share/fonts/opentype/stix/STIXGeneral-Italic.otf STIXGeneral
# /usr/share/fonts/truetype/tlwg/Purisa-Oblique.ttf Purisa
# /usr/share/fonts/opentype/stix/STIXSizeFiveSym-Regular.otf STIXSizeFiveSym
# /usr/share/fonts/opentype/stix-word/STIX-Italic.otf STIX
# /usr/share/fonts/truetype/tlwg/Waree.ttf Waree
# /usr/share/fonts/truetype/tlwg/TlwgTypo-Oblique.ttf Tlwg Typo
# /usr/share/fonts/opentype/stix/STIXNonUnicode-Bold.otf STIXNonUnicode
# /usr/share/fonts/truetype/tlwg/Umpush.ttf Umpush
# /usr/share/fonts/truetype/tlwg/Laksaman-Bold.ttf Laksaman
# /usr/share/fonts/truetype/tlwg/Waree-BoldOblique.ttf Waree
# /usr/share/fonts/truetype/lohit-punjabi/Lohit-Punjabi.ttf Lohit Punjabi
# /usr/share/fonts/opentype/stix-word/STIXMath-Regular.otf STIX Math
# /usr/share/fonts/truetype/tlwg/TlwgTypo.ttf Tlwg Typo
# /usr/share/fonts/truetype/tlwg/TlwgTypewriter.ttf Tlwg Typewriter
# /usr/share/fonts/truetype/liberation/LiberationSans-BoldItalic.ttf Liberation Sans
# /usr/share/fonts/truetype/liberation/LiberationMono-BoldItalic.ttf Liberation Mono
# /usr/share/fonts/truetype/kacst/KacstNaskh.ttf KacstNaskh
# /usr/share/fonts/opentype/stix/STIXIntegralsUp-Regular.otf STIXIntegralsUp
# /usr/share/fonts/opentype/stix/STIXSizeThreeSym-Bold.otf STIXSizeThreeSym
# /usr/share/fonts/truetype/kacst/KacstArt.ttf KacstArt
# /usr/share/fonts/truetype/tlwg/TlwgTypist-Oblique.ttf Tlwg Typist
# /usr/share/fonts/truetype/tlwg/Norasi-BoldOblique.ttf Norasi
# /usr/share/fonts/truetype/tlwg/Norasi.ttf Norasi
# /usr/share/fonts/opentype/stix/STIXSizeOneSym-Regular.otf STIXSizeOneSym
# /usr/share/fonts/opentype/stix/STIXIntegralsD-Regular.otf STIXIntegralsD
# /usr/share/fonts/opentype/stix/STIXNonUnicode-BoldItalic.otf STIXNonUnicode
# /usr/share/fonts/truetype/tlwg/Umpush-Light.ttf Umpush
# /usr/share/fonts/opentype/stix/STIXNonUnicode-Italic.otf STIXNonUnicode
# /usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-C.ttf Ubuntu Condensed
# /usr/share/fonts/truetype/nanum/NanumGothic.ttf NanumGothic
# /usr/share/fonts/opentype/stix/STIXIntegralsSm-Regular.otf STIXIntegralsSm
# /usr/share/fonts/truetype/liberation/LiberationSerif-BoldItalic.ttf Liberation Serif
# /usr/share/fonts/truetype/padauk/Padauk.ttf Padauk
# /usr/share/fonts/truetype/freefont/FreeMonoBold.ttf FreeMono
# /usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-L.ttf Ubuntu
# /usr/share/fonts/opentype/stix-word/STIX-Regular.otf STIX
# /usr/share/fonts/truetype/abyssinica/AbyssinicaSIL-R.ttf Abyssinica SIL
# /usr/share/fonts/truetype/tlwg/Norasi-Italic.ttf Norasi
# /usr/share/fonts/truetype/freefont/FreeSerifItalic.ttf FreeSerif
# /usr/share/fonts/opentype/stix/STIXSizeFourSym-Regular.otf STIXSizeFourSym
# /usr/share/fonts/opentype/stix-word/STIX-BoldItalic.otf STIX
# /usr/share/fonts/truetype/tlwg/TlwgTypewriter-Oblique.ttf Tlwg Typewriter
# /usr/share/fonts/truetype/kacst/KacstTitleL.ttf KacstTitleL
# /usr/share/fonts/truetype/tlwg/TlwgMono-Bold.ttf Tlwg Mono
# /usr/share/fonts/truetype/tlwg/Kinnari-Italic.ttf Kinnari
# /usr/share/fonts/opentype/noto/NotoSansCJK-Black.ttc Noto Sans CJK JP
# /usr/share/fonts/opentype/stix/STIXNonUnicode-Regular.otf STIXNonUnicode
# /usr/share/fonts/truetype/tibetan-machine/TibetanMachineUni.ttf Tibetan Machine Uni
# /usr/share/fonts/truetype/tlwg/Loma-Oblique.ttf Loma
# /usr/share/fonts/truetype/nanum/NanumBarunGothicBold.ttf NanumBarunGothic
# /usr/share/fonts/truetype/tlwg/Garuda-Oblique.ttf Garuda
# /usr/share/fonts/truetype/freefont/FreeMonoOblique.ttf FreeMono
# /usr/share/fonts/opentype/stix/STIXGeneral-Regular.otf STIXGeneral
# /usr/share/fonts/truetype/kacst/KacstScreen.ttf KacstScreen
# /usr/share/fonts/opentype/stix/STIXSizeOneSym-Bold.otf STIXSizeOneSym
# /usr/share/fonts/truetype/freefont/FreeSansBold.ttf FreeSans
# /usr/share/fonts/truetype/freefont/FreeSansBoldOblique.ttf FreeSans
# /usr/share/fonts/truetype/tlwg/Sawasdee-Bold.ttf Sawasdee
# /usr/share/fonts/truetype/kacst/KacstOffice.ttf KacstOffice
# /usr/share/fonts/truetype/liberation/LiberationSans-Italic.ttf Liberation Sans
# /usr/share/fonts/opentype/stix/STIXSizeTwoSym-Bold.otf STIXSizeTwoSym
# /usr/share/fonts/truetype/tlwg/Waree-Oblique.ttf Waree
# /usr/share/fonts/truetype/tlwg/Norasi-Bold.ttf Norasi
# /usr/share/fonts/truetype/takao-gothic/TakaoPGothic.ttf TakaoPGothic
# /usr/share/fonts/truetype/tlwg/Norasi-BoldItalic.ttf Norasi
# /usr/share/fonts/truetype/padauk/Padauk-book.ttf Padauk Book
# /usr/share/fonts/truetype/tlwg/Loma-BoldOblique.ttf Loma
# /usr/share/fonts/truetype/tlwg/Garuda-Bold.ttf Garuda
# /usr/share/fonts/truetype/liberation/LiberationSerif-Italic.ttf Liberation Serif
# /usr/share/fonts/truetype/kacst/KacstPoster.ttf KacstPoster
# /usr/share/fonts/opentype/stix/STIXVariants-Regular.otf STIXVariants
# /usr/share/fonts/truetype/tlwg/Laksaman-BoldItalic.ttf Laksaman
# /usr/share/fonts/truetype/liberation/LiberationMono-Bold.ttf Liberation Mono

# %%
import matplotlib as mpl
zhfont = mpl.font_manager.FontProperties(fname='/usr/share/fonts/truetype/arphic/uming.ttc')
plt.text(0, 0, u'測試一下 ', fontsize=20, fontproperties=zhfont)
# Out:
# Text(0, 0, '測試一下 ')

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.text(0, 0, u'測試一下')
# Out:
# Text(0, 0, '測試一下')

# %%
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 4.1.10  導出圖表

# %%
import pandas as pd
import matplotlib.pyplot as plt
from io import BytesIO
from lxml import etree
import base64
import webbrowser

data = pd.DataFrame({'id':['1','2','3','4','5'], # 構造數據
                     'math':[90,89,99,78,63],
                     'english':[89,94,80,81,94]})
plt.plot(data['math']) # matplotlib做圖
plt.plot(data['english'])

# 保存圖片（與網頁顯示無關）
plt.savefig('test.jpg',dpi=300)

# 保存網頁
buffer = BytesIO()
plt.savefig(buffer)  
plot_data = buffer.getvalue()

imb = base64.b64encode(plot_data)  # 生成網頁內容
ims = imb.decode()
imd = "data:image/png;base64,"+ims
data_im = """<h1>Figure</h1>  """ + """<img src="%s">""" % imd   
data_des = """<h1>Describe</h1>"""+data.describe().T.to_html()
root = "<title>Dataset</title>"
root = root + data_des + data_im

html = etree.HTML(root)
tree = etree.ElementTree(html)
tree.write('tmp.html')
#使用默認瀏覽器打開 html 文件
webbrowser.open('tmp.html',new = 1)
# Out:
# True

# %% [markdown]
# ### 4.1.11  Matplotlib技巧

# %%
import matplotlib

fig = plt.figure(figsize = (6,4), dpi=120) # 設置繪製對象大小
plt.style.use('ggplot') # 設置顯示風格

plt.plot([12,13,45,15,16], label='label1') # 繪圖及設置圖例文字
plt.annotate('local max', xy=(2, 45), xytext=(3, 45),arrowprops=dict(facecolor='black',
    shrink=0.05))  # 繪製帶箭頭的標註
x = np.arange(0, 6)
y = x * x
plt.plot(x, y, marker='o', label='label2') # 繪圖及設置圖例文字
for xy in zip(x, y):
    plt.annotate("(%s,%s)" % xy, xy=xy, xytext=(-20, 10), # 繪製標註
                 textcoords='offset points')
plt.text(4.5, 10, 'Draw text', fontsize=20) # 在位置0,20繪製文字

plt.legend(loc='upper left')  # 在左上角顯示圖例
plt.xlabel("x value")  # 設置x軸上的標籤
plt.ylabel("y value")  # 設置y軸上的標籤
plt.xlim(-0.5,7)  # 設置x軸範圍
plt.ylim(-5,50) # 設置y軸範圍
plt.show()

print(matplotlib.artist.getp(fig.patch))  # 顯示繪製對象的各個屬性值
# Out:
#     agg_filter = None
#     alpha = None
#     animated = False
#     antialiased or aa = False
#     bbox = Bbox(x0=0.0, y0=0.0, x1=1.0, y1=1.0)
#     capstyle = butt
#     children = []
#     clip_box = None
#     clip_on = True
#     clip_path = None
#     contains = None
#     data_transform = BboxTransformTo(     TransformedBbox(         Bbox...
#     edgecolor or ec = (1.0, 1.0, 1.0, 0.0)
#     extents = Bbox(x0=0.0, y0=0.0, x1=720.0, y1=480.0)
#     facecolor or fc = (1.0, 1.0, 1.0, 0.0)
#     figure = Figure(720x480)
#     fill = True
#     gid = None
#     hatch = None
#     height = 1
#     in_layout = True
#     joinstyle = miter
#     label =
#     linestyle or ls = solid
#     linewidth or lw = 0.0
#     patch_transform = CompositeGenericTransform(     BboxTransformTo(   ...
#     path = Path(array([[0., 0.],        [1., 0.],        [1.,...
#     path_effects = []
#     picker = None
#     rasterized = None
#     sketch_params = None
#     snap = None
#     transform = CompositeGenericTransform(     CompositeGenericTra...
#     transformed_clip_path_and_affine = (None, None)
#     url = None
#     verts = [[  0.   0.]  [720.   0.]  [720. 480.]  [  0. 480....
#     visible = True
#     width = 1
#     window_extent = Bbox(x0=0.0, y0=0.0, x1=720.0, y1=480.0)
#     x = 0
#     xy = (0, 0)
#     y = 0
#     zorder = 1
# None
