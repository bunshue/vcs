# %% [markdown]
# ### 注意：代碼目錄只包含用於示例的部分數據，實際數據請從天池競賽平臺下載
# ### https://tianchi.aliyun.com/competition/gameList/activeList

# %%
import pandas as pd
import numpy as np
import datetime
from pandas.api.types import is_numeric_dtype # 用於判斷特徵類型
from sklearn.model_selection import cross_val_score, train_test_split # 切分數據集
from sklearn.metrics import mean_squared_error # 評價函數

data = pd.read_csv('data/happiness_train_min.csv', encoding='gb2312')
test = pd.read_csv('data/happiness_test_min.csv', encoding='gb2312')

# %%
# 特徵工程

def get_mean(fea, data, test): # 同時變換訓練集和測試集
    arr1 = data[fea].unique()
    arr2 = test[fea].unique()
    arr3 = list(arr1)
    arr3.extend(arr2) # 有的數據只出現在訓練集或測試集中
    arr4 = list(set(arr3))
    dic = {}
    for x in arr4:
        dic[x] = data[data[fea] == x][label].mean() # 取其因變量均值
    data[fea] = data[fea].apply(lambda x: dic[x]) # 數據替換
    test[fea] = test[fea].apply(lambda x: dic[x])
    return data,test

label = 'happiness' # 目標變量
features = []

data, test = get_mean('city', data, test)
data, test = get_mean('invest_other', data, test)
data, test = get_mean('province', data, test)

for col in data.columns:
    if not is_numeric_dtype(data[col]): # 非數值型特徵
        continue
    elif col != label and col != 'id' and col not in ['public_service_7']: # 去掉干擾特徵
        features.append(col)
        data[col] = data[col].apply(lambda x: np.nan if x < 0 else x) # 優化點一
        test[col] = test[col].apply(lambda x: np.nan if x < 0 else x)

data_all = pd.concat([data,test]) # 優化點二
data = data[data['happiness'] > 0] # 去掉因變量缺失的數據
x = data[features] # 自變量
y = data[label] # 目標變量
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.25, random_state=0)
x_train = x_train.fillna(data_all[features].mean()) # 空值填充訓練集
x_val = x_val.fillna(data_all[features].mean()) # 空值填充驗證集
x_test = test.fillna(data_all[features].mean()) # 空值填充測試集
x = x.fillna(data_all[features].mean()) # 空值填充全集
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:31: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
# 訓練模型

import xgboost as xgb
from sklearn.cross_validation import KFold
import numpy as np

def my_eval(preds, train): # 自定義評價函數
    score = mean_squared_error(train.get_label(), preds)
    return 'myeval', score

my_params = {"booster":'gbtree','eta': 0.005, 'max_depth': 6, 'subsample': 0.7, 
              'colsample_bytree': 0.8, 'objective': 'reg:linear', 'eval_metric': 'rmse', 
              'silent': True, 'nthread': 4} # 模型參數

train_preds = np.zeros(len(data)) # 用於保存預測結果
test_preds = np.zeros(len(test))
kf = KFold(len(data), n_folds = 5, shuffle=True, random_state=0) # 5折交叉驗證
for fold, (trn_idx, val_idx) in enumerate(kf):
    print("fold {}".format(fold+1))
    train_data = xgb.DMatrix(data[features].iloc[trn_idx], data[label].iloc[trn_idx]) # 訓練集
    val_data = xgb.DMatrix(data[features].iloc[val_idx], data[label].iloc[val_idx]) # 驗證集
    watchlist = [(train_data, 'train'), (val_data, 'valid_data')]
    clf = xgb.train(dtrain=train_data, num_boost_round=5000, evals=watchlist, 
               early_stopping_rounds=200, verbose_eval=100, 
               params=my_params,feval = my_eval)
    train_preds[val_idx] = clf.predict(xgb.DMatrix(data[features].iloc[val_idx]),
               ntree_limit=clf.best_ntree_limit)
    test_preds += clf.predict(xgb.DMatrix(test[features]), 
               ntree_limit=clf.best_ntree_limit) / kf.n_folds
print("CV score: {:<8.8f}".format(mean_squared_error(train_preds, data[label])))

df = pd.DataFrame() # 生成提交結果
df['id'] = test.id
df['happiness'] = test_preds
df.to_csv('out/submit_{}.csv'.format(datetime.datetime.now().strftime('%Y%m%d_%H%M%S')),index=False)
# Out:
# fold 1
# [0]	train-rmse:3.44227	valid_data-rmse:3.47826	train-myeval:11.8492	valid_data-myeval:12.0983
# Multiple eval metrics have been passed: 'valid_data-myeval' will be used for early stopping.
#
# Will train until valid_data-myeval hasn't improved in 200 rounds.
# /usr/local/lib/python3.6/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [100]	train-rmse:2.15998	valid_data-rmse:2.19651	train-myeval:4.66551	valid_data-myeval:4.82466
# [200]	train-rmse:1.40795	valid_data-rmse:1.44959	train-myeval:1.98231	valid_data-myeval:2.10133
# [300]	train-rmse:0.983552	valid_data-rmse:1.03569	train-myeval:0.967374	valid_data-myeval:1.07265
# [400]	train-rmse:0.756499	valid_data-rmse:0.823961	train-myeval:0.57229	valid_data-myeval:0.678911
# [500]	train-rmse:0.641039	valid_data-rmse:0.724438	train-myeval:0.410932	valid_data-myeval:0.524811
# [600]	train-rmse:0.581517	valid_data-rmse:0.680049	train-myeval:0.338162	valid_data-myeval:0.462467
# [700]	train-rmse:0.548352	valid_data-rmse:0.660345	train-myeval:0.30069	valid_data-myeval:0.436055
# [800]	train-rmse:0.52708	valid_data-rmse:0.651311	train-myeval:0.277813	valid_data-myeval:0.424206
# [900]	train-rmse:0.510916	valid_data-rmse:0.646678	train-myeval:0.261035	valid_data-myeval:0.418193
# [1000]	train-rmse:0.497112	valid_data-rmse:0.644209	train-myeval:0.247121	valid_data-myeval:0.415006
# [1100]	train-rmse:0.484903	valid_data-rmse:0.642814	train-myeval:0.235131	valid_data-myeval:0.41321
# [1200]	train-rmse:0.473031	valid_data-rmse:0.642004	train-myeval:0.223758	valid_data-myeval:0.412169
# [1300]	train-rmse:0.462242	valid_data-rmse:0.641773	train-myeval:0.213668	valid_data-myeval:0.411873
# [1400]	train-rmse:0.452294	valid_data-rmse:0.641414	train-myeval:0.20457	valid_data-myeval:0.411412
# [1500]	train-rmse:0.442914	valid_data-rmse:0.641133	train-myeval:0.196173	valid_data-myeval:0.411052
# [1600]	train-rmse:0.433609	valid_data-rmse:0.641076	train-myeval:0.188017	valid_data-myeval:0.410979
# [1700]	train-rmse:0.424445	valid_data-rmse:0.641081	train-myeval:0.180154	valid_data-myeval:0.410985
# Stopping. Best iteration:
# [1531]	train-rmse:0.439905	valid_data-rmse:0.640957	train-myeval:0.193517	valid_data-myeval:0.410826
#
# fold 2
# [0]	train-rmse:3.45005	valid_data-rmse:3.447	train-myeval:11.9028	valid_data-myeval:11.8818
# Multiple eval metrics have been passed: 'valid_data-myeval' will be used for early stopping.
#
# Will train until valid_data-myeval hasn't improved in 200 rounds.
# [100]	train-rmse:2.16269	valid_data-rmse:2.16924	train-myeval:4.67722	valid_data-myeval:4.70561
# [200]	train-rmse:1.40721	valid_data-rmse:1.4327	train-myeval:1.98022	valid_data-myeval:2.05263
# [300]	train-rmse:0.979947	valid_data-rmse:1.03295	train-myeval:0.960297	valid_data-myeval:1.06699
# [400]	train-rmse:0.751196	valid_data-rmse:0.835104	train-myeval:0.564296	valid_data-myeval:0.697399
# [500]	train-rmse:0.634551	valid_data-rmse:0.746803	train-myeval:0.402655	valid_data-myeval:0.557714
# [600]	train-rmse:0.574514	valid_data-rmse:0.709725	train-myeval:0.330066	valid_data-myeval:0.50371
# [700]	train-rmse:0.541163	valid_data-rmse:0.695134	train-myeval:0.292858	valid_data-myeval:0.483211
# [800]	train-rmse:0.519438	valid_data-rmse:0.688887	train-myeval:0.269816	valid_data-myeval:0.474565
# [900]	train-rmse:0.502667	valid_data-rmse:0.686257	train-myeval:0.252674	valid_data-myeval:0.470949
# [1000]	train-rmse:0.488723	valid_data-rmse:0.684753	train-myeval:0.238851	valid_data-myeval:0.468887
# [1100]	train-rmse:0.475897	valid_data-rmse:0.6837	train-myeval:0.226478	valid_data-myeval:0.467446
# [1200]	train-rmse:0.464176	valid_data-rmse:0.683316	train-myeval:0.215459	valid_data-myeval:0.466921
# [1300]	train-rmse:0.452934	valid_data-rmse:0.683109	train-myeval:0.205149	valid_data-myeval:0.466638
# [1400]	train-rmse:0.442223	valid_data-rmse:0.682906	train-myeval:0.195561	valid_data-myeval:0.46636
# [1500]	train-rmse:0.432397	valid_data-rmse:0.682897	train-myeval:0.186967	valid_data-myeval:0.466349
# [1600]	train-rmse:0.423007	valid_data-rmse:0.682562	train-myeval:0.178934	valid_data-myeval:0.465891
# [1700]	train-rmse:0.413988	valid_data-rmse:0.682574	train-myeval:0.171386	valid_data-myeval:0.465907
# [1800]	train-rmse:0.405306	valid_data-rmse:0.682415	train-myeval:0.164273	valid_data-myeval:0.46569
# [1900]	train-rmse:0.396745	valid_data-rmse:0.682449	train-myeval:0.157406	valid_data-myeval:0.465736
# Stopping. Best iteration:
# [1774]	train-rmse:0.407515	valid_data-rmse:0.682388	train-myeval:0.166068	valid_data-myeval:0.465653
#
# fold 3
# [0]	train-rmse:3.45401	valid_data-rmse:3.4311	train-myeval:11.9302	valid_data-myeval:11.7724
# Multiple eval metrics have been passed: 'valid_data-myeval' will be used for early stopping.
#
# Will train until valid_data-myeval hasn't improved in 200 rounds.
# [100]	train-rmse:2.16387	valid_data-rmse:2.15672	train-myeval:4.68233	valid_data-myeval:4.65142
# [200]	train-rmse:1.40698	valid_data-rmse:1.42419	train-myeval:1.97958	valid_data-myeval:2.02832
# [300]	train-rmse:0.978692	valid_data-rmse:1.0289	train-myeval:0.957839	valid_data-myeval:1.05863
# [400]	train-rmse:0.750044	valid_data-rmse:0.835362	train-myeval:0.562566	valid_data-myeval:0.69783
# [500]	train-rmse:0.633798	valid_data-rmse:0.750531	train-myeval:0.4017	valid_data-myeval:0.563296
# [600]	train-rmse:0.57484	valid_data-rmse:0.715752	train-myeval:0.330441	valid_data-myeval:0.512301
# [700]	train-rmse:0.541962	valid_data-rmse:0.701309	train-myeval:0.293722	valid_data-myeval:0.491834
# [800]	train-rmse:0.520796	valid_data-rmse:0.694564	train-myeval:0.271229	valid_data-myeval:0.482418
# [900]	train-rmse:0.50426	valid_data-rmse:0.691248	train-myeval:0.254278	valid_data-myeval:0.477824
# [1000]	train-rmse:0.491338	valid_data-rmse:0.689052	train-myeval:0.241413	valid_data-myeval:0.474792
# [1100]	train-rmse:0.47957	valid_data-rmse:0.687486	train-myeval:0.229988	valid_data-myeval:0.472637
# [1200]	train-rmse:0.468135	valid_data-rmse:0.686294	train-myeval:0.21915	valid_data-myeval:0.470999
# [1300]	train-rmse:0.457656	valid_data-rmse:0.685334	train-myeval:0.209449	valid_data-myeval:0.469683
# [1400]	train-rmse:0.44741	valid_data-rmse:0.68489	train-myeval:0.200176	valid_data-myeval:0.469074
# [1500]	train-rmse:0.438082	valid_data-rmse:0.684439	train-myeval:0.191916	valid_data-myeval:0.468457
# [1600]	train-rmse:0.42871	valid_data-rmse:0.684088	train-myeval:0.183792	valid_data-myeval:0.467976
# [1700]	train-rmse:0.419765	valid_data-rmse:0.683735	train-myeval:0.176203	valid_data-myeval:0.467493
# [1800]	train-rmse:0.410727	valid_data-rmse:0.683216	train-myeval:0.168696	valid_data-myeval:0.466783
# [1900]	train-rmse:0.402457	valid_data-rmse:0.682824	train-myeval:0.161972	valid_data-myeval:0.466249
# [2000]	train-rmse:0.394123	valid_data-rmse:0.682707	train-myeval:0.155333	valid_data-myeval:0.466089
# [2100]	train-rmse:0.385756	valid_data-rmse:0.682649	train-myeval:0.148808	valid_data-myeval:0.466009
# [2200]	train-rmse:0.377764	valid_data-rmse:0.68233	train-myeval:0.142705	valid_data-myeval:0.465574
# [2300]	train-rmse:0.370386	valid_data-rmse:0.682268	train-myeval:0.137186	valid_data-myeval:0.465489
# [2400]	train-rmse:0.362629	valid_data-rmse:0.682179	train-myeval:0.1315	valid_data-myeval:0.465368
# [2500]	train-rmse:0.355264	valid_data-rmse:0.682259	train-myeval:0.126212	valid_data-myeval:0.465477
# [2600]	train-rmse:0.348123	valid_data-rmse:0.682218	train-myeval:0.12119	valid_data-myeval:0.465422
# [2700]	train-rmse:0.341057	valid_data-rmse:0.681957	train-myeval:0.11632	valid_data-myeval:0.465066
# [2800]	train-rmse:0.334053	valid_data-rmse:0.681974	train-myeval:0.111592	valid_data-myeval:0.465088
# [2900]	train-rmse:0.327315	valid_data-rmse:0.681963	train-myeval:0.107135	valid_data-myeval:0.465073
# [3000]	train-rmse:0.320733	valid_data-rmse:0.682038	train-myeval:0.10287	valid_data-myeval:0.465175
# [3100]	train-rmse:0.314454	valid_data-rmse:0.68176	train-myeval:0.098881	valid_data-myeval:0.464797
# [3200]	train-rmse:0.308023	valid_data-rmse:0.681877	train-myeval:0.094878	valid_data-myeval:0.464956
# [3300]	train-rmse:0.30204	valid_data-rmse:0.682014	train-myeval:0.091228	valid_data-myeval:0.465144
# Stopping. Best iteration:
# [3161]	train-rmse:0.310529	valid_data-rmse:0.681726	train-myeval:0.096428	valid_data-myeval:0.464751
#
# fold 4
# [0]	train-rmse:3.44804	valid_data-rmse:3.45524	train-myeval:11.889	valid_data-myeval:11.9387
# Multiple eval metrics have been passed: 'valid_data-myeval' will be used for early stopping.
#
# Will train until valid_data-myeval hasn't improved in 200 rounds.
# [100]	train-rmse:2.16142	valid_data-rmse:2.18027	train-myeval:4.67176	valid_data-myeval:4.75358
# [200]	train-rmse:1.40681	valid_data-rmse:1.44356	train-myeval:1.97912	valid_data-myeval:2.08386
# [300]	train-rmse:0.979591	valid_data-rmse:1.04016	train-myeval:0.959598	valid_data-myeval:1.08194
# [400]	train-rmse:0.751583	valid_data-rmse:0.839116	train-myeval:0.564877	valid_data-myeval:0.704116
# [500]	train-rmse:0.635863	valid_data-rmse:0.747358	train-myeval:0.404321	valid_data-myeval:0.558544
# [600]	train-rmse:0.57695	valid_data-rmse:0.708381	train-myeval:0.332872	valid_data-myeval:0.501804
# [700]	train-rmse:0.544043	valid_data-rmse:0.691651	train-myeval:0.295982	valid_data-myeval:0.478381
# [800]	train-rmse:0.523189	valid_data-rmse:0.684391	train-myeval:0.273727	valid_data-myeval:0.468391
# [900]	train-rmse:0.506777	valid_data-rmse:0.680831	train-myeval:0.256823	valid_data-myeval:0.463531
# [1000]	train-rmse:0.493576	valid_data-rmse:0.67878	train-myeval:0.243617	valid_data-myeval:0.460742
# [1100]	train-rmse:0.481373	valid_data-rmse:0.677462	train-myeval:0.23172	valid_data-myeval:0.458955
# [1200]	train-rmse:0.469686	valid_data-rmse:0.676994	train-myeval:0.220605	valid_data-myeval:0.45832
# [1300]	train-rmse:0.458814	valid_data-rmse:0.67667	train-myeval:0.21051	valid_data-myeval:0.457883
# [1400]	train-rmse:0.448452	valid_data-rmse:0.676225	train-myeval:0.201109	valid_data-myeval:0.45728
# [1500]	train-rmse:0.437874	valid_data-rmse:0.67626	train-myeval:0.191734	valid_data-myeval:0.457327
# [1600]	train-rmse:0.42805	valid_data-rmse:0.675966	train-myeval:0.183227	valid_data-myeval:0.45693
# [1700]	train-rmse:0.418878	valid_data-rmse:0.675723	train-myeval:0.175459	valid_data-myeval:0.456602
# [1800]	train-rmse:0.410489	valid_data-rmse:0.675562	train-myeval:0.168501	valid_data-myeval:0.456384
# [1900]	train-rmse:0.402255	valid_data-rmse:0.675483	train-myeval:0.161809	valid_data-myeval:0.456277
# [2000]	train-rmse:0.394007	valid_data-rmse:0.67551	train-myeval:0.155242	valid_data-myeval:0.456314
# [2100]	train-rmse:0.385756	valid_data-rmse:0.675612	train-myeval:0.148807	valid_data-myeval:0.456452
# Stopping. Best iteration:
# [1967]	train-rmse:0.396849	valid_data-rmse:0.675384	train-myeval:0.157489	valid_data-myeval:0.456144
#
# fold 5
# [0]	train-rmse:3.45283	valid_data-rmse:3.43581	train-myeval:11.9221	valid_data-myeval:11.8048
# Multiple eval metrics have been passed: 'valid_data-myeval' will be used for early stopping.
#
# Will train until valid_data-myeval hasn't improved in 200 rounds.
# [100]	train-rmse:2.16418	valid_data-rmse:2.16094	train-myeval:4.68365	valid_data-myeval:4.66964
# [200]	train-rmse:1.40836	valid_data-rmse:1.42601	train-myeval:1.98348	valid_data-myeval:2.03351
# [300]	train-rmse:0.981011	valid_data-rmse:1.02633	train-myeval:0.962382	valid_data-myeval:1.05336
# [400]	train-rmse:0.752739	valid_data-rmse:0.828497	train-myeval:0.566616	valid_data-myeval:0.686406
# [500]	train-rmse:0.636798	valid_data-rmse:0.739833	train-myeval:0.405512	valid_data-myeval:0.547353
# [600]	train-rmse:0.577304	valid_data-rmse:0.702893	train-myeval:0.33328	valid_data-myeval:0.494058
# [700]	train-rmse:0.543891	valid_data-rmse:0.687762	train-myeval:0.295817	valid_data-myeval:0.473017
# [800]	train-rmse:0.52258	valid_data-rmse:0.680817	train-myeval:0.27309	valid_data-myeval:0.463512
# [900]	train-rmse:0.50589	valid_data-rmse:0.678031	train-myeval:0.255925	valid_data-myeval:0.459726
# [1000]	train-rmse:0.492051	valid_data-rmse:0.676208	train-myeval:0.242114	valid_data-myeval:0.457257
# [1100]	train-rmse:0.479806	valid_data-rmse:0.67519	train-myeval:0.230213	valid_data-myeval:0.455881
# [1200]	train-rmse:0.468807	valid_data-rmse:0.67455	train-myeval:0.21978	valid_data-myeval:0.455018
# [1300]	train-rmse:0.457989	valid_data-rmse:0.674203	train-myeval:0.209754	valid_data-myeval:0.45455
# [1400]	train-rmse:0.447637	valid_data-rmse:0.674016	train-myeval:0.200379	valid_data-myeval:0.454298
# [1500]	train-rmse:0.43747	valid_data-rmse:0.673627	train-myeval:0.19138	valid_data-myeval:0.453774
# [1600]	train-rmse:0.428088	valid_data-rmse:0.673583	train-myeval:0.183259	valid_data-myeval:0.453714
# [1700]	train-rmse:0.418643	valid_data-rmse:0.673392	train-myeval:0.175262	valid_data-myeval:0.453456
# [1800]	train-rmse:0.40936	valid_data-rmse:0.673463	train-myeval:0.167576	valid_data-myeval:0.453553
# Stopping. Best iteration:
# [1653]	train-rmse:0.42314	valid_data-rmse:0.673189	train-myeval:0.179047	valid_data-myeval:0.453183
#
# CV score: 0.45011008

# %%
import matplotlib.pyplot as plt

fig,ax = plt.subplots()
fig.set_size_inches(40,6)
xgb.plot_tree(clf, ax=ax, num_trees=0) # 顯示模型中的第一棵樹
plt.savefig('tmp.png',dpi=300)

# %%
# 檢測干擾變量

from sklearn.ensemble import GradientBoostingRegressor

baseline = 0.4887 # 誤差baseline
for i in features:
    features_new = [x for x in features if x != i]
    clf = GradientBoostingRegressor(criterion='mse', random_state=0)
    clf.fit(x_train[features_new], y_train)
    mse = mean_squared_error(y_val, [round(i) for i in clf.predict(x_val[features_new])])
    if mse < baseline:
        print("remove", i, "MSE: %.4f" % mse)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# remove survey_type MSE: 0.4712
# remove province MSE: 0.4732
# remove city MSE: 0.4807
# remove county MSE: 0.4697
# remove gender MSE: 0.4812
# remove birth MSE: 0.4762
# remove nationality MSE: 0.4687
# remove religion MSE: 0.4772
# remove religion_freq MSE: 0.4702
# remove edu MSE: 0.4707
# remove edu_status MSE: 0.4787
# remove edu_yr MSE: 0.4737
# remove income MSE: 0.4637
# remove political MSE: 0.4727
# remove join_party MSE: 0.4702
# remove floor_area MSE: 0.4752
# remove property_0 MSE: 0.4717
# remove property_1 MSE: 0.4707
# remove property_2 MSE: 0.4707
# remove property_3 MSE: 0.4707
# remove property_4 MSE: 0.4707
# remove property_5 MSE: 0.4707
# remove property_6 MSE: 0.4687
# remove property_7 MSE: 0.4707
# remove property_8 MSE: 0.4712
# remove height_cm MSE: 0.4757
# remove weight_jin MSE: 0.4722
# remove health MSE: 0.4712
# remove health_problem MSE: 0.4757
# remove hukou MSE: 0.4712
# remove hukou_loc MSE: 0.4707
# remove media_1 MSE: 0.4707
# remove media_2 MSE: 0.4712
# remove media_3 MSE: 0.4752
# remove media_4 MSE: 0.4717
# remove media_5 MSE: 0.4712
# remove media_6 MSE: 0.4692
# remove leisure_1 MSE: 0.4737
# remove leisure_2 MSE: 0.4737
# remove leisure_3 MSE: 0.4712
# remove leisure_4 MSE: 0.4712
# remove leisure_5 MSE: 0.4712
# remove leisure_6 MSE: 0.4712
# remove leisure_7 MSE: 0.4687
# remove leisure_8 MSE: 0.4737
# remove leisure_9 MSE: 0.4757
# remove leisure_10 MSE: 0.4707
# remove leisure_11 MSE: 0.4712
# remove leisure_12 MSE: 0.4707
# remove socialize MSE: 0.4787
# remove relax MSE: 0.4742
# remove learn MSE: 0.4692
# remove social_neighbor MSE: 0.4777
# remove social_friend MSE: 0.4742
# remove socia_outing MSE: 0.4797
# remove equity MSE: 0.4882
# remove class MSE: 0.4872
# remove class_10_before MSE: 0.4697
# remove class_10_after MSE: 0.4792
# remove class_14 MSE: 0.4632
# remove work_exper MSE: 0.4727
# remove work_status MSE: 0.4677
# remove work_yr MSE: 0.4707
# remove work_type MSE: 0.4702
# remove work_manage MSE: 0.4727
# remove insur_1 MSE: 0.4722
# remove insur_2 MSE: 0.4712
# remove insur_3 MSE: 0.4712
# remove insur_4 MSE: 0.4712
# remove family_income MSE: 0.4747
# remove family_m MSE: 0.4747
# remove family_status MSE: 0.4812
# remove house MSE: 0.4782
# remove car MSE: 0.4707
# remove invest_0 MSE: 0.4707
# remove invest_1 MSE: 0.4712
# remove invest_2 MSE: 0.4712
# remove invest_3 MSE: 0.4707
# remove invest_4 MSE: 0.4707
# remove invest_5 MSE: 0.4702
# remove invest_6 MSE: 0.4697
# remove invest_7 MSE: 0.4712
# remove invest_8 MSE: 0.4717
# remove invest_other MSE: 0.4682
# remove son MSE: 0.4677
# remove daughter MSE: 0.4737
# remove minor_child MSE: 0.4702
# remove marital MSE: 0.4782
# remove marital_1st MSE: 0.4747
# remove s_birth MSE: 0.4687
# remove marital_now MSE: 0.4717
# remove s_edu MSE: 0.4757
# remove s_political MSE: 0.4717
# remove s_hukou MSE: 0.4707
# remove s_income MSE: 0.4712
# remove s_work_exper MSE: 0.4707
# remove s_work_status MSE: 0.4702
# remove s_work_type MSE: 0.4702
# remove f_birth MSE: 0.4702
# remove f_edu MSE: 0.4702
# remove f_political MSE: 0.4707
# remove f_work_14 MSE: 0.4712
# remove m_birth MSE: 0.4737
# remove m_edu MSE: 0.4662
# remove m_political MSE: 0.4687
# remove m_work_14 MSE: 0.4662
# remove status_peer MSE: 0.4867
# remove status_3_before MSE: 0.4667
# remove view MSE: 0.4772
# remove inc_ability MSE: 0.4752
# remove inc_exp MSE: 0.4672
# remove trust_1 MSE: 0.4702
# remove trust_2 MSE: 0.4737
# remove trust_3 MSE: 0.4657
# remove trust_4 MSE: 0.4792
# remove trust_5 MSE: 0.4742
# remove trust_6 MSE: 0.4712
# remove trust_7 MSE: 0.4782
# remove trust_8 MSE: 0.4682
# remove trust_9 MSE: 0.4707
# remove trust_10 MSE: 0.4697
# remove trust_11 MSE: 0.4712
# remove trust_12 MSE: 0.4702
# remove trust_13 MSE: 0.4667
# remove neighbor_familiarity MSE: 0.4827
# remove public_service_1 MSE: 0.4707
# remove public_service_2 MSE: 0.4697
# remove public_service_3 MSE: 0.4767
# remove public_service_4 MSE: 0.4662
# remove public_service_5 MSE: 0.4687
# remove public_service_6 MSE: 0.4777
# remove public_service_8 MSE: 0.4692
# remove public_service_9 MSE: 0.4692
