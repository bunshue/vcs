# %%
#chap4-07a
a=[]
a.append(1)
a.append(3)
a.append(5)
a.append(7)
a.append(9)
print(a)
# Out:
# [1, 3, 5, 7, 9]

# %%
#chap4-07b
a=[]
for i in range(1,10,2):
  a.append(i)
print(a)
# Out:
# [1, 3, 5, 7, 9]

# %%
#chap4-07c
a=[i for i in range(1,10,2)]
print(a)
# Out:
# [1, 3, 5, 7, 9]

# %%
#chap4-07d
a=[i for i in range(1,10,1) if i%2==1]
print(a)
a=[[x,y,x*y] for x in range(1,4) for y in range(1,4)]
print(a)
# Out:
# [1, 3, 5, 7, 9]
# [[1, 1, 1], [1, 2, 2], [1, 3, 3], [2, 1, 2], [2, 2, 4], [2, 3, 6], [3, 1, 3], [3, 2, 6], [3, 3, 9]]

# %%
#chap4-07e
sentence="庭院深深深幾許淚眼問花花不語"
print(sentence.count("深"))
print(sentence.count("深深"))
print(sentence.count("深深深"))
a={char:sentence.count(char) for char in set(sentence)}
print(a)
word="ADIDAS"
a={letter:word.count(letter) for letter in set(word)}
print(a)
# Out:
# 3
# 1
# 1
# {'眼': 1, '淚': 1, '許': 1, '花': 2, '院': 1, '深': 3, '幾': 1, '問': 1, '語': 1, '庭': 1, '不': 1}
# {'A': 2, 'D': 2, 'S': 1, 'I': 1}

# %%
#chap4-07f
word="ADIDAS"
letters=set(word)
print(letters)
letters={letter for letter in word}
print(letters)
# Out:
# {'A', 'D', 'S', 'I'}
# {'A', 'D', 'S', 'I'}
