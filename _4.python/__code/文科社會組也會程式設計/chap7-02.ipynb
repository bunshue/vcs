# %%
#chap7-02a
import requests
url ='https://www.dcard.tw/f/stock/p/237123381'
res = requests.get(url)
print(res.text)

# %%
#chap7-02b
import requests
from bs4 import BeautifulSoup
url ='https://www.dcard.tw/f/stock/p/237123381'
res = requests.get(url)
#指定html.parser作為解析器
soup = BeautifulSoup(res.text, 'html.parser') 
#把排版後的html印出來，因為未排版前有很多網頁語法缺乏換行符號，不易閱讀
#必須借助於Beautiful Shop套件
print(soup.prettify())

# %%
#chap7-02c
import requests
from bs4 import BeautifulSoup
url = 'https://www.dcard.tw/f/stock/p/237123381'
res = requests.get(url)
#指定html.parser作為解析器
soup = BeautifulSoup(res.text, 'html.parser') 
#把排版後的html印出來
#print(soup.prettify()) 
a_tags = soup.find_all('h1')
print(">>>>>文章標題")
print(a_tags[0].contents[0])
print("\n")
# Out:
# >>>>>文章標題
# 我的投資初體驗！人生買的第一張股票怎麼挑的啊🤔

# %%
#chap7-02d
import requests
from bs4 import BeautifulSoup
url = 'https://www.dcard.tw/f/stock/p/237123381'
res = requests.get(url)
#指定html.parser作為解析器
soup = BeautifulSoup(res.text, 'html.parser') 
#把排版後的html印出來
#print(soup.prettify()) 
a_tags = soup.find_all('h1')
print(">>>>>文章標題")
print(a_tags[0].contents[0])
print("\n")
a_tags = soup.find_all('div',limit=1)
a_tag=a_tags[0]
cc=""
for b in a_tag.contents:
  if str(b).find("gFINpq")>=0:  
    b=str(b).replace('\n','').replace('\r','')
    cc=cc+b
print(cc.strip())
# Out:
# >>>>>文章標題
# 我的投資初體驗！人生買的第一張股票怎麼挑的啊🤔
#
#
# <div class="bvk29r-0 jhIZYh"><div class="bvk29r-1 cXYfzh"><div class="sc-1bfxmuy-0 hkUAph"><a href="/forum/all"><div class="sc-11gkikh-0 jGtkKv"><div class="sc-1bfxmuy-1 iVjreC"><svg aria-hidden="true" class="sc-husrwi dvqhOE" focusable="false" role="img" viewbox="0 0 24 24"><path d="M18.95 3H5.05A2.04 2.04 0 003 5.04v13.91A2.04 2.04 0 005.05 21h13.9A2.05 2.05 0 0021 18.96V5.03A2.05 2.05 0 0018.95 3zM6.68 17.73a1.64 1.64 0 111.64-1.64 1.64 1.64 0 01-1.64 1.64zm0-4.1A1.64 1.64 0 118.32 12a1.64 1.64 0 01-1.64 1.64zm0-4.08A1.64 1.64 0 118.32 7.9a1.64 1.64 0 01-1.64 1.64zm11.86 6.77a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.1a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.45a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.08a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1z" data-name="icon_md_forum"></path></svg></div><div class="gthja3-1 fvZEcc">所有看板</div></div></a><a href="/forum/popular"><div class="sc-11gkikh-0 jGtkKv"><div class="sc-1bfxmuy-1 iVjreC"><svg aria-hidden="true" class="sc-husrwi dvqhOE" focusable="false" role="img" viewbox="0 0 24 24"><path d="M19.5 14.5a7.5 7.5 0 01-15 0 12.9 12.9 0 012.21-7.25l.02-.03a.18.18 0 01.04-.05.5.5 0 01.31-.15.51.51 0 01.55.46A3.36 3.36 0 0010.9 10a3.26 3.26 0 003.2-3.5 16.5 16.5 0 00-.32-2.9 1.63 1.63 0 01-.04-.19V3.4a.5.5 0 01.49-.5.51.51 0 01.28.08.45.45 0 01.1.09A15.95 15.95 0 0119.5 14.5zm-3.59-1.55a12.97 12.97 0 00-.22-1.32.5.5 0 00-.83-.27 7.93 7.93 0 01-3.73 1.77 2.94 2.94 0 00-2.63 2.93c0 2.55 3.3 4.32 5.95 1.5a5.75 5.75 0 001.46-4.6z" data-name="ic_hot"></path></svg></div><div class="gthja3-1 fvZEcc">即時熱門看板</div></div></a><a href="/goods"><div class="sc-11gkikh-0 jGtkKv"><div class="sc-1bfxmuy-1 iVjreC"><svg aria-hidden="true" class="sc-husrwi dvqhOE m2vgdk-0 jdZdIW" focusable="false" height="24" role="img" style="fill:#fff" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M20.962 9l-.994-5a2.156 2.156 0 00-1.987-2H6.019a2.156 2.156 0 00-1.987 2l-.994 5A2.34 2.34 0 004 11.269V20a2 2 0 002 2h12a2 2 0 002-2v-8.731A2.34 2.34 0 0020.962 9zM6.019 10a1 1 0 01-.993-1l.993-5H7v5.042a.993.993 0 01-.981.958zM9 9V4h2v5a1 1 0 01-2 0zm5.5 11h-5v-5.143a.937.937 0 011-.857h3a.937.937 0 011 .857zM15 9a1 1 0 01-2 0V4h2zm2.981 1A.993.993 0 0117 9.042V4h.981l.993 5a1 1 0 01-.993 1z"></path><path d="M0 0h24v24H0z" fill="none"></path></svg></div><div class="gthja3-1 fvZEcc">好物研究室</div></div></a></div></div><div class="bvk29r-2 glwZhP"><div class="sc-10tqbnq-0 gsZYxo" role="main"><div class="sc-10tqbnq-1 kuiJhT"><div class="sc-1wisey8-0 buWRCP"><div class="sc-1bx44oc-0 ecWTaY"><div class="sc-2yjare-3 ekuPEY"></div><div class="auv9sk-0 iNekYe"><div class="sc-1oj78p7-0 czRoHf"><div class="sc-1oj78p7-1 klfKyS"><div class="rt56oo-1 kZmeZS"><div class="sc-1x2m678 eoESgl"><div class="rt56oo-0 cREKGP"><a class="xrkql2-3 hHyjVL" href="/@stockangel"><div class="eisivb-0 BquoC"><div class="eisivb-1 bGTWDl"><div class="yj50et-0 eOQgZp eisivb-2 bGPcym"><svg class="sc-husrwi dvqhOE sc-1airdzr-0 eYzQsU" focusable="false" height="32" style="fill:#006aa6" viewbox="0 0 100 100" width="32"><title>官方</title><path d="M100 50A50 50 0 110 50a50 50 0 01100 0"></path><g fill="#FFF"><path d="M61 43.7a4.9 4.9 0 00-5 5c0 2.6 2.3 4.8 5 4.8s4.9-2.2 4.9-4.9-2.2-4.9-5-4.9"></path><path d="M69.7 55.8l-.1 1.8a3.9 3.9 0 01-3.2.6c-1.6-.5-3.1-1.4-4.3-2.5l-4.1 4c2.5 2.5 5.7 4.2 9.4 4.7-3 5.3-8.8 9-15.3 9H34.5V49.5a44 44 0 0029.4-17.2c1.5 1 2.8 2.2 3.7 3.5 1.3 2.5 2 5.3 2 8.3v11.6zM52 20.8H28.6v58.4h23.5c13 0 23.4-10.5 23.4-23.4V44.2a23.4 23.4 0 00-23.4-23.4z"></path></g><path d="M20.8 20.8h58.3v58.3H20.8z" fill="none"></path></svg></div></div><div class="eisivb-3 kukaUv"><div class="eisivb-4 ggahOj"><div class="xrkql2-0 kdcyrU">股票小天使</div></div><div class="eisivb-5 GZSZ"><div class="xrkql2-2 cUFZKq"><div class="xrkql2-1 kDRfzo">@<!-- -->stockangel</div></div></div></div></div></a></div></div></div><div class="sc-1jn3b3k-0 iulbWD"><div class="sc-1jn3b3k-2 ewZtht"><button class="sc-pwv2fp kUPLe ...

# %%
#chap7-02e
import requests
from bs4 import BeautifulSoup
url = 'https://www.dcard.tw/f/stock/p/237123381'
res = requests.get(url)
#指定html.parser作為解析器
soup = BeautifulSoup(res.text, 'html.parser') 
#把排版後的html印出來
#print(soup.prettify()) 
a_tags = soup.find_all('h1')
print(">>>>>文章標題")
print(a_tags[0].contents[0])
print()
a_tags = soup.find_all('div',limit=1)
a_tag=a_tags[0]
cc=""
for b in a_tag.contents:
  if str(b).find("gFINpq")>=0:  
    b=str(b)
    cc=cc+b
cc=cc.strip()
data=">>>>>原Po文章\n"
#尋找前四筆，第一個是原Po文章，後三個則為熱門留言
for j in range(4):
  #尋找最附近的<div class>有gFINpq
  datapos1=cc.find("gFINpq")
  #只保留這個字串以後的文字
  cc=cc[datapos1:] 
  while True:
    #尋找最附近的<span
    datapos1=cc.find("<span")
    #只保留<span以後的文字
    cc=cc[datapos1:]
    #尋找最附近的>
    datapos1=cc.find(">")
    #尋找最附近的</span> 
    datapos2=cc.find("</span>")
    #如果<span></span>中間出現了enUbOQ，表示這個步驟該結束了 
    if cc[:datapos2].find("enUbOQ")>=0:
      break   
    #如果<span></span>有資料，就合併在data字串裡 
    if datapos1+1<datapos2:
      #但是<span></span>的資料，如果還有span就不行了
      if cc[datapos1+1:datapos2].find("span")<0:       
        data=data+cc[datapos1+1:datapos2]+"\n" 
    #只保留</span>之後的文字    
    cc=cc[datapos2+7:]
  #後三個是熱門留言
  if j<3:
    data=data+"\n*******熱門留言"+str(j+1)+":\n"  
print(data)
# Out:
# >>>>>文章標題
# 我的投資初體驗！人生買的第一張股票怎麼挑的啊🤔
#
# >>>>>原Po文章
# 股票板的卡友們大家好~
# 由於板上的新手卡友日益增加，也有越來越多的老手進駐發文
# 因此我們想舉辦一個特別企劃，讓老手們可以跟新手們分享自己初入股票投資的經驗
# 也可以讓新手藉此學習，找到入門的方法
#
# 你也有自己的獨特心法想要分享嗎？
# 現在就來發文吧！
#
# 📌活動文募集時間
# 10/1-10/8 19:00
#
# 活動方法
# 1.在股票板發布一篇文章，說明人生買入的第一張股票是什麼、當時如何做功課等等
# 2.給予新手如何入門的建議，無論是推薦的工具、書籍、觀念都可以哦！
# 3.在文章標題上加上 #初體驗
# 4.在文章話題加上「我的投資初體驗」
# 5.坐等文章爆紅🍿
#
# 如果你有開設卡稱，並在股票板持續經營自己
# 發表活動文章將更有機會讓你的卡稱被更多人看到，讓你的粉絲越來越多
# 如果你還沒有卡稱，也有機會讓更多人在 Dcard 上看到你的心得哦！
#
# 期待大大們的發文🙏🙏🙏
#
# *******熱門留言1:
# 跪求高手教學  輸到脫褲
# 1 天前
#
# *******熱門留言2:
# 唯一推無腦買0050或006208
# 1 天前
#
# *******熱門留言3:
# 只想要投機 就要承受輸錢的壓力
# 1 天前

# %%
#chap7-02f
import requests
import json
import pandas as pd
postid = '237123381'
url = 'https://www.dcard.tw/service/api/v2/posts/'+postid
res = requests.get(url)
#有兩種方法，下面兩行任選一種都可以
#data = json.loads(res.text) #方法1
data=res.json() #方法2
#查看有哪些欄位
print(data.keys())
#因為只有一欄，而且沒有欄位名稱
#否則只要 df = pd.DataFrame(data) 即可
df = pd.DataFrame.from_dict(data,orient="index")
#查看有哪些內容
print(df)
# Out:
# dict_keys(['id', 'title', 'content', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'tags', 'topics', 'supportedReactions', 'withNickname', 'reportReason', 'hiddenByAuthor', 'meta', 'forumName', 'forumAlias', 'nsfw', 'school', 'department', 'replyTitle', 'gender', 'personaSubscriptable', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'isModerator', 'layout', 'pinnedType', 'pinnedPriority', 'spoilerAlert', 'totalCommentCount', 'withImages', 'withVideos', 'media', 'reportReasonText', 'mediaMeta', 'excerptComments', 'edited', 'postAvatar', 'activityAvatar', 'verifiedBadge', 'memberType'])
#                                                                       0
# id                                                            237123381
# title                                           我的投資初體驗！人生買的第一張股票怎麼挑的啊🤔
# content               https://i.imgur.com/eyRbZzO.jpg\n股票板的卡友們大家好~\n...
# excerpt               股票板的卡友們大家好~，由於板上的新手卡友日益增加，也有越來越多的老手進駐發文，因此我們想舉...
# anonymousSchool                                                   False
# anonymousDepartment                                               False
# pinned                                                             True
# forumId                            2fb88b62-aa28-4b18-af51-dda08dd037a9
# replyId                                                            None
# createdAt                                      2021-10-01T10:57:08.249Z
# updatedAt                                      2021-10-01T11:08:24.671Z
# commentCount                                                         62
# likeCount                                                           400
# tags                                                                 []
# topics                                            [我的投資初體驗, 股票, 投資, 理財]
# supportedReactions                                                 None
# withNickname                                                       True
# reportReason
# hiddenByAuthor                                                    False
# meta                                              {'layout': 'classic'}
# forumName                                                            股票
# forumAlias                                                        stock
# nsfw                                                              False
# school                                                            股票小天使
# department                                                   stockangel
# replyTitle                                                         None
# gender                                                                D
# personaSubscriptable                                               True
# reactions             [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...
# hidden                                                            False
# customStyle                                                        None
# isSuspiciousAccount                                               False
# isModerator                                                       False
# layout                                                          classic
# pinnedType                                                        dcard
# pinnedPriority                                            1633086039337
# spoilerAlert                                                      False
# totalCommentCount                                                    62
# withImages                                                         True
# withVideos                                                        False
# media                      [{'url': 'https://i.imgur.com/eyRbZzO.jpg'}]
# reportReasonText
# mediaMeta             [{'id': 'f92cf9a6-d56d-4eae-8a80-ee712c044735'...
# excerptComments                                                      []
# edited                                                            False
# postAvatar
# activityAvatar
# verifiedBadge                                                      True
# memberType

# %%
#chap7-02g
import requests
import json
import pandas as pd
postid = '237123381'
url = 'https://www.dcard.tw/service/api/v2/posts/'+postid
res = requests.get(url)
#有兩種方法，下面兩行任選一種都可以
#data = json.loads(res.text) #方法1
data=res.json() #方法2
#因為只有一欄，而且沒有欄位名稱
#否則只要 df = pd.DataFrame(data) 即可
df = pd.DataFrame.from_dict(data,orient="index")
#取出title、content內容
print(">>>>>文章標題")
print(df.loc["title",0])
print()
print(">>>>>原Po文章")
print(str(df.loc["content",0]).strip())
# Out:
# >>>>>文章標題
# 我的投資初體驗！人生買的第一張股票怎麼挑的啊🤔
#
# >>>>>原Po文章
# https://i.imgur.com/eyRbZzO.jpg
# 股票板的卡友們大家好~
# 由於板上的新手卡友日益增加，也有越來越多的老手進駐發文
# 因此我們想舉辦一個特別企劃，讓老手們可以跟新手們分享自己初入股票投資的經驗
# 也可以讓新手藉此學習，找到入門的方法
#
# 你也有自己的獨特心法想要分享嗎？
# 現在就來發文吧！
#
# 📌活動文募集時間
# 10/1-10/8 19:00
#
# 活動方法
# 1.在股票板發布一篇文章，說明人生買入的第一張股票是什麼、當時如何做功課等等
# 2.給予新手如何入門的建議，無論是推薦的工具、書籍、觀念都可以哦！
# 3.在文章標題上加上 #初體驗
# 4.在文章話題加上「我的投資初體驗」
# 5.坐等文章爆紅🍿
#
# 如果你有開設卡稱，並在股票板持續經營自己
# 發表活動文章將更有機會讓你的卡稱被更多人看到，讓你的粉絲越來越多
# 如果你還沒有卡稱，也有機會讓更多人在 Dcard 上看到你的心得哦！
#
# 期待大大們的發文🙏🙏🙏

# %%
#chap7-02h
import requests
import json
import pandas as pd
from datetime import datetime
postid = '237123381'
url = 'https://www.dcard.tw/service/api/v2/posts/'+postid
res = requests.get(url)
#有兩種方法，下面兩行任選一種都可以
#data = json.loads(res.text) #方法1
data = res.json() #方法2
#因為只有一欄，而且沒有欄位名稱
#否則只要 df = pd.DataFrame(data) 即可
df = pd.DataFrame.from_dict(data,orient="index")
#取出title、content內容
print(">>>>>文章標題")
print(df[0]["title"])
print()
print(">>>>>原Po文章\n")
print(str(df[0]["content"]).strip())
url = 'https://www.dcard.tw/service/api/v2/posts/'+postid+'/comments?popular=True'
res = requests.get(url)
#有兩種方法，下面兩行任選一種都可以
#data = json.loads(res.text) #方法1
data = res.json() #方法2
#因為有欄位名稱
#只要 df = pd.DataFrame(data) 即可
df = pd.DataFrame(data)
#取出前3筆資料
for i in range(3):
  print("*******熱門留言"+str(i)+":")
  print(df.loc[i,"content"])
  #將最後修改文字日期轉換成日期  
  updatedate=datetime.fromisoformat(str(df.loc[i,"updatedAt"]).replace("Z",""))
  #計算現在和最後修改日期的時間差
  datediff=datetime.today()-updatedate
  #顯示幾天前有最新留言
  print(datediff.days,"天前")
  print()
#若要查看有哪些欄位
print((df.keys()))
#也可以透過df.info()查看
df.info()
#也可以直接看前幾列
df.head(3)
# Out:
# >>>>>文章標題
# 我的投資初體驗！人生買的第一張股票怎麼挑的啊🤔
#
# >>>>>原Po文章
#
# https://i.imgur.com/eyRbZzO.jpg
# 股票板的卡友們大家好~
# 由於板上的新手卡友日益增加，也有越來越多的老手進駐發文
# 因此我們想舉辦一個特別企劃，讓老手們可以跟新手們分享自己初入股票投資的經驗
# 也可以讓新手藉此學習，找到入門的方法
#
# 你也有自己的獨特心法想要分享嗎？
# 現在就來發文吧！
#
# 📌活動文募集時間
# 10/1-10/8 19:00
#
# 活動方法
# 1.在股票板發布一篇文章，說明人生買入的第一張股票是什麼、當時如何做功課等等
# 2.給予新手如何入門的建議，無論是推薦的工具、書籍、觀念都可以哦！
# 3.在文章標題上加上 #初體驗
# 4.在文章話題加上「我的投資初體驗」
# 5.坐等文章爆紅🍿
#
# 如果你有開設卡稱，並在股票板持續經營自己
# 發表活動文章將更有機會讓你的卡稱被更多人看到，讓你的粉絲越來越多
# 如果你還沒有卡稱，也有機會讓更多人在 Dcard 上看到你的心得哦！
#
# 期待大大們的發文🙏🙏🙏
# *******熱門留言0:
# 跪求高手教學  輸到脫褲
# 2 天前
#
# *******熱門留言1:
# 唯一推無腦買0050或006208
# 1 天前
#
# *******熱門留言2:
# 只想要投機 就要承受輸錢的壓力
# 1 天前
#
# Index(['id', 'anonymous', 'postId', 'createdAt', 'updatedAt', 'floor',
#        'content', 'likeCount', 'withNickname', 'hiddenByAuthor', 'meta',
#        'gender', 'school', 'host', 'reportReason', 'mediaMeta', 'hidden',
#        'inReview', 'reportReasonText', 'isSuspiciousAccount', 'isModerator',
#        'doorplate', 'edited', 'postAvatar', 'activityAvatar', 'verifiedBadge',
#        'memberType', 'enablePrivateMessage'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    3 non-null      object
#  1   anonymous             3 non-null      bool
#  2   postId                3 non-null      int64
#  3   createdAt             3 non-null      object
#  4   updatedAt             3 non-null      object
#  5   floor                 3 non-null      int64
#  6   content               3 non-null      object
#  7   likeCount             3 non-null      int64
#  8   withNickname          3 non-null      bool
#  9   hiddenByAuthor        3 non-null      bool
#  10  meta                  3 non-null      object
#  11  gender                3 non-null      object
#  12  school                3 non-null      object
#  13  host                  3 non-null      bool
#  14  reportReason          3 non-null      object
#  15  mediaMeta             3 non-null      object
#  16  hidden                3 non-null      bool
#  17  inReview              3 non-null      bool
#  18  reportReasonText      3 non-null      object
#  19  isSuspiciousAccount   3 non-null      bool
#  20  isModerator           3 non-null      bool
#  21  doorplate             3 non-null      object
#  22  edited                3 non-null      bool
#  23  postAvatar            3 non-null      object
#  24  activityAvatar        3 non-null      object
#  25  verifiedBadge         3 non-null      bool
#  26  memberType            3 non-null      object
#  27  enablePrivateMessage  1 non-null      object
# dtypes: bool(10), int64(3), object(15)
# memory usage: 590.0+ bytes
#                                      id  ...  enablePrivateMessage
# 0  4f9db986-7627-470a-8940-e01ee8015a97  ...                   NaN
# 1  089a859c-988d-4b90-9d75-ed2a0b1818e7  ...                 False
# 2  51824a6d-8cc6-4508-a221-76c14badf5eb  ...                   NaN
#
# [3 rows x 28 columns]

# %%
#chap7-02i
import requests
import json
import pandas as pd
from datetime import datetime
postid = '237123381'
url = 'https://www.dcard.tw/service/api/v2/posts/'+postid
res = requests.get(url)
#有兩種方法，下面兩行任選一種都可以
#data = json.loads(res.text) #方法1
data = res.json() #方法2
#因為只有一欄，而且沒有欄位名稱
#否則只要 df = pd.DataFrame(data) 即可
df = pd.DataFrame.from_dict(data,orient="index")
#取出title、content內容
print(">>>>>文章標題")
print(df[0]["title"])
print()
print(">>>>>原Po文章\n")
print(str(df[0]["content"]).strip())
url = 'https://www.dcard.tw/service/api/v2/posts/'+postid+'/comments'
res = requests.get(url)
#有兩種方法，下面兩行任選一種都可以
#data = json.loads(res.text) #方法1
data = res.json() #方法2
#因為有欄位名稱
#只要 df = pd.DataFrame(data) 即可
df = pd.DataFrame(data)
#除了updatedAt, content, likeCount三個欄位以外，全部刪除
#刪除欄依定要指定axis=1 
#inplace=True真實刪除
df.drop(['id', 'anonymous', 'postId', 'createdAt', 'floor',
    'withNickname', 'hiddenByAuthor', 'meta',
    'gender', 'school', 'host', 'reportReason', 'mediaMeta', 'hidden',
    'inReview', 'reportReasonText', 'isSuspiciousAccount', 'isModerator',
    'doorplate', 'edited', 'postAvatar', 'activityAvatar', 'verifiedBadge',
    'memberType', 'enablePrivateMessage', 'department'],inplace=True,axis=1)
#依據likeCout內容排序，以降序排列
df.sort_values(by='likeCount', inplace=True, ascending=False)
#要記得重設index，這樣df.loc[]的結果才會正確
df = df.reset_index(drop=True)
#取出前3筆資料
for i in range(3):
  print("*******熱門留言"+str(i)+":")
  print(df.loc[i,"content"])
  #將最後修改文字日期轉換成日期  
  updatedate=datetime.fromisoformat(str(df.loc[i,"updatedAt"]).replace("Z",""))
  #計算現在和最後修改日期的時間差
  datediff=datetime.today()-updatedate
  #顯示幾天前有最新留言
  print(datediff.days,"天前")
  print()
#若要查看有哪些欄位
print((df.keys()))
#也可以透過df.info()查看
df.info()
#也可以直接看前幾列
df.head(3)
# Out:
# >>>>>文章標題
# 我的投資初體驗！人生買的第一張股票怎麼挑的啊🤔
#
# >>>>>原Po文章
#
# https://i.imgur.com/eyRbZzO.jpg
# 股票板的卡友們大家好~
# 由於板上的新手卡友日益增加，也有越來越多的老手進駐發文
# 因此我們想舉辦一個特別企劃，讓老手們可以跟新手們分享自己初入股票投資的經驗
# 也可以讓新手藉此學習，找到入門的方法
#
# 你也有自己的獨特心法想要分享嗎？
# 現在就來發文吧！
#
# 📌活動文募集時間
# 10/1-10/8 19:00
#
# 活動方法
# 1.在股票板發布一篇文章，說明人生買入的第一張股票是什麼、當時如何做功課等等
# 2.給予新手如何入門的建議，無論是推薦的工具、書籍、觀念都可以哦！
# 3.在文章標題上加上 #初體驗
# 4.在文章話題加上「我的投資初體驗」
# 5.坐等文章爆紅🍿
#
# 如果你有開設卡稱，並在股票板持續經營自己
# 發表活動文章將更有機會讓你的卡稱被更多人看到，讓你的粉絲越來越多
# 如果你還沒有卡稱，也有機會讓更多人在 Dcard 上看到你的心得哦！
#
# 期待大大們的發文🙏🙏🙏
# *******熱門留言0:
# 跪求高手教學  輸到脫褲
# 2 天前
#
# *******熱門留言1:
# 唯一推無腦買0050或006208
# 2 天前
#
# *******熱門留言2:
# 只想要投機 就要承受輸錢的壓力
# 2 天前
#
# Index(['updatedAt', 'content', 'likeCount'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   updatedAt  30 non-null     object
#  1   content    28 non-null     object
#  2   likeCount  28 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 848.0+ bytes
#                   updatedAt            content  likeCount
# 0  2021-10-01T11:00:25.116Z       跪求高手教學  輸到脫褲       79.0
# 1  2021-10-01T14:17:09.866Z  唯一推無腦買0050或006208       72.0
# 2  2021-10-01T13:50:46.409Z    只想要投機 就要承受輸錢的壓力       29.0

# %%
#chap7-02j
import requests
import csv
import pandas as pd
#如果要將csv擋下載後讀取要 import io
#from io import StringIO
county="屏東縣"
url = 'https://data.epa.gov.tw/api/v1/aqx_p_432?limit=1000&api_key=9be7b239-557b-4c10-9775-78cadfc555e9&sort=ImportDate%20desc&format=csv'
#方法1:下載檔案後儲存，再開啟檔案讀出
#res = requests.get(url)
#open('data.csv','wb').write(res.content)
#df=pd.read_csv('data.csv')
#方法2:直接讀取網站的檔案
df=pd.read_csv(url)
#查看有那些欄位
df.info()
#只保留SiteName、County、AQI、Status四個欄位
df.drop(['SiteId','Longitude','Latitude','PublishTime','SO2_AVG', 'Pollutant', 'SO2', 'CO', 'NO', 'CO_8hr', 'O3', 'O3_8hr', 'PM10', 'PM10_AVG', 'PM2.5', 'PM2.5_AVG', 'NO2', 'NOx', 'WindSpeed', 'WindDirec'],inplace=True,axis=1)
#設定過濾條件
indexNames=df[df['County']!=county].index
#刪除所有不是臺北市的偵測站
df.drop(indexNames,inplace=True)
#重設索引值
df=df.reset_index(drop=True)
#列出該縣市所有偵測站狀態
print(county,"空氣品質狀態")
for i in range(len(df)):
  print(df.loc[i,'SiteName'],'(',df.loc[i,'Status'],")")
indexNames=df[df['Status']=='良好'].index
df.drop(indexNames,inplace=True)
#重設索引值
df=df.reset_index(drop=True)
#列出該縣市所有為達良好之偵測站
print()
print(county,"空氣品質未達良好之偵測站")
for i in range(len(df)):
  print(df.loc[i,'SiteName'],'(',df.loc[i,'Status'],")")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SiteName     84 non-null     object
#  1   County       84 non-null     object
#  2   AQI          84 non-null     int64
#  3   Pollutant    42 non-null     object
#  4   Status       84 non-null     object
#  5   SO2          83 non-null     float64
#  6   CO           84 non-null     object
#  7   CO_8hr       84 non-null     object
#  8   O3           84 non-null     float64
#  9   O3_8hr       84 non-null     int64
#  10  PM10         82 non-null     float64
#  11  PM2.5        84 non-null     int64
#  12  NO2          83 non-null     float64
#  13  NOx          83 non-null     float64
#  14  NO           83 non-null     float64
#  15  WindSpeed    84 non-null     object
#  16  WindDirec    84 non-null     object
#  17  PublishTime  84 non-null     object
#  18  PM2.5_AVG    84 non-null     int64
#  19  PM10_AVG     82 non-null     float64
#  20  SO2_AVG      84 non-null     int64
#  21  Longitude    84 non-null     float64
#  22  Latitude     84 non-null     float64
#  23  SiteId       84 non-null     int64
# dtypes: float64(9), int64(6), object(9)
# memory usage: 15.9+ KB
# 屏東縣 空氣品質狀態
# 屏東 ( 普通 )
# 潮州 ( 普通 )
# 恆春 ( 良好 )
# 屏東(琉球) ( 普通 )
# 屏東(建興) ( 普通 )
#
# 屏東縣 空氣品質未達良好之偵測站
# 屏東 ( 普通 )
# 潮州 ( 普通 )
# 屏東(琉球) ( 普通 )
# 屏東(建興) ( 普通 )
