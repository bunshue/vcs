# %%
#打開檔案
file1=open("Test.txt","w") 
#寫入文字(沒有換行)
file1.write("新課綱程式設計") 
#寫入文字(沒有換行)
file1.write("文科社會組") 
#寫入文字(有換行)
file1.write("\n新課綱程式設計") 
#寫入文字(有換行)
file1.write("\n文科社會組") 
#字串變數a
a="\n新課綱程式設計" 
#寫入字串變數內容(有換行)
file1.write(a) 
#字串變數b
b="\n文科社會組" 
#寫入字串變數內容(有換行)
file1.write(b) 
#關閉檔案
file1.close()
