# %%
#產生元組方法1
tuple1=1,2,3
print(tuple1)
#產生元組方法2
tuple2=(1,2,3)
print(tuple2)
#列出元組元素
print(tuple2[0])
#元組轉串列
list1=list(tuple1)
print(list1)
#列出串列元素
print(list1[0])
#串列轉元組
tuple3=tuple(list1)
print(tuple3)
a=3
b=4
print(a,b)
#利用重新設定定元組達成兩數交換的目的
a,b=b,a
print(a,b)
