# %%
from sklearn.feature_extraction.text import  CountVectorizer
from sklearn.preprocessing import Normalizer
from sklearn.decomposition import TruncatedSVD

import numpy
import pandas as pd

# %%
corpus = ["Python is popular in machine learning",
         "Distributed system is important in big data analysis",
        "Machine learning is theoretical foundation of data mining",
        "Learning Python is fun",
        "Playing soccer is fun",
        "Many data scientists like playing soccer",
        "Chinese men's soccer team failed again",
        "Thirty two soccer teams enter World Cup finals"]

vectorizer = CountVectorizer(min_df=1, stop_words="english")
data = vectorizer.fit_transform(corpus)
vectorizer.get_feature_names()

pd.DataFrame(data.toarray(), index=corpus, columns=vectorizer.get_feature_names()).head(10)
# Out:
#                                                     analysis  big  chinese  \
# Python is popular in machine learning                      0    0        0
# Distributed system is important in big data ana...         1    1        0
# Machine learning is theoretical foundation of d...         0    0        0
# Learning Python is fun                                     0    0        0
# Playing soccer is fun                                      0    0        0
# Many data scientists like playing soccer                   0    0        0
# Chinese men's soccer team failed again                     0    0        1
# Thirty two soccer teams enter World Cup finals             0    0        0
#
#                                                     cup  data  distributed  \
# Python is popular in machine learning                 0     0            0
# Distributed system is important in big data ana...    0     1            1
# Machine learning is theoretical foundation of d...    0     1            0
# Learning Python is fun                                0     0            0
# Playing soccer is fun                                 0     0            0
# Many data scientists like playing soccer              0     1            0
# Chinese men's soccer team failed again                0     0            0
# Thirty two soccer teams enter World Cup finals        1     0            0
#
#                                                     enter  failed  finals  \
# Python is popular in machine learning                   0       0       0
# Distributed system is important in big data ana...      0       0       0
# Machine learning is theoretical foundation of d...      0       0       0
# Learning Python is fun                                  0       0       0
# Playing soccer is fun                                   0       0       0
# Many data scientists like playing soccer                0       0       0
# Chinese men's soccer team failed again                  0       1       0
# Thirty two soccer teams enter World Cup finals          1       0       1
#
#                                                     foundation  ...    \
# Python is popular in machine learning                        0  ...
# Distributed system is important in big data ana...           0  ...
# Machine learning is theoretical foundation of d...           1  ...
# Learning Python is fun                                       0  ...
# Playing soccer is fun                                        0  ...
# Many data scientists like playing soccer                     0  ...
# Chinese men's soccer team failed again                       0  ...
# Thirty two soccer teams enter World Cup finals               0  ...
#
#                                                     playing  popular  python  \
# Python is popular in machine learning                     0        1       1
# Distributed system is important in big data ana...        0        0       0
# Machine learning is theoretical foundation of d...        0        0       0
# Learning Python is fun                                    0        0       1
# Playing soccer is fun                                     1        0       0
# Many data scientists like playing soccer                  1        0       0
# Chinese men's soccer team failed again                    0        0       0
# Thirty two soccer teams enter World Cup finals            0        0       0
#
#                                                     scientists  soccer  team  \
# Python is popular in machine learning                        0       0     0
# Distributed system is important in big data ana...           0       0     0
# Machine learning is theoretical foundation of d...           0       0     0
# Learning Python is fun                                       0       0     0
# Playing soccer is fun                                        0       1     0
# Many data scientists like playing soccer                     1       1     0
# Chinese men's soccer team failed again                       0       1     1
# Thirty two soccer teams enter World Cup finals               0       1     0
#
#                                                     teams  theoretical  \
# Python is popular in machine learning                   0            0
# Distributed system is important in big data ana...      0            0
# Machine learning is theoretical foundation of d...      0            1
# Learning Python is fun                                  0            0
# Playing soccer is fun                                   0            0
# Many data scientists like playing soccer                0            0
# Chinese men's soccer team failed again                  0            0
# Thirty two soccer teams enter World Cup finals          1            0
#
#                                                     thirty  world
# Python is popular in machine learning                    0      0
# Distributed system is important in big data ana...       0      0
# Machine learning is theoretical foundation of d...       0      0
# Learning Python is fun                                   0      0
# Playing soccer is fun                                    0      0
# Many data scientists like playing soccer                 0      0
# Chinese men's soccer team failed again                   0      0
# Thirty two soccer teams enter World Cup finals           1      1
#
# [8 rows x 27 columns]

# %%
"""Singular value decomposition and LSA"""
model = TruncatedSVD(2)

data_n = model.fit_transform(data)
data_n = Normalizer(copy=False).fit_transform(data_n)
data_n
# Out:
# array([[ 0.50851054,  0.86105576],
#        [ 0.81777683,  0.57553546],
#        [ 0.60883014,  0.79330061],
#        [ 0.62372804,  0.78164144],
#        [ 0.91874886, -0.39484242],
#        [ 0.98024768, -0.19777381],
#        [ 0.78731953, -0.61654518],
#        [ 0.71694817, -0.69712648]])

# %%
pd.DataFrame(data_n, index = corpus, columns = ["component_1", "component_2"])
# Out:
#                                                     component_1  component_2
# Python is popular in machine learning                  0.508511     0.861056
# Distributed system is important in big data ana...     0.817777     0.575535
# Machine learning is theoretical foundation of d...     0.608830     0.793301
# Learning Python is fun                                 0.623728     0.781641
# Playing soccer is fun                                  0.918749    -0.394842
# Many data scientists like playing soccer               0.980248    -0.197774
# Chinese men's soccer team failed again                 0.787320    -0.616545
# Thirty two soccer teams enter World Cup finals         0.716948    -0.697126

# %%
xs = data_n[:,0]
ys = data_n[:,1]
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.figure(figsize=(4,4))
ax = plt.gca()
ax.set_xlim([-1, 2])
ax.set_ylim([-1, 2])
plt.scatter(xs, ys)
plt.xlabel('First principal component')
plt.ylabel('Second principal component')
plt.title('Plot of points agains LSA principal components')
plt.show()
# Out:
# backend module://ipykernel.pylab.backend_inline version unknown

# %%
similarity = numpy.asarray(numpy.asmatrix(data_n) * numpy.asmatrix(data_n).T)
pd.DataFrame(similarity, index = corpus, columns = corpus).head(10)
# Out:
#                                                     Python is popular in machine learning  \
# Python is popular in machine learning                                            1.000000
# Distributed system is important in big data anl...                               0.911416
# Machine learning is theoretical foundation of d...                               0.992673
# Learning Python is fun                                                           0.990209
# Playing soccer is fun                                                            0.127212
# Many data scientists like playing soccer                                         0.328172
# Chinese men's soccer team failed again                                          -0.130519
# Thirty two soccer teams enter World Cup finals                                  -0.235689
#
#                                                     Distributed system is important in big data anlaysis  \
# Python is popular in machine learning                                                        0.911416
# Distributed system is important in big data anl...                                           1.000000
# Machine learning is theoretical foundation of d...                                           0.954460
# Learning Python is fun                                                                       0.959933
# Playing soccer is fun                                                                        0.524086
# Many data scientists like playing soccer                                                     0.687798
# Chinese men's soccer team failed again                                                       0.289008
# Thirty two soccer teams enter World Cup finals                                               0.185083
#
#                                                     Machine learning is theoretical foundation of data minng  \
# Python is popular in machine learning                                                        0.992673
# Distributed system is important in big data anl...                                           0.954460
# Machine learning is theoretical foundation of d...                                           1.000000
# Learning Python is fun                                                                       0.999821
# Playing soccer is fun                                                                        0.246133
# Many data scientists like playing soccer                                                     0.439910
# Chinese men's soccer team failed again                                                      -0.009762
# Thirty two soccer teams enter World Cup finals                                              -0.116531
#
#                                                     Learning Python is fun  \
# Python is popular in machine learning                             0.990209
# Distributed system is important in big data anl...                0.959933
# Machine learning is theoretical foundation of d...                0.999821
# Learning Python is fun                                            1.000000
# Playing soccer is fun                                             0.264424
# Many data scientists like playing soccer                          0.456820
# Chinese men's soccer team failed again                            0.009156
# Thirty two soccer teams enter World Cup finals                   -0.097722
#
#                                                     Playing soccer is fun  \
# Python is popular in machine learning                            0.127212
# Distributed system is important in big data anl...               0.524086
# Machine learning is theoretical foundation of d...               0.246133
# Learning Python is fun                                           0.264424
# Playing soccer is fun                                            1.000000
# Many data scientists like playing soccer                         0.978691
# Chinese men's soccer team failed again                           0.966787
# Thirty two soccer teams enter World Cup finals                   0.933950
#
#                                                     Many data scientists like playing soccer  \
# Python is popular in machine learning                                               0.328172
# Distributed system is important in big data anl...                                  0.687798
# Machine learning is theoretical foundation of d...                                  0.439910
# Learning Python is fun                                                              0.456820
# Playing soccer is fun                                                               0.978691
# Many data scientists like playing soccer                                            1.000000
# Chinese men's soccer team failed again                                              0.893705
# Thirty two soccer teams enter World Cup finals                                      0.840660
#
#                                                     Chinese men's soccer team failed again  \
# Python is popular in machine learning                                            -0.130519
# Distributed system is important in big data anl...                                0.289008
# Machine learning is theoretical foundation of d...                               -0.009762
# Learning Python is fun                                                            0.009156
# Playing soccer is fun                                                             0.966787
# Many data scientists like playing soccer                                          0.893705
# Chinese men's soccer team failed again                                            1.000000
# Thirty two soccer teams enter World Cup finals                                    0.994277
#
#                                                     Thirty two soccer teams enter World Cup finals
# Python is popular in machine learning                                                    -0.235689
# Distributed system is important in big data anl...                                        0.185083
# Machine learning is theoretical foundation of d...                                       -0.116531
# Learning Python is fun                                                                   -0.097722
# Playing soccer is fun                                                                     0.933950
# Many data scientists like playing soccer                                                  0.840660
# Chinese men's soccer team failed again                                                    0.994277
# Thirty two soccer teams enter World Cup finals                                            1.000000

# %%
sns.heatmap(similarity,cmap='Reds')
