# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
# %matplotlib inline

plt.style.use('bmh')
colors = ['#A60628','#467821']
plt.cmap = matplotlib.colors.ListedColormap(colors)

matplotlib.rcParams['figure.figsize'] = (10.0, 6.0) 
 
np.random.seed(3)
num_pos = 500
 
# Bivariate normal distribution mean [0, 0] [0.5, 4], with a covariance matrix
subset1 = np.random.multivariate_normal([0, 0], [[1, 0.6],[0.6, 1]], num_pos)
subset2 = np.random.multivariate_normal([0.5, 4], [[1, 0.6],[0.6, 1]], num_pos)
 
X = np.vstack((subset1, subset2))
y = np.hstack((np.zeros(num_pos), np.ones(num_pos)))
 
plt.scatter(X[:, 0], X[:, 1], c=y,cmap=plt.cmap,marker='o',s=40)
plt.show()

# %%
from sklearn import linear_model
clf = linear_model.LogisticRegression()
clf.fit(X, y)
print(clf.intercept_, clf.coef_, clf.classes_)
# Out:
# (array([-5.7268742]), array([[-1.43492343,  3.15471817]]), array([0., 1.]))

# %%
y_pred = clf.predict(X)
print y_pred.shape
print np.sum(y_pred.reshape(-1,1)==y.reshape(-1,1))*1.0/len(y)
# Out:
# (1000L,)
# 0.99

# %%
from sklearn.metrics import confusion_matrix
print confusion_matrix(y,y_pred)

sns.heatmap(confusion_matrix(y,y_pred))
# Out:
# [[495   5]
#  [  5 495]]

# %%
#绘制分类边界
plt.style.use('bmh')
def plot_decision_boundary(pred_func, X, y, title):
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    h = 0.01
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole grid (get class for each grid point)
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # print(Z)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z,alpha=0.3)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=40, alpha=0.8,cmap=plt.cmap)
    plt.title(title)
    plt.show()
 
# run on the training dataset with predict function
plot_decision_boundary(lambda x: clf.predict(x), X, y, "logistic regression prediction")
# Out:
# d:\Anaconda2\lib\site-packages\numpy\ma\core.py:6442: MaskedArrayFutureWarning: In the future the default for ma.maximum.reduce will be axis=0, not the current None, to match np.maximum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
# d:\Anaconda2\lib\site-packages\numpy\ma\core.py:6442: MaskedArrayFutureWarning: In the future the default for ma.minimum.reduce will be axis=0, not the current None, to match np.minimum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
def log_likelihood(X, y, theta):
    scores = np.dot(X, theta)
    ll = np.sum(  y * scores - np.log(1 + np.exp(scores)) )
    return ll

# %%
def logistic_regression(X,y,l_rate,iterations,add_intercept = True):
    
    if add_intercept:
        intercept = np.ones((X.shape[0], 1))
        X = np.hstack((intercept, X))
        
     
    theta = np.zeros(X.shape[1]).reshape(-1,1)
    y=y.reshape(-1,1)
    accu_history = [0] * iterations
    ll_history = [0.0] * iterations
    for epoch in range(iterations):
        x_theta = np.dot(X, theta)
        y_hat = sigmoid(x_theta)
        error = y  - y_hat 
        gradient = np.dot(X.T, error)
        theta = theta + l_rate*gradient
        preds = np.round( y_hat )      
        
        accu = np.sum(preds==y)*1.0/len(y)
        accu_history[epoch]=accu

    
        if( epoch % 5 == 0):
            print("After iter {}; accuracy: {}".format(epoch +1,  accu))
    return theta,accu_history

# %%
theta,accu = logistic_regression(X,y,1,2000)
# Out:
# After iter 1; accuracy: 0.5
# After iter 6; accuracy: 0.985
# After iter 11; accuracy: 0.99
# After iter 16; accuracy: 0.989
# After iter 21; accuracy: 0.989
# After iter 26; accuracy: 0.989
# After iter 31; accuracy: 0.989
# After iter 36; accuracy: 0.989
# After iter 41; accuracy: 0.989
# After iter 46; accuracy: 0.989
# After iter 51; accuracy: 0.988
# After iter 56; accuracy: 0.988
# After iter 61; accuracy: 0.988
# After iter 66; accuracy: 0.988
# After iter 71; accuracy: 0.988
# After iter 76; accuracy: 0.988
# After iter 81; accuracy: 0.988
# After iter 86; accuracy: 0.988
# After iter 91; accuracy: 0.988
# After iter 96; accuracy: 0.988
# After iter 101; accuracy: 0.988
# After iter 106; accuracy: 0.988
# After iter 111; accuracy: 0.988
# After iter 116; accuracy: 0.988
# After iter 121; accuracy: 0.988
# After iter 126; accuracy: 0.988
# After iter 131; accuracy: 0.988
# After iter 136; accuracy: 0.988
# After iter 141; accuracy: 0.988
# After iter 146; accuracy: 0.988
# After iter 151; accuracy: 0.988
# After iter 156; accuracy: 0.988
# After iter 161; accuracy: 0.988
# After iter 166; accuracy: 0.988
# After iter 171; accuracy: 0.988
# After iter 176; accuracy: 0.988
# After iter 181; accuracy: 0.988
# After iter 186; accuracy: 0.988
# After iter 191; accuracy: 0.988
# After iter 196; accuracy: 0.988
# After iter 201; accuracy: 0.988
# After iter 206; accuracy: 0.988
# After iter 211; accuracy: 0.988
# After iter 216; accuracy: 0.988
# After iter 221; accuracy: 0.988
# After iter 226; accuracy: 0.988
# After iter 231; accuracy: 0.989
# After iter 236; accuracy: 0.988
# After iter 241; accuracy: 0.989
# After iter 246; accuracy: 0.988
# After iter 251; accuracy: 0.989
# After iter 256; accuracy: 0.988
# After iter 261; accuracy: 0.989
# After iter 266; accuracy: 0.988
# After iter 271; accuracy: 0.989
# After iter 276; accuracy: 0.988
# After iter 281; accuracy: 0.989
# After iter 286; accuracy: 0.988
# After iter 291; accuracy: 0.989
# After iter 296; accuracy: 0.988
# After iter 301; accuracy: 0.989
# After iter 306; accuracy: 0.988
# After iter 311; accuracy: 0.989
# After iter 316; accuracy: 0.988
# After iter 321; accuracy: 0.989
# After iter 326; accuracy: 0.988
# After iter 331; accuracy: 0.989
# After iter 336; accuracy: 0.988
# After iter 341; accuracy: 0.989
# After iter 346; accuracy: 0.988
# After iter 351; accuracy: 0.989
# After iter 356; accuracy: 0.988
# After iter 361; accuracy: 0.989
# After iter 366; accuracy: 0.988
# After iter 371; accuracy: 0.989
# After iter 376; accuracy: 0.988
# After iter 381; accuracy: 0.989
# After iter 386; accuracy: 0.988
# After iter 391; accuracy: 0.989
# After iter 396; accuracy: 0.987
# After iter 401; accuracy: 0.989
# After iter 406; accuracy: 0.987
# After iter 411; accuracy: 0.989
# After iter 416; accuracy: 0.987
# After iter 421; accuracy: 0.989
# After iter 426; accuracy: 0.987
# After iter 431; accuracy: 0.989
# After iter 436; accuracy: 0.987
# After iter 441; accuracy: 0.99
# After iter 446; accuracy: 0.987
# After iter 451; accuracy: 0.99
# After iter 456; accuracy: 0.987
# After iter 461; accuracy: 0.99
# After iter 466; accuracy: 0.987
# After iter 471; accuracy: 0.99
# After iter 476; accuracy: 0.987
# After iter 481; accuracy: 0.99
# After iter 486; accuracy: 0.987
# After iter 491; accuracy: 0.99
# After iter 496; accuracy: 0.987
# After iter 501; accuracy: 0.99
# After iter 506; accuracy: 0.987
# After iter 511; accuracy: 0.99
# After iter 516; accuracy: 0.987
# After iter 521; accuracy: 0.981
# After iter 526; accuracy: 0.738
# After iter 531; accuracy: 0.936
# After iter 536; accuracy: 0.987
# After iter 541; accuracy: 0.987
# After iter 546; accuracy: 0.988
# After iter 551; accuracy: 0.988
# After iter 556; accuracy: 0.988
# After iter 561; accuracy: 0.988
# After iter 566; accuracy: 0.988
# After iter 571; accuracy: 0.988
# After iter 576; accuracy: 0.988
# After iter 581; accuracy: 0.988
# After iter 586; accuracy: 0.988
# After iter 591; accuracy: 0.988
# After iter 596; accuracy: 0.988
# After iter 601; accuracy: 0.988
# After iter 606; accuracy: 0.988
# After iter 611; accuracy: 0.988
# After iter 616; accuracy: 0.988
# After iter 621; accuracy: 0.988
# After iter 626; accuracy: 0.988
# After iter 631; accuracy: 0.988
# After iter 636; accuracy: 0.988
# After iter 641; accuracy: 0.988
# After iter 646; accuracy: 0.988
# After iter 651; accuracy: 0.988
# After iter 656; accuracy: 0.988
# After iter 661; accuracy: 0.988
# After iter 666; accuracy: 0.988
# After iter 671; accuracy: 0.988
# After iter 676; accuracy: 0.988
# After iter 681; accuracy: 0.988
# After iter 686; accuracy: 0.988
# After iter 691; accuracy: 0.988
# After iter 696; accuracy: 0.988
# After iter 701; accuracy: 0.988
# After iter 706; accuracy: 0.988
# After iter 711; accuracy: 0.988
# After iter 716; accuracy: 0.988
# After iter 721; accuracy: 0.988
# After iter 726; accuracy: 0.988
# After iter 731; accuracy: 0.988
# After iter 736; accuracy: 0.988
# After iter 741; accuracy: 0.988
# After iter 746; accuracy: 0.988
# After iter 751; accuracy: 0.988
# After iter 756; accuracy: 0.988
# After iter 761; accuracy: 0.988
# After iter 766; accuracy: 0.988
# After iter 771; accuracy: 0.988
# After iter 776; accuracy: 0.988
# After iter 781; accuracy: 0.988
# After iter 786; accuracy: 0.988
# After iter 791; accuracy: 0.988
# After iter 796; accuracy: 0.988
# After iter 801; accuracy: 0.988
# After iter 806; accuracy: 0.988
# After iter 811; accuracy: 0.988
# After iter 816; accuracy: 0.988
# After iter 821; accuracy: 0.988
# After iter 826; accuracy: 0.988
# After iter 831; accuracy: 0.988
# After iter 836; accuracy: 0.988
# After iter 841; accuracy: 0.988
# After iter 846; accuracy: 0.988
# After iter 851; accuracy: 0.988
# After iter 856; accuracy: 0.988
# After iter 861; accuracy: 0.988
# After iter 866; accuracy: 0.988
# After iter 871; accuracy: 0.988
# After iter 876; accuracy: 0.988
# After iter 881; accuracy: 0.988
# After iter 886; accuracy: 0.988
# After iter 891; accuracy: 0.988
# After iter 896; accuracy: 0.988
# After iter 901; accuracy: 0.988
# After iter 906; accuracy: 0.988
# After iter 911; accuracy: 0.988
# After iter 916; accuracy: 0.988
# After iter 921; accuracy: 0.988
# After iter 926; accuracy: 0.988
# After iter 931; accuracy: 0.988
# After iter 936; accuracy: 0.988
# After iter 941; accuracy: 0.988
# After iter 946; accuracy: 0.988
# After iter 951; accuracy: 0.988
# After iter 956; accuracy: 0.988
# After iter 961; accuracy: 0.988
# After iter 966; accuracy: 0.988
# After iter 971; accuracy: 0.988
# After iter 976; accuracy: 0.988
# After iter 981; accuracy: 0.988
# After iter 986; accuracy: 0.988
# After iter 991; accuracy: 0.988
# After iter 996; accuracy: 0.988
# After iter 1001; accuracy: 0.988
# After iter 1006; accuracy: 0.988
# After iter 1011; accuracy: 0.988
# After iter 1016; accuracy: 0.988
# After iter 1021; accuracy: 0.988
# After iter 1026; accuracy: 0.988
# After iter 1031; accuracy: 0.988
# After iter 1036; accuracy: 0.988
# After iter 1041; accuracy: 0.988
# After iter 1046; accuracy: 0.988
# After iter 1051; accuracy: 0.988
# After iter 1056; accuracy: 0.988
# After iter 1061; accuracy: 0.988
# After iter 1066; accuracy: 0.988
# After iter 1071; accuracy: 0.988
# After iter 1076; accuracy: 0.988
# After iter 1081; accuracy: 0.988
# After iter 1086; accuracy: 0.988
# After iter 1091; accuracy: 0.988
# After iter 1096; accuracy: 0.988
# After iter 1101; accuracy: 0.988
# After iter 1106; accuracy: 0.988
# After iter 1111; accuracy: 0.988
# After iter 1116; accuracy: 0.988
# After iter 1121; accuracy: 0.988
# After iter 1126; accuracy: 0.988
# After iter 1131; accuracy: 0.988
# After iter 1136; accuracy: 0.988
# After iter 1141; accuracy: 0.988
# After iter 1146; accuracy: 0.988
# After iter 1151; accuracy: 0.988
# After iter 1156; accuracy: 0.988
# After iter 1161; accuracy: 0.988
# After iter 1166; accuracy: 0.988
# After iter 1171; accuracy: 0.988
# After iter 1176; accuracy: 0.988
# After iter 1181; accuracy: 0.988
# After iter 1186; accuracy: 0.988
# After iter 1191; accuracy: 0.988
# After iter 1196; accuracy: 0.988
# After iter 1201; accuracy: 0.988
# After iter 1206; accuracy: 0.988
# After iter 1211; accuracy: 0.988
# After iter 1216; accuracy: 0.988
# After iter 1221; accuracy: 0.988
# After iter 1226; accuracy: 0.988
# After iter 1231; accuracy: 0.988
# After iter 1236; accuracy: 0.988
# After iter 1241; accuracy: 0.988
# After iter 1246; accuracy: 0.988
# After iter 1251; accuracy: 0.988
# After iter 1256; accuracy: 0.988
# After iter 1261; accuracy: 0.988
# After iter 1266; accuracy: 0.988
# After iter 1271; accuracy: 0.988
# After iter 1276; accuracy: 0.989
# After iter 1281; accuracy: 0.988
# After iter 1286; accuracy: 0.989
# After iter 1291; accuracy: 0.988
# After iter 1296; accuracy: 0.989
# After iter 1301; accuracy: 0.988
# After iter 1306; accuracy: 0.989
# After iter 1311; accuracy: 0.988
# After iter 1316; accuracy: 0.989
# After iter 1321; accuracy: 0.988
# After iter 1326; accuracy: 0.989
# After iter 1331; accuracy: 0.988
# After iter 1336; accuracy: 0.989
# After iter 1341; accuracy: 0.988
# After iter 1346; accuracy: 0.989
# After iter 1351; accuracy: 0.988
# After iter 1356; accuracy: 0.989
# After iter 1361; accuracy: 0.988
# After iter 1366; accuracy: 0.989
# After iter 1371; accuracy: 0.988
# After iter 1376; accuracy: 0.989
# After iter 1381; accuracy: 0.988
# After iter 1386; accuracy: 0.989
# After iter 1391; accuracy: 0.988
# After iter 1396; accuracy: 0.989
# After iter 1401; accuracy: 0.988
# After iter 1406; accuracy: 0.989
# After iter 1411; accuracy: 0.988
# After iter 1416; accuracy: 0.989
# After iter 1421; accuracy: 0.988
# After iter 1426; accuracy: 0.989
# After iter 1431; accuracy: 0.988
# After iter 1436; accuracy: 0.989
# After iter 1441; accuracy: 0.987
# After iter 1446; accuracy: 0.989
# After iter 1451; accuracy: 0.987
# After iter 1456; accuracy: 0.989
# After iter 1461; accuracy: 0.987
# After iter 1466; accuracy: 0.989
# After iter 1471; accuracy: 0.987
# After iter 1476; accuracy: 0.989
# After iter 1481; accuracy: 0.987
# After iter 1486; accuracy: 0.99
# After iter 1491; accuracy: 0.987
# After iter 1496; accuracy: 0.99
# After iter 1501; accuracy: 0.987
# After iter 1506; accuracy: 0.99
# After iter 1511; accuracy: 0.987
# After iter 1516; accuracy: 0.99
# After iter 1521; accuracy: 0.987
# After iter 1526; accuracy: 0.99
# After iter 1531; accuracy: 0.987
# After iter 1536; accuracy: 0.99
# After iter 1541; accuracy: 0.987
# After iter 1546; accuracy: 0.99
# After iter 1551; accuracy: 0.987
# After iter 1556; accuracy: 0.99
# After iter 1561; accuracy: 0.987
# After iter 1566; accuracy: 0.988
# After iter 1571; accuracy: 0.924
# After iter 1576; accuracy: 0.774
# After iter 1581; accuracy: 0.968
# After iter 1586; accuracy: 0.989
# After iter 1591; accuracy: 0.989
# After iter 1596; accuracy: 0.989
# After iter 1601; accuracy: 0.989
# After iter 1606; accuracy: 0.988
# After iter 1611; accuracy: 0.988
# After iter 1616; accuracy: 0.988
# After iter 1621; accuracy: 0.988
# After iter 1626; accuracy: 0.988
# After iter 1631; accuracy: 0.988
# After iter 1636; accuracy: 0.988
# After iter 1641; accuracy: 0.988
# After iter 1646; accuracy: 0.988
# After iter 1651; accuracy: 0.988
# After iter 1656; accuracy: 0.988
# After iter 1661; accuracy: 0.988
# After iter 1666; accuracy: 0.988
# After iter 1671; accuracy: 0.988
# After iter 1676; accuracy: 0.988
# After iter 1681; accuracy: 0.988
# After iter 1686; accuracy: 0.988
# After iter 1691; accuracy: 0.988
# After iter 1696; accuracy: 0.988
# After iter 1701; accuracy: 0.988
# After iter 1706; accuracy: 0.988
# After iter 1711; accuracy: 0.988
# After iter 1716; accuracy: 0.988
# After iter 1721; accuracy: 0.988
# After iter 1726; accuracy: 0.988
# After iter 1731; accuracy: 0.988
# After iter 1736; accuracy: 0.988
# After iter 1741; accuracy: 0.988
# After iter 1746; accuracy: 0.988
# After iter 1751; accuracy: 0.988
# After iter 1756; accuracy: 0.988
# After iter 1761; accuracy: 0.988
# After iter 1766; accuracy: 0.988
# After iter 1771; accuracy: 0.988
# After iter 1776; accuracy: 0.988
# After iter 1781; accuracy: 0.988
# After iter 1786; accuracy: 0.988
# After iter 1791; accuracy: 0.988
# After iter 1796; accuracy: 0.988
# After iter 1801; accuracy: 0.988
# After iter 1806; accuracy: 0.988
# After iter 1811; accuracy: 0.988
# After iter 1816; accuracy: 0.988
# After iter 1821; accuracy: 0.988
# After iter 1826; accuracy: 0.988
# After iter 1831; accuracy: 0.988
# After iter 1836; accuracy: 0.988
# After iter 1841; accuracy: 0.988
# After iter 1846; accuracy: 0.988
# After iter 1851; accuracy: 0.988
# After iter 1856; accuracy: 0.988
# After iter 1861; accuracy: 0.988
# After iter 1866; accuracy: 0.988
# After iter 1871; accuracy: 0.988
# After iter 1876; accuracy: 0.988
# After iter 1881; accuracy: 0.988
# After iter 1886; accuracy: 0.988
# After iter 1891; accuracy: 0.988
# After iter 1896; accuracy: 0.988
# After iter 1901; accuracy: 0.988
# After iter 1906; accuracy: 0.988
# After iter 1911; accuracy: 0.988
# After iter 1916; accuracy: 0.988
# After iter 1921; accuracy: 0.988
# After iter 1926; accuracy: 0.988
# After iter 1931; accuracy: 0.988
# After iter 1936; accuracy: 0.988
# After iter 1941; accuracy: 0.988
# After iter 1946; accuracy: 0.988
# After iter 1951; accuracy: 0.988
# After iter 1956; accuracy: 0.988
# After iter 1961; accuracy: 0.988
# After iter 1966; accuracy: 0.988
# After iter 1971; accuracy: 0.988
# After iter 1976; accuracy: 0.988
# After iter 1981; accuracy: 0.988
# After iter 1986; accuracy: 0.988
# After iter 1991; accuracy: 0.988
# After iter 1996; accuracy: 0.988

# %%
theta
# Out:
# array([[-599.88926069],
#        [-181.5414528 ],
#        [ 328.95859873]])

# %%
accu
# Out:
# [0.5,
#  0.734,
#  0.799,
#  0.897,
#  0.967,
#  0.985,
#  0.988,
#  0.99,
#  0.99,
#  0.99,
#  0.99,
#  0.989,
#  0.989,
#  0.989,
#  0.989,
#  0.989,
#  0.989,
#  0.989,
#  0.989,
#  0.989]
