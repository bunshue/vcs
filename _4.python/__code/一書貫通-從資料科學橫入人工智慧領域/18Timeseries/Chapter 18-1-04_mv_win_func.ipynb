# %% [markdown]
# # 时间序列数据统计—滑动窗口

# %% [markdown]
# ## 窗口函数

# %%
import pandas as pd
import numpy as np

ser_obj = pd.Series(np.random.randn(1000), 
                    index=pd.date_range('20170101', periods=1000))
ser_obj_c = ser_obj.cumsum()
print(ser_obj.head())
# Out:
# 2017-01-01   -0.155538
# 2017-01-02    1.758112
# 2017-01-03   -0.783311
# 2017-01-04   -0.867679
# 2017-01-05    0.199064
# Freq: D, dtype: float64

# %%
# ?ser_obj.cumsum

# %%
print(ser_obj_c.head())
# Out:
# 2017-01-01   -0.155538
# 2017-01-02    1.602575
# 2017-01-03    0.819264
# 2017-01-04   -0.048415
# 2017-01-05    0.150650
# Freq: D, dtype: float64

# %%
r_obj = ser_obj.rolling(window=5)
print(r_obj)
# Out:
# Rolling [window=5,center=False,axis=0]

# %%
print(r_obj.mean())

# 验证：
# 前5个数据的均值
# print(ser_obj[0:5].mean())

# 1-6个数据的均值
# print(ser_obj[1:6].mean())
# Out:
# 2017-01-01          NaN
# 2017-01-02          NaN
# 2017-01-03          NaN
# 2017-01-04          NaN
# 2017-01-05     2.611688
# 2017-01-06     3.003956
# 2017-01-07     3.865358
# 2017-01-08     4.372358
# 2017-01-09     4.560945
# 2017-01-10     5.016164
# 2017-01-11     5.624272
# 2017-01-12     6.238922
# 2017-01-13     6.634693
# 2017-01-14     7.086889
# 2017-01-15     6.910070
# 2017-01-16     7.111327
# 2017-01-17     7.109422
# 2017-01-18     7.060062
# 2017-01-19     6.785338
# 2017-01-20     7.131506
# 2017-01-21     6.711244
# 2017-01-22     6.276579
# 2017-01-23     6.027026
# 2017-01-24     6.016312
# 2017-01-25     5.827490
# 2017-01-26     5.589399
# 2017-01-27     5.403508
# 2017-01-28     5.443616
# 2017-01-29     5.443827
# 2017-01-30     5.206693
#                 ...
# 2019-08-29   -17.146041
# 2019-08-30   -17.742543
# 2019-08-31   -17.577325
# 2019-09-01   -17.682518
# 2019-09-02   -17.766373
# 2019-09-03   -17.688098
# 2019-09-04   -17.576031
# 2019-09-05   -17.558658
# 2019-09-06   -17.346696
# 2019-09-07   -17.801064
# 2019-09-08   -18.205594
# 2019-09-09   -18.422849
# 2019-09-10   -18.893691
# 2019-09-11   -19.189014
# 2019-09-12   -18.765853
# 2019-09-13   -18.488670
# 2019-09-14   -18.175313
# 2019-09-15   -18.415255
# 2019-09-16   -18.823850
# 2019-09-17   -19.444853
# 2019-09-18   -19.759235
# 2019-09-19   -19.956240
# 2019-09-20   -19.637751
# 2019-09-21   -19.143481
# 2019-09-22   -18.717170
# 2019-09-23   -18.194239
# 2019-09-24   -17.650949
# 2019-09-25   -17.099883
# 2019-09-26   -17.017858
# 2019-09-27   -17.082079
# Freq: D, Length: 1000, dtype: float64

# %%
# 画图查看
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(15, 5))

ser_obj.plot(style='r--')
ser_obj.rolling(window=10).mean().plot(style='b')

# %%
print(ser_obj.rolling(window=5, center=True).mean())
# Out:
# 2017-01-01          NaN
# 2017-01-02          NaN
# 2017-01-03     2.611688
# 2017-01-04     3.003956
# 2017-01-05     3.865358
# 2017-01-06     4.372358
# 2017-01-07     4.560945
# 2017-01-08     5.016164
# 2017-01-09     5.624272
# 2017-01-10     6.238922
# 2017-01-11     6.634693
# 2017-01-12     7.086889
# 2017-01-13     6.910070
# 2017-01-14     7.111327
# 2017-01-15     7.109422
# 2017-01-16     7.060062
# 2017-01-17     6.785338
# 2017-01-18     7.131506
# 2017-01-19     6.711244
# 2017-01-20     6.276579
# 2017-01-21     6.027026
# 2017-01-22     6.016312
# 2017-01-23     5.827490
# 2017-01-24     5.589399
# 2017-01-25     5.403508
# 2017-01-26     5.443616
# 2017-01-27     5.443827
# 2017-01-28     5.206693
# 2017-01-29     5.389922
# 2017-01-30     5.164947
#                 ...
# 2019-08-29   -17.577325
# 2019-08-30   -17.682518
# 2019-08-31   -17.766373
# 2019-09-01   -17.688098
# 2019-09-02   -17.576031
# 2019-09-03   -17.558658
# 2019-09-04   -17.346696
# 2019-09-05   -17.801064
# 2019-09-06   -18.205594
# 2019-09-07   -18.422849
# 2019-09-08   -18.893691
# 2019-09-09   -19.189014
# 2019-09-10   -18.765853
# 2019-09-11   -18.488670
# 2019-09-12   -18.175313
# 2019-09-13   -18.415255
# 2019-09-14   -18.823850
# 2019-09-15   -19.444853
# 2019-09-16   -19.759235
# 2019-09-17   -19.956240
# 2019-09-18   -19.637751
# 2019-09-19   -19.143481
# 2019-09-20   -18.717170
# 2019-09-21   -18.194239
# 2019-09-22   -17.650949
# 2019-09-23   -17.099883
# 2019-09-24   -17.017858
# 2019-09-25   -17.082079
# 2019-09-26          NaN
# 2019-09-27          NaN
# Freq: D, Length: 1000, dtype: float64
