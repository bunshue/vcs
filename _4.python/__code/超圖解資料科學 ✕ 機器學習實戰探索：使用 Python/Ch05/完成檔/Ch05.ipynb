# %%
#資料檔路徑(資料檔：i_filepath，完成檔：o_filepath，內文說明檔：c_filepath)
filepath = '/content/MyGoogleDrive/My Drive/Colab Notebooks/Python-for-Titanic/Ch05/'
i_filepath = filepath 
o_filepath = filepath + '完成檔/'
c_filepath = filepath + '內文說明檔/'

# %% [markdown]
# # 5-1 資料視覺化的重要性

# %% [markdown]
# # (圖)-原始資料與視覺化圖形

# %%
from google.colab import drive
drive.mount('/content/MyGoogleDrive')
import pandas as pd
df=pd.read_csv(c_filepath + '圖5-1-年度銷售金額.csv')
df.index = df['AREA']
df=df.drop('AREA',axis=1)
df
# Out:
# Drive already mounted at /content/MyGoogleDrive; to attempt to forcibly remount, call drive.mount("/content/MyGoogleDrive", force_remount=True).
#         1st   2nd   3rd   4th
# AREA
# East   4522  2120  1200  3800
# West   3101  1846  2022  1900
# South  2111  2897  3200  2139
# North  4213   987   500  1568

# %%
df['1st'].plot(kind='pie', autopct='%.2f%%')

# %%
df.plot(kind='bar', rot=0)

# %% [markdown]
# # (圖)-圓餅圖比直條圖更能呈現各項資料所佔的比例

# %%
import pandas as pd
n=['Tom','Allen','Cathy','Jacky']
v=[1324,2514,5586,657]
df=pd.DataFrame()
df['name'] = n
df['vote'] = v
df
# Out:
#     name  vote
# 0    Tom  1324
# 1  Allen  2514
# 2  Cathy  5586
# 3  Jacky   657

# %%
df.index = df['name']
df['vote'].plot(kind='pie', autopct='%.0f%%')

# %%
df.plot(kind='bar', rot=0)

# %% [markdown]
# # 5-2 常見的資料視覺化圖表

# %% [markdown]
# # 5-2-1 愛看趨勢的折線圖

# %% [markdown]
# # (圖)-折線圖：不同月份參觀人數的統計趨勢圖

# %%
from google.colab import drive
drive.mount('/content/MyGoogleDrive')
import pandas as pd
df=pd.read_csv(c_filepath + '圖5-3-觀光人數統計.csv')
df.index = df['Month'] 
df[['Green Island', 'Guguan']].head()
# Out:
# Drive already mounted at /content/MyGoogleDrive; to attempt to forcibly remount, call drive.mount("/content/MyGoogleDrive", force_remount=True).
#        Green Island  Guguan
# Month
# 1              5872  151397
# 2             10210  151951
# 3             13213  127943
# 4             42587  147752
# 5             39920  108086

# %%
df[['Green Island', 'Guguan']].plot()

# %% [markdown]
# # 實作-繪製折線圖【EX5-2.1a.ipynb】

# %% [markdown]
# # Step 01

# %%
import pandas as pd
a = ['E','W','S','N']
m =[4522,3101,5211,4613]
s = pd.Series(m, index=a)
s
# Out:
# E    4522
# W    3101
# S    5211
# N    4613
# dtype: int64

# %% [markdown]
# # Step 02

# %%
s.plot()

# %% [markdown]
# # Step 03

# %%
from google.colab import drive
drive.mount('/content/MyGoogleDrive')
import pandas as pd
df=pd.read_csv(i_filepath + '觀光人數統計.csv')
df.index = df['Month'] #自定列索引為Month內容
df=df.drop('Month',axis=1) #刪除原本的月份行資料
df.head()
# Out:
# Drive already mounted at /content/MyGoogleDrive; to attempt to forcibly remount, call drive.mount("/content/MyGoogleDrive", force_remount=True).
#        Green Island  Guguan  National Museum
# Month
# 1              5872  151397            40988
# 2             10210  151951            82165
# 3             13213  127943            50683
# 4             42587  147752            83679
# 5             39920  108086            66842

# %% [markdown]
# # Step 04

# %%
df.plot()

# %% [markdown]
# # (圖)-圖表各元件名稱

# %%
df.plot(linewidth=2, linestyle=':', title='Number of visitors')

# %%
df.head()
# Out:
#        Green Island  Guguan  National Museum
# Month
# 1              5872  151397            40988
# 2             10210  151951            82165
# 3             13213  127943            50683
# 4             42587  147752            83679
# 5             39920  108086            66842

# %% [markdown]
# # 加廣知識：自定列索引

# %%
import pandas as pd
a = ['E','W','S','N']
m =[4522,3101,5211,4613]
s = pd.Series(m, index=a)
s
# Out:
# E    4522
# W    3101
# S    5211
# N    4613
# dtype: int64

# %%
s.plot()

# %%
s.index = ['EAST','WEST','SOUTH','NORTH']
s
# Out:
# EAST     4522
# WEST     3101
# SOUTH    5211
# NORTH    4613
# dtype: int64

# %%
s.plot()

# %%
df.head()
# Out:
#        Green Island  Guguan  National Museum
# Month
# 1              5872  151397            40988
# 2             10210  151951            82165
# 3             13213  127943            50683
# 4             42587  147752            83679
# 5             39920  108086            66842

# %%
df_T = df.T
df_T.head()
# Out:
# Month                1       2       3       4   ...      9       10      11      12
# Green Island       5872   10210   13213   42587  ...   26671   21745   11525   10294
# Guguan           151397  151951  127943  147752  ...  134118  129351  144019  205617
# National Museum   40988   82165   50683   83679  ...   67488   66921   50670   64738
#
# [3 rows x 12 columns]

# %% [markdown]
# # 實作-折線圖(部份資料框)【EX5-2.1b.ipynb】

# %% [markdown]
# # Step 01

# %%
df1=df['Green Island']
df1.head()
# Out:
# Month
# 1     5872
# 2    10210
# 3    13213
# 4    42587
# 5    39920
# Name: Green Island, dtype: int64

# %% [markdown]
# # Step 02

# %%
df1.plot()

# %% [markdown]
# # Step 03

# %%
df2=df[['Green Island','Guguan']]
df2.head()
# Out:
#        Green Island  Guguan
# Month
# 1              5872  151397
# 2             10210  151951
# 3             13213  127943
# 4             42587  147752
# 5             39920  108086

# %% [markdown]
# # Step 04

# %%
df2.plot()

# %% [markdown]
# # Step 05

# %%
df_T=df.T
df_T.head()
# Out:
# Month                1       2       3       4   ...      9       10      11      12
# Green Island       5872   10210   13213   42587  ...   26671   21745   11525   10294
# Guguan           151397  151951  127943  147752  ...  134118  129351  144019  205617
# National Museum   40988   82165   50683   83679  ...   67488   66921   50670   64738
#
# [3 rows x 12 columns]

# %% [markdown]
# # Step 06

# %%
df3=df_T[3]
df3.plot()

# %% [markdown]
# # 5-2-2 最愛比較的長條圖

# %% [markdown]
# # (圖)-長條圖：呈現及比較不同區域各季的銷售金額

# %%
from google.colab import drive
drive.mount('/content/MyGoogleDrive')
import pandas as pd
df = pd.read_csv(c_filepath + '圖5-5-年度銷售金額.csv')
df.index = df['AREA']
df = df.drop('AREA', axis=1)
df
# Out:
# Drive already mounted at /content/MyGoogleDrive; to attempt to forcibly remount, call drive.mount("/content/MyGoogleDrive", force_remount=True).
#         1st   2nd   3rd   4th
# AREA
# East   4522  2120  1200  3800
# West   3101  1846  2022  1900
# South  2111  2897  3200  2139
# North  4213   987   500  1568

# %%
df.plot(kind='bar', rot=0)

# %% [markdown]
# # 實作-長條圖【EX5-2.2.ipynb】

# %% [markdown]
# # Step 01

# %%
from google.colab import drive
drive.mount('/content/MyGoogleDrive')
import pandas as pd
df=pd.read_csv(i_filepath + '年度銷售金額.csv')
df.index = df['AREA']
df = df.drop('AREA', axis=1)
df
# Out:
# Drive already mounted at /content/MyGoogleDrive; to attempt to forcibly remount, call drive.mount("/content/MyGoogleDrive", force_remount=True).
#         1st   2nd   3rd   4th
# AREA
# East   4522  2120  1200  3800
# West   3101  1846  2022  1900
# South  2111  2897  3200  2139
# North  4213   987   500  1568

# %% [markdown]
# # Step 02

# %%
df.plot(kind='bar')

# %% [markdown]
# # Step 03

# %%
df.plot(kind='barh')

# %% [markdown]
# # 加廣知識：旋轉X軸標籤角度

# %%
df.plot(kind='bar')

# %%
df.plot(kind='bar', rot=0)

# %% [markdown]
# # 5-2-3 能展現自己重要性的圓餅圖

# %% [markdown]
# # (圖)-圓餅圖：顯示不同區域佔第一季總銷售金額的比例

# %%
from google.colab import drive
drive.mount('/content/MyGoogleDrive')
import pandas as pd
df = pd.read_csv(c_filepath + '圖5-6-年度銷售金額.csv')
df.index = df['AREA']
df = df.drop('AREA', axis=1)
df
# Out:
# Drive already mounted at /content/MyGoogleDrive; to attempt to forcibly remount, call drive.mount("/content/MyGoogleDrive", force_remount=True).
#         1st   2nd   3rd   4th
# AREA
# East   4522  2120  1200  3800
# West   3101  1846  2022  1900
# South  2111  2897  3200  2139
# North  4213   987   500  1568

# %%
df['1st'].plot(kind='pie', autopct='%.2f%%')

# %% [markdown]
# # 實作-圓餅圖【EX5-2.3.ipynb】

# %% [markdown]
# # Step 01

# %%
from google.colab import drive
drive.mount('/content/MyGoogleDrive')
import pandas as pd
df=pd.read_csv(i_filepath + '年度銷售金額.csv')
df.index = df['AREA']
df = df.drop('AREA', axis=1)
df
# Out:
# Drive already mounted at /content/MyGoogleDrive; to attempt to forcibly remount, call drive.mount("/content/MyGoogleDrive", force_remount=True).
#         1st   2nd   3rd   4th
# AREA
# East   4522  2120  1200  3800
# West   3101  1846  2022  1900
# South  2111  2897  3200  2139
# North  4213   987   500  1568

# %% [markdown]
# # Step 02

# %%
df['1st'].plot(kind='pie')

# %% [markdown]
# # 加深知識-繪製圓餅圖pie

# %%
df['1st'].plot(kind='pie', title='Proportion of each area')

# %%
df['1st'].plot(kind='pie', colors=['red','#00FF00','blue','yellow'])

# %%
df['1st'].plot(kind='pie', fontsize=12)

# %%
df['1st'].plot(kind='pie', fontsize=24)

# %%
df['1st'].plot(kind='pie', figsize=(1,1))

# %%
df['1st'].plot(kind='pie', figsize=(4,4))

# %%
df['1st'].plot(kind='pie', autopct='%.2f')

# %%
df['1st'].plot(kind='pie', autopct='%.0f%%')

# %% [markdown]
# # 5-2-4 掌握分佈局勢的直方圖

# %% [markdown]
# # (圖)-直方圖：顯示成績分布的情形

# %%
from google.colab import drive
drive.mount('/content/MyGoogleDrive')
import pandas as pd
df=pd.read_csv(c_filepath + '圖5-7-第一次期中考.csv')
df
# Out:
# Drive already mounted at /content/MyGoogleDrive; to attempt to forcibly remount, call drive.mount("/content/MyGoogleDrive", force_remount=True).
#         ID name  第1次期中考
# 0  1080001  丁軒軒      60
# 1  1080002  王倫樺      82
# 2  1080003  何宜敏      84
# 3  1080004  何志陞      83
# 4  1080005  吳ㄧ歌      64
# 5  1080006  宋緯挺      82
# 6  1080007  李宇綸      82
# 7  1080008  李憲勝      84
# 8  1080009  杜以潔      98
# 9  1080010  沈程隆     100

# %%
df['第1次期中考'].plot(kind='bar')

# %%
df['第1次期中考'].plot(kind='hist', bins=10)

# %% [markdown]
# # 實作-直方圖【EX5-2.4.ipynb】

# %% [markdown]
# # Step 01

# %%
from google.colab import drive
drive.mount('/content/MyGoogleDrive')
import pandas as pd
df=pd.read_csv(i_filepath + '學生成績檔.csv')
df.head()
# Out:
# Drive already mounted at /content/MyGoogleDrive; to attempt to forcibly remount, call drive.mount("/content/MyGoogleDrive", force_remount=True).
#         ID name sex                  email  ...  第5次平時考   總分    平均  排名
# 0  1080027  陳生貞   男  1080027@sun.tc.edu.tw  ...     100  497  99.4   1
# 1  1080012  林絜峰   男  1080012@sun.tc.edu.tw  ...      95  483  96.6   2
# 2  1080002  王倫樺   女  1080002@sun.tc.edu.tw  ...      96  482  96.4   3
# 3  1080013  林保苓   女  1080013@sun.tc.edu.tw  ...      94  475  95.0   4
# 4  1080028  陳宇愷   男  1080028@sun.tc.edu.tw  ...     100  473  94.6   5
#
# [5 rows x 12 columns]

# %% [markdown]
# # Step 02

# %%
df['第1次平時考'].plot(kind='hist')

# %% [markdown]
# # 加深知識：繪製直方圖hist

# %%
df['第1次平時考'].plot(kind='hist', bins=20)

# %%
df['第1次平時考'].plot(kind='hist', bins=40)

# %%
df['第1次平時考'].plot(kind='hist', color='blue', edgecolor='orange')

# %% [markdown]
# # 5-2-5 愛找模式的散佈圖

# %% [markdown]
# # (圖)-散佈圖：氣溫與紅茶銷售量之間的相關性

# %%
from google.colab import drive
drive.mount('/content/MyGoogleDrive')
import pandas as pd
df=pd.read_csv(c_filepath + '圖5-8-紅茶銷售量.csv')
df
# Out:
# Drive already mounted at /content/MyGoogleDrive; to attempt to forcibly remount, call drive.mount("/content/MyGoogleDrive", force_remount=True).
#     temperature  sale
# 0            10     5
# 1            28    62
# 2            34    93
# 3            31    84
# 4            25    59
# 5            29    64
# 6            32    80
# 7            31    75
# 8            24    58
# 9            33    91
# 10           25    51
# 11           31    73
# 12           26    65
# 13           30    84

# %%
df.plot(kind='scatter', x='temperature', y='sale')

# %% [markdown]
# # 實作-散佈圖【EX5-2.5.ipynb】

# %% [markdown]
# # Step 01

# %%
from google.colab import drive
drive.mount('/content/MyGoogleDrive')
import pandas as pd
df=pd.read_csv(i_filepath + 'sunshine.csv')
df
# Out:
# Drive already mounted at /content/MyGoogleDrive; to attempt to forcibly remount, call drive.mount("/content/MyGoogleDrive", force_remount=True).
#     Month  Temperature  SunShine
# 0       1         18.5      78.0
# 1       2         18.8      55.5
# 2       3         19.8      76.3
# 3       4         24.2     105.0
# 4       5         25.0      80.3
# 5       6         28.5      91.4
# 6       7         30.3     145.5
# 7       8         30.5     186.8
# 8       9         27.3     139.7
# 9      10         25.3     159.0
# 10     11         22.0     102.9
# 11     12         19.1      80.8

# %% [markdown]
# # Step 02

# %%
df.plot(kind='scatter', x='SunShine', y='Temperature')

# %% [markdown]
# # 加深知識－設定散佈圖X、Y軸的座標值

# %%
df.plot(kind='scatter', x='SunShine', y='Temperature')

# %%
df.plot(kind='scatter', x='SunShine', y='Temperature',xlim=(0, 200),  ylim=(0, 40))
