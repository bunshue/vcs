# %%
#資料檔路徑(資料檔：i_filepath，完成檔：o_filepath，內文說明檔：c_filepath)
filepath = '/content/MyGoogleDrive/My Drive/Colab Notebooks/Python-for-Titanic/Ch03/'
i_filepath = filepath 
o_filepath = filepath + '完成檔/'
c_filepath = filepath + '內文說明檔/'

# %% [markdown]
# #3-1 認識 pandas–從資料結構看起

# %% [markdown]
# # (圖)-試算表與pandas 資料框的對照

# %%
from google.colab import drive
drive.mount('/content/MyGoogleDrive')
import pandas as pd
df = pd.read_excel(c_filepath + '學生成績檔.xlsx')
df.head()
# Out:
# Drive already mounted at /content/MyGoogleDrive; to attempt to forcibly remount, call drive.mount("/content/MyGoogleDrive", force_remount=True).
#         ID name sex                  email  ...  第2次平時考  第3次平時考  第4次平時考  第5次平時考
# 0  1080001  丁軒軒   男  1080001@sun.tc.edu.tw  ...    88.0    82.0      87    92.0
# 1  1080002  王倫樺   女  1080002@sun.tc.edu.tw  ...   100.0    95.0      99    96.0
# 2  1080003  何宜敏   女  1080003@sun.tc.edu.tw  ...    87.0    86.0      82    82.0
# 3  1080004  何志陞   男  1080004@sun.tc.edu.tw  ...    92.0    99.0      91    92.0
# 4  1080005  吳ㄧ歌   女  1080005@sun.tc.edu.tw  ...     NaN    92.0      97    98.0
#
# [5 rows x 9 columns]

# %% [markdown]
# # 3-1-1 建立與存取序列

# %% [markdown]
# #實作-利用Python一維串列存放資料【EX3-1.1a.ipynb】

# %% [markdown]
# # Step 01

# %%
c = ['國文','英文','數學','資訊科技']
s = [84,92,88,95]

# %% [markdown]
# # Step 02

# %%
print(c)
print(s)
# Out:
# ['國文', '英文', '數學', '資訊科技']
# [84, 92, 88, 95]

# %% [markdown]
# #實作-利用pandas套件建立序列【EX3-1.1b.ipynb】

# %% [markdown]
# # Step 01

# %%
import pandas as pd

# %% [markdown]
# # Step 02

# %%
c = ['國文','英文','數學','資訊科技']
s = [84,92,88,95]

# %% [markdown]
# # Step 03

# %%
cs = pd.Series(c)
ss = pd.Series(s)
print(cs)
print(ss)
# Out:
# 0      國文
# 1      英文
# 2      數學
# 3    資訊科技
# dtype: object
# 0    84
# 1    92
# 2    88
# 3    95
# dtype: int64

# %% [markdown]
# # Step 04

# %%
print(cs[0])
print(ss[0])
# Out:
# 國文
# 84

# %% [markdown]
# #實作-建立自定索引的序列【EX3-1.1c.ipynb】

# %% [markdown]
# # Step 01

# %%
import pandas as pd
c = ['國文','英文','數學','資訊科技']
s = [84,92,88,95]

# %% [markdown]
# # Step 02

# %%
sc = pd.Series(s, index=c)
print(sc)
# Out:
# 國文      84
# 英文      92
# 數學      88
# 資訊科技    95
# dtype: int64

# %% [markdown]
# # Step 03

# %%
#使用內定索引
print(sc[1])
sc[1] = 100
print(sc[1])

#使用自定索引
print(sc['英文'])
sc['英文'] = 80
print(sc['英文'])
# Out:
# 92
# 100
# 100
# 80

# %% [markdown]
# # 加廣知識：存取序列的多個元素

# %%
#使用內定索引存取多個元素
ss = pd.Series([84,92,88,95])
print(ss[0:3])
print(ss[[1,3]])
nums=[1,3]
print(ss[nums])
# Out:
# 0    84
# 1    92
# 2    88
# dtype: int64
# 1    92
# 3    95
# dtype: int64
# 1    92
# 3    95
# dtype: int64

# %%
#使用自定索引存取多個元素
sc = pd.Series([84,92,88,95], index=['國文','英文','數學','資訊科技'])
print(sc['國文':'數學'])
print(sc[['英文','資訊科技']])
nums=['英文','資訊科技']
print(sc[nums])
# Out:
# 國文    84
# 英文    92
# 數學    88
# dtype: int64
# 英文      92
# 資訊科技    95
# dtype: int64
# 英文      92
# 資訊科技    95
# dtype: int64

# %% [markdown]
# # 3-1-2 建立與存取資料框

# %% [markdown]
# #實作-利用Python list建立二維串列【EX3-1.2a.ipynb】

# %% [markdown]
# # Step 01

# %%
sc = [['國文','英文','數學','資訊科技'],[84,92,88,95]]
print(sc)
# Out:
# [['國文', '英文', '數學', '資訊科技'], [84, 92, 88, 95]]

# %% [markdown]
# # Step 02

# %%
print(len(sc))
# Out:
# 2

# %% [markdown]
# # Step 03

# %%
for i in range(len(sc[0])):
  print(sc[0][i],sc[1][i])
# Out:
# 國文 84
# 英文 92
# 數學 88
# 資訊科技 95

# %% [markdown]
# #實作-呼叫pandas的DataFrame()函式建立資料框【EX3-1.2b.ipynb】

# %% [markdown]
# # Step 01

# %%
import pandas as pd
c = ['國文','英文','數學','資訊科技']
s = [84,92,88,95]

# %% [markdown]
# # Step 02

# %%
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Step 03

# %%
df['科目'] = c
df['分數'] = s

# %% [markdown]
# # Step 04

# %%
df
# Out:
#      科目  分數
# 0    國文  84
# 1    英文  92
# 2    數學  88
# 3  資訊科技  95

# %% [markdown]
# # Step 05

# %%
for i in range(len(df)):
    print(df['科目'][i],df['分數'][i])
# Out:
# 國文 84
# 英文 92
# 數學 88
# 資訊科技 95

# %% [markdown]
# #實作-自定資料框的列索引【EX3-1.2c.ipynb】

# %% [markdown]
# # Step 01

# %%
import pandas as pd
c = ['國文','英文','數學','資訊科技']
s = [84,92,88,95]
df = pd.DataFrame()
df['科目'] = c
df['分數'] = s
df.index = ['第1科','第2科','第3科','第4科']
df
# Out:
#        科目  分數
# 第1科    國文  84
# 第2科    英文  92
# 第3科    數學  88
# 第4科  資訊科技  95

# %% [markdown]
# # Step 02

# %%
for i in range(len(df)):
  print(df.index[i],df['科目'][i],df['分數'][i])
# Out:
# 0 國文 84
# 1 英文 92
# 2 數學 88
# 3 資訊科技 95

# %% [markdown]
# #加廣知識：資料框參數設定

# %%
import pandas as pd
n = ['丁軒軒','王倫華','何宜敏','陳志昇']
c = ['國文','英文','數學','社會','自然']
s = [[86,88,82,87,92],[92,100,95,99,96],[82,87,86,82,82],[91,92,99,91,92]]
df = pd.DataFrame(s, index=n, columns=c)
df
# Out:
#      國文   英文  數學  社會  自然
# 丁軒軒  86   88  82  87  92
# 王倫華  92  100  95  99  96
# 何宜敏  82   87  86  82  82
# 陳志昇  91   92  99  91  92

# %% [markdown]
# # 3-2 資料取得

# %% [markdown]
# #3-2-1 讀取資料檔

# %% [markdown]
# #實作-掛接Google雲端硬碟【EX3-2.1a.ipynb】

# %% [markdown]
# # Step 01

# %%
from google.colab import drive
drive.mount('/content/MyGoogleDrive')
# Out:
# Drive already mounted at /content/MyGoogleDrive; to attempt to forcibly remount, call drive.mount("/content/MyGoogleDrive", force_remount=True).

# %% [markdown]
# #實作-pandas讀取CSV檔及印出資料【EX3-2.1b.ipynb】

# %% [markdown]
# # Step 01

# %%
from google.colab import drive
drive.mount('/content/MyGoogleDrive')
import pandas as pd
df = pd.read_csv(i_filepath + 'Iris.csv')
# Out:
# Drive already mounted at /content/MyGoogleDrive; to attempt to forcibly remount, call drive.mount("/content/MyGoogleDrive", force_remount=True).

# %% [markdown]
# # Step 02

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# # 3-2-2 儲存(匯出)資料檔

# %% [markdown]
# #實作-將資料框儲存成CSV檔【EX3-2.2.ipynb】

# %% [markdown]
# # Step 01

# %%
from google.colab import drive
drive.mount('/content/MyGoogleDrive')
# Out:
# Drive already mounted at /content/MyGoogleDrive; to attempt to forcibly remount, call drive.mount("/content/MyGoogleDrive", force_remount=True).

# %% [markdown]
# # Step 02

# %%
import pandas as pd
n = ['丁軒軒','王倫樺','何宜敏','何志陞']
c = ['國文','英文','數學','社會','自然']
s = [[86,88,82,87,92],[92,100,95,99,96],[82,87,86,82,82],[91,92,99,91,92]]
df = pd.DataFrame(s, index=n, columns=c )
df
# Out:
#      國文   英文  數學  社會  自然
# 丁軒軒  86   88  82  87  92
# 王倫樺  92  100  95  99  96
# 何宜敏  82   87  86  82  82
# 何志陞  91   92  99  91  92

# %% [markdown]
# # Step 03

# %%
filename='五科成績.csv'       
df.to_csv(o_filepath + filename)

# %% [markdown]
# # 3-2-3 由網址讀取資料檔

# %% [markdown]
# #實作-由網址讀取資料檔【EX3-2.3.ipynb】

# %% [markdown]
# # Step 01

# %%
import pandas as pd
df=pd.read_csv('https://data.epa.gov.tw/api/v1/aqx_p_322?limit=1000&api_key=9be7b239-557b-4c10-9775-78cadfc555e9&format=csv')
df.head()
# Out:
#    SiteId SiteName County  ...  ItemUnit          MonitorDate Concentration
# 0       1       基隆    基隆市  ...     μg/m3  2021-05-06 00:00:00            18
# 1       2       汐止    新北市  ...     μg/m3  2021-05-06 00:00:00            25
# 2       3       萬里    新北市  ...     μg/m3  2021-05-06 00:00:00            19
# 3       4       新店    新北市  ...     μg/m3  2021-05-06 00:00:00            19
# 4       5       土城    新北市  ...     μg/m3  2021-05-06 00:00:00            21
#
# [5 rows x 9 columns]

# %% [markdown]
# # Step 02

# %%
filename='PM25.csv'       
df.to_csv(o_filepath + filename)

# %% [markdown]
# # 3-2-4 網路爬蟲

# %% [markdown]
# #實作-網路爬蟲-台灣彩券【EX3-2.4.ipynb】

# %% [markdown]
# # Step 01-02

# %%
import pandas as pd
url='https://www.taiwanlottery.com.tw/Lotto/Lotto649/history.aspx'
df = pd.read_html(url)
df
# Out:
# [                                                   0
#  0  .style3 {color: #FF0000} .style5 {color: #FF00...,
#                                                     0
#  0  期別 開獎日 兌獎截止(註6)  銷售金額 獎金總額  110000045  110/05/...
#  1  期別 開獎日 兌獎截止(註6)  銷售金額 獎金總額  110000044  110/04/...
#  2  期別 開獎日 兌獎截止(註6)  銷售金額 獎金總額  110000043  110/04/...
#  3  期別 開獎日 兌獎截止(註6)  銷售金額 獎金總額  110000042  110/04/...
#  4  期別 開獎日 兌獎截止(註6)  銷售金額 獎金總額  110000041  110/04/...
#  5  期別 開獎日 兌獎截止(註6)  銷售金額 獎金總額  110000040  110/04/...
#  6  期別 開獎日 兌獎截止(註6)  銷售金額 獎金總額  110000039  110/04/...
#  7  期別 開獎日 兌獎截止(註6)  銷售金額 獎金總額  110000038  110/04/...
#  8  期別 開獎日 兌獎截止(註6)  銷售金額 獎金總額  110000037  110/04/...
#  9  期別 開獎日 兌獎截止(註6)  銷售金額 獎金總額  110000036  110/04/...,
#              0          1          2  ...          7          8          9
#  0          期別        開獎日        開獎日  ...       獎金總額       獎金總額       獎金總額
#  1   110000045  110/05/04  110/05/04  ...  121406835  121406835  121406835
# ...

# %% [markdown]
# # Step 03

# %%
df[1]
# Out:
#                                                    0
# 0  期別 開獎日 兌獎截止(註6)  銷售金額 獎金總額  110000045  110/05/...
# 1  期別 開獎日 兌獎截止(註6)  銷售金額 獎金總額  110000044  110/04/...
# 2  期別 開獎日 兌獎截止(註6)  銷售金額 獎金總額  110000043  110/04/...
# 3  期別 開獎日 兌獎截止(註6)  銷售金額 獎金總額  110000042  110/04/...
# 4  期別 開獎日 兌獎截止(註6)  銷售金額 獎金總額  110000041  110/04/...
# 5  期別 開獎日 兌獎截止(註6)  銷售金額 獎金總額  110000040  110/04/...
# 6  期別 開獎日 兌獎截止(註6)  銷售金額 獎金總額  110000039  110/04/...
# 7  期別 開獎日 兌獎截止(註6)  銷售金額 獎金總額  110000038  110/04/...
# 8  期別 開獎日 兌獎截止(註6)  銷售金額 獎金總額  110000037  110/04/...
# 9  期別 開獎日 兌獎截止(註6)  銷售金額 獎金總額  110000036  110/04/...

# %%
df[2]
# Out:
#             0          1          2  ...          7          8          9
# 0          期別        開獎日        開獎日  ...       獎金總額       獎金總額       獎金總額
# 1   110000045  110/05/04  110/05/04  ...  121406835  121406835  121406835
# 2          獎號         獎號         獎號  ...         獎號        特別號        特別號
# 3        開出順序       開出順序         27  ...         05         42         42
# 4        大小順序       大小順序         05  ...         37         42         42
# 5        獎金分配       獎金分配       獎金分配  ...       獎金分配       獎金分配       獎金分配
# 6          項目         頭獎         頭獎  ...         陸獎         柒獎         普獎
# 7     對中  獎號數         6個         6個  ...  任3個  ＋特別號  任2個  ＋特別號        任3個
# 8      中獎  注數          0          0  ...       2100      20583      34215
# 9      單注  獎金          0          0  ...       1000        400        400
# 10   累至次  期獎金   85311966   85311966  ...        NaN        NaN        NaN
#
# [11 rows x 10 columns]
