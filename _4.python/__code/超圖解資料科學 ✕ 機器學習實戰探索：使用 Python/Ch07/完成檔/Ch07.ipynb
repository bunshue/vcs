# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
X = [[1], [2], [3], [4], [5]]
y = [88, 72, 90, 76, 92]
lm.fit(X, y)
print('第6次考試分數：', lm.predict([[6]]))
# Out:
# 第6次考試分數： [87.2]
