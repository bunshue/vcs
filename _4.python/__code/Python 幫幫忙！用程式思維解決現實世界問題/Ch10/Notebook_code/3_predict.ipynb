# %%
import os
from datetime import datetime
import cv2 as cv

names = {1: "Demming"}  # 將使用者 ID 聯結到使用者名稱

# 設定 Haar 分類器檔案路徑
cascade_path = "C:/Users/Admin/anaconda/Lib/site-packages/cv2/data/"
face_detector = cv.CascadeClassifier(cascade_path +
                                     'haarcascade_frontalface_default.xml')

# 初始化辨識器物件，並載入訓練資料
recognizer = cv.face.LBPHFaceRecognizer_create()
recognizer.read('lbph_trainer.yml')

#test_path = './tester'  # 若使用的是你的臉，請取消註解
test_path = './demming_tester' # 使用提供的臉部影像
image_paths = [os.path.join(test_path, f) for f in os.listdir(test_path)]

# 執行人臉辨識並更新存取日誌檔案
for image in image_paths:
    predict_image = cv.imread(image, cv.IMREAD_GRAYSCALE)
    faces = face_detector.detectMultiScale(predict_image,
                                          scaleFactor=1.05,
                                          minNeighbors=5)
    for (x, y, w, h) in faces:
        print(f"\nAccess requested at {datetime.now()}.")
        face = cv.resize(predict_image[y:y + h, x:x + w], (100, 100))   
        predicted_id, dist = recognizer.predict(face)
        if predicted_id == 1 and dist <= 95:
            name = names[predicted_id]
            print("{} identified as {} with distance={}"
                  .format(image, name, round(dist, 1)))
            print(f"Access granted to {name} at {datetime.now()}.",
                  file=open('lab_access_log.txt', 'a'))
        else:
            name = 'unknown'
            print(f"{image} is {name}.")
        
        cv.rectangle(predict_image, (x, y), (x + w, y + h), 255, 2) # 繪製矩形
        cv.putText(predict_image, name, (x + 1, y + h -5),
                   cv.FONT_HERSHEY_SIMPLEX, 0.5, 255, 1) # 標示使用者名稱
        cv.imshow('ID', predict_image) # 顯示影像     
        cv.waitKey(2000) # 視窗停滯 2 秒
        cv.destroyAllWindows() # 關閉視窗
# Out:
# Access requested at 2022-01-03 13:37:37.134347.
# ./demming_tester\test (1).jpg identified as Demming with distance=94.0
#
# Access requested at 2022-01-03 13:37:39.248024.
# ./demming_tester\test (1).png is unknown.
#
# Access requested at 2022-01-03 13:37:41.434284.
# ./demming_tester\test (10).png is unknown.
#
# Access requested at 2022-01-03 13:37:43.565096.
# ./demming_tester\test (11).png is unknown.
#
# Access requested at 2022-01-03 13:37:45.717509.
# ./demming_tester\test (12).png is unknown.
#
# Access requested at 2022-01-03 13:37:47.791937.
# ./demming_tester\test (2).jpg identified as Demming with distance=34.3
#
# Access requested at 2022-01-03 13:37:49.864008.
# ./demming_tester\test (2).png is unknown.
#
# Access requested at 2022-01-03 13:37:51.949060.
# ./demming_tester\test (3).jpg identified as Demming with distance=95.0
#
# Access requested at 2022-01-03 13:37:54.041983.
# ./demming_tester\test (3).png is unknown.
#
# Access requested at 2022-01-03 13:37:56.121986.
# ./demming_tester\test (4).jpg identified as Demming with distance=82.1
#
# Access requested at 2022-01-03 13:37:58.301176.
# ./demming_tester\test (4).png is unknown.
#
# Access requested at 2022-01-03 13:38:00.391023.
# ./demming_tester\test (5).jpg identified as Demming with distance=27.2
#
# Access requested at 2022-01-03 13:38:02.504182.
# ./demming_tester\test (5).png is unknown.
#
# Access requested at 2022-01-03 13:38:04.588728.
# ./demming_tester\test (6).jpg identified as Demming with distance=32.9
#
# Access requested at 2022-01-03 13:38:06.727064.
# ./demming_tester\test (6).png is unknown.
#
# Access requested at 2022-01-03 13:38:08.806662.
# ./demming_tester\test (7).jpg identified as Demming with distance=87.9
#
# Access requested at 2022-01-03 13:38:11.004665.
# ./demming_tester\test (7).png is unknown.
#
# Access requested at 2022-01-03 13:38:13.090402.
# ./demming_tester\test (8).jpg identified as Demming with distance=64.9
#
# Access requested at 2022-01-03 13:38:15.187943.
# ./demming_tester\test (8).png is unknown.
#
# Access requested at 2022-01-03 13:38:17.297223.
# ./demming_tester\test (9).png is unknown.
