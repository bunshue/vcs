# %%
import requests
url = "https://www.taiwannews.com.tw/en/news/3610689"
html = requests.get(url).text
print(html)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#                                     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <meta name="author" content="Taiwan News">
#     <meta name="msvalidate.01" content="1B767768A4DBD00EE727D7234A6D366E">    <meta property="og:type" content="article">
#     <meta property="og:site_name" content="Taiwan News">
#     <meta name="google-site-verification" content="z_olpn978vuQe5nR1yuzhIPFXgCbfnPNxUjkXN46Q_0">
#     <link rel="icon" href="/img/favicon-TN3.png">
#     <title>Taiwan scientists develop new mosquito trap t... | Taiwan News</title>
#     <!-- Open Graph protocol metadata-->
#     <meta property="og:title" content="Taiwan scientists develop new mosquito trap t... | Taiwan News">
#     <meta property="og:url" content="https://www.taiwannews.com.tw/en/news/3610689">
#     <meta name="description" content="The &#39;smart&#39; trap can identify species and disease-carrying capacity immediately.The National Health Research Institutes (NHRI) have developed a new hi-tec mosquito trap that can potentially curb the progression of virus epidemics.">
#     <meta property="og:description" content="The &#39;smart&#39; trap can identify species and disease-carrying capacity immediately.The National Health Research Institutes (NHRI) have developed a new hi-tec mosquito trap that can potentially curb the progression of virus epidemics.">
#     <meta property="og:image" content="https://tnimage.taiwannews.com.tw/photos/shares/5c302b8c3726b.jpg">
#     <meta property="og:image:width" content="640">
#     <meta property="og:image:height" content="442">    <link href="https://www.taiwannews.com.tw/en/news/3610689" rel="canonical">    <!-- FB App ID-->
#     <meta property="fb:app_id" content="1082075965223782">    <meta http-equiv="refresh" content="600">    <!-- Custom styles for this template-->
#     <link href="/css/swiper.min.css" rel="stylesheet">
#     <link href="/css/slider.css" rel="stylesheet">
#     <link href="/css/font-awesome.min.css" rel="stylesheet">    <link href="/css/cms-theme-en.css?ts=1546539839" rel="stylesheet">    <link href="https://fonts.googleapis.com/css?family=Montserrat" rel="stylesheet" type="text/css">
#     <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries--><!--[if lt IE 9]>
#     <script src="/js/html5shiv.min.js"></script>
#     <script src="/js/respond.min.js"></script><![endif]-->
#     <!-- Start Alexa Certify Javascript -->
#     <script type="text/javascript">
#       _atrk_opts = { atrk_acct:"+151o1QolK10fn", domain:"taiwannews.com.tw",dynamic: true};
#       (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://d31qbv1cthcecs.cloudfront.net/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
#     </script>
#     <noscript><img src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=+151o1QolK10fn" style="display:none" height="1" width="1" alt=""></noscript><!-- End Alexa Certify Javascript -->
#     <!-- Google Analytics -->
#     <script>
#       (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#       (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#       m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#       })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#       ga('create', 'UA-86170837-1', 'auto');
#       ga('send', 'pageview');
#     </script><!-- End Google Analytics -->
#   </head>
#   <body>
#     <div id="wrapper">
#                   <header id="header">
#         <section>
#           <button id="sidebar-toggle" type="button" data-toggle="collapse" data-target="#navbar-collapse" aria-expanded="false" aria-controls="navbar" class="collapsed"><span class="sr-only">Toggle navigation</span><span class="bar top"></span><span class="bar middle"></span><span class="bar bottom"></span></button>
#           <div id="navbar-collapse" class="collapse menu-collapse">
#             <ul id="sidebar" class="nav">              <li style="background-color: #FF0000;" class="de_rec"></li>                            <li style="display:flex;">                <div style="background-color: #F78680;width:5px;height:auto;"></div><a href="/en/cate/3">World</a>
#               </li>                            <li style="display:flex;">                <div style="background-color: #808ECC;width:5px;height:auto;"></div><a href="/en/cate/9">Politics</a>
#               </li>                            <li style="display:flex;">                <div style="background-color: #F4B064;width:5px;height:auto;"></div><a href="/en/cate/5">Business</a>
#               </li>                            <li style="display:flex;">                <div style="background-color: #5BA5F6;width:5px;height:auto;"></div><a href="/en/cate/7">Society</a>
#               </li>                            <li style="display:flex;">                <div style="background-color: #71D5CA;width:5px;height:auto;"></div><a href="/en/cate/4">Culture</a>
#               </li>                            <li style="display:flex;">                <div style="background-color: #274e13;width:5px;height:auto;"></div><a href="/en/cate/6">Editorial</a>
#               </li>                            <li style="display:flex;">                <div style="background-color: #F4B064;width:5px;height:auto;"></div><a href="/en/cate/12">Opinion</a>
#               </li>                            <li style="display:flex;">                <div style="background-color: #A670BD;width:5px;height:auto;"></div><a href="/en/cate/10">Travel &amp; Cuisine</a>
#               </li>                            <li style="display:flex;">                <div style="background-color: #F78680;width:5px;height:auto;"></div><a href="/en/cate/11">New Immigrants</a>
#               </li>                            <li style="display:flex;">                <div style="background-color: #cc0000;width:5px;height:auto;"></div><a href="/en/cate/13">Sports &amp; Entertainment</a>
#               </li>                            <li style="display:flex;">                <div style="background-color: #71D5CA;width:5px;height:auto;"></div><a href="/en/cate/14">Environment</a>
#               </li>                            <li style="display:flex;">                <div style="background-color: #808ECC;width:5px;height:auto;"></div><a href="/en/cate/16">Food Safety &amp; Health</a>
#               </li>                            <li style="display:flex;">                <div style="background-color: #000000;width:5px;height:auto;"></div><a href="/en/cate/34">Taiwan News Weekly Roundup</a>
#               </li>                            <li style="display:flex;">                <div style="background-color: #000000;width:5px;height:auto;"></div><a href="/en/cate/37">Photo of the Day</a>
#               </li>                            <li style="display:flex;">                <div style="background-color: #000000;width:5px;height:auto;"></div><a href="/en/cate/38">2018 SmartCitySummit</a>
#               </li>                            <li style="background-color: #9900FF;" class="de_rec"></li>
#             </ul>
#           </div>
#         </section>
#         <!--end sidebar-menu-->
#         <button id="sidebar-logo" type="button" data-toggle="collapse" data-target="#navbar-collapse" aria-expanded="false" aria-controls="navbar" background-color="white" class="collapsed mod_logo hm pull-left"></button>
#         <section class="mod_language"><a href="https://www.taiwannews.com.tw/ch/index" class="btn system-language Chinese">漢</a><a href="https://www.taiwannews.com.tw/en/index" class="btn system-language English">En
#             <!--end mod_language--></a>
#         </section>
#         <section style="margin-left:-6px;" class="mod_header-navbar">
#           <ul>            <li><a href="#" data-toggle="modal" data-target="#loginModal" id="loginButton"><img src="/img/m2.png" class="mod_logo hm"></a></li>          </ul>
#         </section>
#         <section class="mod_logo hm logo_center img-responsive"><a href="/en/index"><img src="/img/TN-logo-enb.png"></a></section>
#         <div id="loginModal" tabindex="-1" role="dialog" class="modal fade">
#           <div role="document" style="z-index:2000;" class="modal-dialog">
#             <div class="modal-content">
#               <div id="loginModalContent" class="modal-content">
#                 <section class="mod_auth common_pane-md">
#                   <div class="mod_tab-flex">
#                     <div style="padding-top:0px;" class="tab-content">
#                       <div id="login" role="tabpanel" class="tab-pane active">
#                         <header class="de_header">                          <h4 class="text-center">Login</h4>                        </header>
#                         <div class="common_wrapper-vertical">                          <form action="https://www.taiwannews.com.tw/en/login" method="POST" class="mod_form-icon-style form-horizontal text-center"><input type="hidden" name="_token" value="SSSBdBk7lmZVUbj08LYWxMFtJKvz5khFpZtuYsg1">
#                             <div class="col-md-offset-1 col-md-10">
#                               <div class="form-group">
#                                 <label for="email" class="control-label col-xs-3 col-md-2"><span class="fa fa-user"></span></label>
#                                 <div class="col-xs-9 col-md-10">                                  <input placeholder="Please enter email" name="email" type="email" class="form-control">                                </div>
#                               </div>
#                               <div class="form-group">
#                                 <label for="password" class="control-label col-xs-3 col-md-2"><span class="fa fa-lock"></span></label>
#                                 <div class="col-xs-9 col-md-10">                                  <input placeholder="Please enter password" name="password" type="password" class="form-control">                                </div>
#                               </div>
#                               <div class="password-action text-left">
#                                 <input type="checkbox" name="keep_login"><span>Stay logged in</span>                                <div class="password-forgot"><a href="#forgot" role="tab" data-toggle="tab" id="forgotModel">Forget password?</a></div>
#                               </div>
#                               <div class="button-group">                                <button type="submit" class="btn btn-lg btn-block btn-status submit">Login</button>                              </div>
#                               <div class="register text-center">                                <h5 class="common_inline">Not yet a member？<a href="/en/member/register">Register</a></h5>                              </div>
#                             </div>
#                           </form>
#                         </div>
#                       </div>
#                       <div id="forgot" role="tabpanel" class="tab-pane">
#                         <header class="de_header">
#                           <h4 class="text-center">忘記密碼</h4>
#                         </header>
#                         <div class="modal-dialog forgot">
#                           <div class="modal-body">                            <form role="form" method="POST" action="https://www.taiwannews.com.tw/%7Blang%7D/password/forgot" class="mod_form form-horizontal"><input type="hidden" name="_token" value="SSSBdBk7lmZVUbj08LYWxMFtJKvz5khFpZtuYsg1">
#                               <div class="col-md-offset-1 col-md-10">
#                                 <div class="form-group">
#                                   <label for="email" class="control-label col-md-4">E-Mail</label>
#                                   <div class="col-md-8">
#                                     <input placeholder="E-Mail" name="email" type="text" value="" class="form-control">
#                                   </div>
#                                 </div>
#                                 <div class="common_twenty"></div>
#                                 <div class="button-group">
#                                   <button type="submit" class="btn btn-lg btn-block btn-status submit">送出</button>
#                                 </div>
#                                 <div class="register text-center">
#                                   <h5 class="common_inline">返回<a href="#login" role="tab" data-toggle="tab">登入頁</a></h5>
#                                 </div>
#                               </div>
#                             </form>
#                             <div class="clearfix"></div>
#                           </div>
#                         </div>
#                       </div>
#                     </div>
#                   </div>
#                 </section>
#               </div>
#             </div>
#           </div>
#         </div>
#         <div id="forgotSuccessModal" tabindex="-1" role="dialog" class="modal fade">
#           <div role="document" style="z-index:2000;" class="modal-dialog">
#             <div class="modal-content">
#               <div id="forgotSuccessModal" class="modal-body">
#                 <p>密碼設定成功，請使用新密碼登入
#                 </p>
#               </div>
#             </div>
#           </div>
#         </div>
#         <!--end mod_header-navbar-->
#       </header>
#       <section class="mod_social-nav">
#         <ul class="social-nav">
#           <li><a href="#" data-toggle="collapse" data-target="#collapseSearch" aria-expanded="false" class="search"><i class="fa fa-search"></i></a></li>
#           <li><a href="https://www.taiwannews.com.tw/guide?lang=english" target="_blank" style="background-color:#e98422;"><img src="/img/icon-en.jpg" style="margin-top:-2px;padding-bottom: 2px;"></a></li>
#           <li><a href="https://www.facebook.com/taiwannews.en/" target="_blank" class="facebook"><i class="fa fa-facebook"></i></a></li>
#           <li><a href="http://twitter.com/TaiwanNews886?lang=zh-tw" target="_blank" class="twitter"><i class="fa fa-twitter"></i></a></li>
#           <li><a href="https://www.youtube.com/user/taiwannewsonline" target="_blank" class="youtube"><i class="fa fa-youtube"></i></a></li>
#         </ul>
#       </section>
#       <div id="collapseSearch" class="collapse">
#         <div class="mod_search-box">          <form role="search" action="/en/search" class="form-inline">
#             <div class="form-group2">
#               <button type="submit" id="search-btn" class="form-control"><span class="fa fa-search"></span><span>&nbsp;|</span></button>              <input type="search" id="search" name="keyword" value="" placeholder="search" class="form-control">
#             </div>
#           </form>
#         </div>
#       </div>
#       <div id="content">        <div class="mod_breadcrumb">
#           <ol class="breadcrumb">
#             <li><a href="/en/index" title="Home">Home</a></li>            <li><a href="/en/cate/16" title="Food Safety &amp; Health">Food Safety &amp; Health</a></li>                      </ol>
#         </div>
#         <div class="no-gutter">
#           <div id="main" class="col-xs-12 col-md-8 de_paper">
#             <section class="mod_single-column">
#               <header class="article-head-wrapper">
#                                                 <h1 class="article-title">Taiwan scientists develop new mosquito trap that could save lives</h1>                <h4 class="subtilte">The &#39;smart&#39; trap can identify species and disease-carrying capacity immediately</h4>                <div class="up_share">
#                   <div class="a2a_kit"><span class="viewcount-badge"><span style="margin-bottom: 2px;" class="fa fa-eye"></span>&nbsp; 275</span><a data-href="https://www.taiwannews.com.tw/en/news/3610689" data-width="50" data-layout="button_count" data-action="like" data-show-faces="true" data-share="false" style="margin-right: 0px;" class="fb-like"></a>
#                     <div data-href="https://www.taiwannews.com.tw/en/news/3610689" data-layout="button" class="fb-share-button"></div><a data-count="horizontal" data-url="https://www.taiwannews.com.tw/en/news/3610689" class="a2a_button_twitter_tweet"></a><a data-annotation="bubble" data-href="https://www.taiwannews.com.tw/en/news/3610689" class="a2a_button_google_plus_share"></a>
#                   </div>
#                 </div>
#                 <div class="article-meta">
#                   <div class="article-author"><span>By&nbsp;</span><a href="/en/search?keyword=Ryan Drillsma" title="Ryan Drillsma">Ryan Drillsma</a>,Taiwan News, Staff Writer
#                                       </div>
#                   <div class="article-date">2019/01/05 12:01</div>
#                 </div>
#               </header>
#               <article class="container-fluid article">                <section class="mod_article-slide">
#                   <div class="swiper-container detail-jade">
#                     <div class="swiper-wrapper">                      <div class="swiper-slide"><img src="https://tnimage.taiwannews.com.tw/photos/shares/5c302b8c3726b.jpg" title="Dengue-fever-carrying insects are identified within fractions of a second" alt="Dengue-fever-carrying insects are identified within fractions of a second" class="img-responsive">                        <div class="caption">
#                                                                                                                                   <p>Dengue-fever-carrying insects are identified within fractions of a second (By Central News Agency)</p>                        </div>                      </div>                    </div>                  </div>
#                 </section><span><p>TAIPEI (Taiwan News) &mdash; The National Health Research Institutes (NHRI) have developed a new high-tech mosquito trap that can potentially curb the progression of virus epidemics.</p>
#
# <p><a href="https://www.cna.com.tw/news/ahel/201901040087.aspx" target="_blank">CNA</a> reports NHRI have spent a year and a half developing what they call a &ldquo;smart&rdquo; mosquito trap. The trap can detect whether or not a mosquito carries dengue fever within 0.07 seconds of its capture and could be used to identify areas at high risk of an epidemic.</p>
#
# <p>The institutes held a press conference yesterday (Jan. 5) in which they shared the results of their latest research on the prevention and control of mosquito-borne illnesses.</p>
#
# <p>During an interview at the conference, NHRI biomedical engineer Liao Lun-de (廖倫德) said crucial research has been carried out over recent years on the dissemination of contagious diseases like dengue fever and zika, with particular focus on carrier mosquitos.</p>
#
# <p> </p>
#
# <p>Prior to now, mosquito traps have focused on eradicating the pest without identifying its species or virus-carrying capacity, he commented.</p>
#
# <p> </p>
#
# <p>The new mosquito trap combines photoelectric sensors and artificial intelligence technology to identify the unique flying patterns of different mosquitos by using what the institutes dub a kind of &ldquo;facial-recognition&rdquo; technology.</p>
#
# <p> </p>
#
# <p>Liao said once a mosquito flies into the trap, sensors trigger cameras that capture 10,800 images of the insect, which are used to determine whether it is of a common, harmless variety or a more dangerous, disease-carrying species.</p>
#
# <p> </p>
#
# <p>The technology identifies mosquito species with 90 percent accuracy. The cost of each unit is between NT$2000 and NT$4000.</p>
#
# <p> </p>
#
# <p>Liao explained that most mosquito traps use sticky paper that kills the insects upon landing and risks them becoming attached to other creatures such as roaches. The new trap contains (rather than kills) the insect so the blood it carries can be examined to see what kind of creature it has bitten, and whether or not it carries disease.</p>
#
# <p> </p>
#
# <p>Data collected from trapped mosquitos is uploaded to a system, Liao disclosed, and can be used in combination with GIS technology to predict high-risk areas. This will help enable frontline epidemic prevention units initiate preventative measures to curb the risk of diseases spreading.</p>
# </span>
#               </article>
#               <div class="container-fluid">
#                 <div class="tagcloud"><a href="/en/search?keyword=mosquitoes" title="mosquitoes"><span class="tag">
#                       <div class="fa fa-fw fa-tag"></div>mosquitoes</span></a><a href="/en/search?keyword=Dengue Fever" title="Dengue Fever"><span class="tag">
#                       <div class="fa fa-fw fa-tag"></div>Dengue Fever</span></a><a href="/en/search?keyword=Zika" title="Zika"><span class="tag">
#                       <div class="fa fa-fw fa-tag"></div>Zika</span></a><a href="/en/search?keyword=National Health Research Institutes" title="National Health Research Institutes"><span class="tag">
#                       <div class="fa fa-fw fa-tag"></div>National Health Research Institutes</span></a></div>
#                 <div class="down_share">
#                   <div class="a2a_kit"><a data-href="https://www.taiwannews.com.tw/en/news/3610689" data-width="50" data-layout="button_count" data-action="like" data-show-faces="true" data-share="false" style="margin-right: 0px;" class="fb-like"></a>
#                     <div data-href="https://www.taiwannews.com.tw/en/news/3610689" data-layout="button" class="fb-share-button"></div><a data-count="horizontal" data-url="https://www.taiwannews.com.tw/en/news/3610689" class="a2a_button_twitter_tweet"></a><a data-annotation="bubble" data-href="https://www.taiwannews.com.tw/en/news/3610689" class="a2a_button_google_plus_share"></a>
#                   </div>
#                 </div>
#               </div>
#               <footer class="article-foot-wrapper hide">
#                 <nav>
#                   <ul class="pager">
#                     <li class="previous disabled"><a href="#" title="Older"><span aria-hidden="true">&larr;</span>Older</a></li>
#                     <li class="next"><a href="#" title="Newer">Newer<span aria-hidden="true">&rarr;</span></a></li>
#                   </ul>
#                 </nav>
#               </footer>
#               <!--end mod_single-column-->
#             </section>            <header class="page-header">
#               <div class="container-fluid">                <h2 class="latest">RELATED ARTICLES</h2>              </div>
#             </header>
#             <section class="mod_related-list row m-0">              <div class="div popular_side col-xs-12 col-md-12"><a href="/en/news/3527540" style="padding: 0px;" title="Southern Taiwanese city of Tainan reports year&#39;s first indigenous dengue fever case" class="col-xs-5 col-sm-2 col-md-2"><img src="https://tnimage.taiwannews.com.tw/small/shares/5b97abb245032.jpg" alt="Southern Taiwanese city of Tainan reports year&#39;s first indigenous dengue fever case" class="img-responsive center-block popular_img"></a>
#                 <div class="col-xs-11 col-sm-12 col-md-12 related-words"><a href="/en/news/3527540" title="Southern Taiwanese city of Tainan reports year&#39;s first indigenous dengue fever case" class="de_remove-link-color">Southern Taiwanese city of Tainan reports year&#39;s first indigenous dengue fever case</a></div>
#                 <div style="padding:0 10px;" class="col-xs-4 col-sm-4 col-md-4 text-right">2018/09/11 19:47</div>
#               </div>              <div class="div popular_side col-xs-12 col-md-12"><a href="/en/news/3525848" style="padding: 0px;" title="New Taipei City&#39;s Yonghe&nbsp;District sees first&nbsp;dengue fever case" class="col-xs-5 col-sm-2 col-md-2"><img src="https://tnimage.taiwannews.com.tw/small/shares/5b5c29e87a843.jpg" alt="New Taipei City&#39;s Yonghe&nbsp;District sees first&nbsp;dengue fever case" class="img-responsive center-block popular_img"></a>
#                 <div class="col-xs-11 col-sm-12 col-md-12 related-words"><a href="/en/news/3525848" title="New Taipei City&#39;s Yonghe&nbsp;District sees first&nbsp;dengue fever case" class="de_remove-link-color">New Taipei City&#39;s Yonghe&nbsp;District sees first&nbsp;dengue fever case</a></div>
#                 <div style="padding:0 10px;" class="col-xs-4 col-sm-4 col-md-4 text-right">2018/09/09 11:37</div>
#               </div>              <div class="div popular_side col-xs-12 col-md-12"><a href="/en/news/3518638" style="padding: 0px;" title="Southern Taiwan mobilizes 5,000 people to combat dengue fever" class="col-xs-5 col-sm-2 col-md-2"><img src="https://tnimage.taiwannews.com.tw/small/shares/5b879ddf275e9.jpg" alt="Southern Taiwan mobilizes 5,000 people to combat dengue fever" class="img-responsive center-block popular_img"></a>
#                 <div class="col-xs-11 col-sm-12 col-md-12 related-words"><a href="/en/news/3518638" title="Southern Taiwan mobilizes 5,000 people to combat dengue fever" class="de_remove-link-color">Southern Taiwan mobilizes 5,000 people to combat dengue fever</a></div>
#                 <div style="padding:0 10px;" class="col-xs-4 col-sm-4 col-md-4 text-right">2018/08/30 15:36</div>
#               </div>              <div class="div popular_side col-xs-12 col-md-12"><a href="/en/news/3516259" style="padding: 0px;" title="7 new cases of dengue fever recorded across Taiwan" class="col-xs-5 col-sm-2 col-md-2"><img src="https://tnimage.taiwannews.com.tw/small/shares/5b83ec125efe8.jpg" alt="7 new cases of dengue fever recorded across Taiwan" class="img-responsive center-block popular_img"></a>
#                 <div class="col-xs-11 col-sm-12 col-md-12 related-words"><a href="/en/news/3516259" title="7 new cases of dengue fever recorded across Taiwan" class="de_remove-link-color">7 new cases of dengue fever recorded across Taiwan</a></div>
#                 <div style="padding:0 10px;" class="col-xs-4 col-sm-4 col-md-4 text-right">2018/08/27 20:20</div>
#               </div>              <div class="div popular_side col-xs-12 col-md-12"><a href="/en/news/3515450" style="padding: 0px;" title="Taiwan&#39;s wet weather increases risk of dengue fever outbreak" class="col-xs-5 col-sm-2 col-md-2"><img src="https://tnimage.taiwannews.com.tw/small/shares/5b8262dd7fc9f.jpg" alt="Taiwan&#39;s wet weather increases risk of dengue fever outbreak" class="img-responsive center-block popular_img"></a>
#                 <div class="col-xs-11 col-sm-12 col-md-12 related-words"><a href="/en/news/3515450" title="Taiwan&#39;s wet weather increases risk of dengue fever outbreak" class="de_remove-link-color">Taiwan&#39;s wet weather increases risk of dengue fever outbreak</a></div>
#                 <div style="padding:0 10px;" class="col-xs-4 col-sm-4 col-md-4 text-right">2018/08/26 16:23</div>
#               </div>            </section>            <hr>
#             <div class="rad-ad"><ins style="display:inline-block;width:0px;height:0px;" data-sca-pub="lR8NHxQ/Sy5GUxc=" data-sca-web="102" data-sca-category="1" data-sca-cid="14347" data-sca-responsive="auto" data-sca-background-color="#ffffff" data-sca-title-color="#333333" data-sca-title-font-family="Microsoft JhengHei" data-sca-description-color="#3989D4" data-sca-description-font-family="Microsoft JhengHei" data-sca-border-color="#f2f2f2" class="scupioadslot"></ins>
#               <script async="" src="//img.scupio.com/js/ad.js"></script>
#             </div>            <section class="mod_related-list">
#               <div data-widget="plista_widget_belowArticle"></div>
#               <script>
#                 (function (c) {
#                   var g, s = 'script', w = window, n = c.name || 'PLISTA';
#                   if (!w[n]) {
#                     w[n] = c;
#                     g = w.document.getElementsByTagName(s)[0];
#                     s = w.document.createElement(s);
#                     s.async = true;
#                     s.type = 'text/javascript';
#                     s.src = (w.location.protocol === 'https:' ? 'https:' : 'http:') + '//static' + (c.origin ? '-' + c.origin : '') + '.plista.com/async' + (c.name ? '/' + c.name : '') + '.js';
#                     g.parentNode.insertBefore(s, g);
#                   }
#                 }({
#                   "publickey": "a5313d009e59dffa13015729",
#                   "item": {
#                     "objectid": "3610689",
#                     "title": "Taiwan scientists develop new mosquito trap that could save lives",
#                     "text": "TAIPEI (Taiwan News) &mdash; The National Health Research Institutes (NHRI) have developed a new high-tech mosquito trap that can potentially curb the progression of virus epidemics.CNA reports NHRI have spent a year and a half developing what they ca...",
#                     "url": "https://www.taiwannews.com.tw/en/news/3610689",
#                     "img": "https://tnimage.taiwannews.com.tw/photos/shares/5c302b8c3726b.jpg",
#                     "category": "Food Safety &amp; Health",
#                     "published_at": 1546660860,
#                     "updated_at": 1546666435                  },
#                   "origin": "tw" }));
#
#               </script>
#             </section>
#           </div>
#           <div id="aside" class="col-xs-12 col-md-4">            <section class="mod_sidebar">
#               <div class="update_time">                <p>Updated : 2019-01-05 19:55 GMT+08:00</p>              </div>              <header class="page-header">
#                 <div class="container-fluid">                  <h4>MOST POPULAR</h4>                </div>                <div class="div popular_side"><a href="/en/news/3605624" title="File Photo: Kenyan Pres. Uhuru Kenyatta and Xi Jinping, 2013"><img src="https://tnimage.taiwannews.com.tw/small/shares/5c24a3ace4946.jpg" alt="File Photo: Kenyan Pres. Uhuru Kenyatta and Xi Jinping, 2013" class="img-responsive center-block popular_img">
#                     <div style="width:75%;" class="related-words"><a href="/en/news/3605624" title="China&#39;s African debt-trap: Beijing prepares to seize Kenya&#39;s port of Mombasa" class="de_remove-link-color popular_font">China&#39;s African debt-trap: Beijing prepares to seize Kenya&#39;s port of Mombasa</a></div></a></div>                <div class="div popular_side"><a href="/en/news/3608740" title="(Image from 爆廢公社)"><img src="https://tnimage.taiwannews.com.tw/small/shares/5c2c738d30d8c.jpg" alt="(Image from 爆廢公社)" class="img-responsive center-block popular_img">
#                     <div style="width:75%;" class="related-words"><a href="/en/news/3608740" title="Taiwanese man saves NT$80,000 in 1 year with &#39;365 Savings Method&#39;" class="de_remove-link-color popular_font">Taiwanese man saves NT$80,000 in 1 year with &#39;365 Savings Method&#39;</a></div></a></div>                <div class="div popular_side"><a href="/en/news/3608137" title="Trump Signs the ARIA Act into law, Dec. 31"><img src="https://tnimage.taiwannews.com.tw/small/shares/5c2afbfb69018.jpg" alt="Trump Signs the ARIA Act into law, Dec. 31" class="img-responsive center-block popular_img">
#                     <div style="width:75%;" class="related-words"><a href="/en/news/3608137" title="Trump signs pro-Taiwan &#39;Asia Reassurance Initiative Act&#39; into law" class="de_remove-link-color popular_font">Trump signs pro-Taiwan &#39;Asia Reassurance Initiative Act&#39; into law</a></div></a></div>                <div class="div popular_side"><a href="/en/news/3608779" title="President Tsai Ing-wen responds to the &#039;one country, two system&#039; framework for Taiwan proposed by China&#039;s President Xi Jinping on Jan. 2 (Source: CNA)"><img src="https://tnimage.taiwannews.com.tw/small/shares/5c2c78588439a.jpg" alt="President Tsai Ing-wen responds to the &#039;one country, two system&#039; framework for Taiwan proposed by China&#039;s President Xi Jinping on Jan. 2 (Source: CNA)" class="img-responsive center-block popular_img">
#                     <div style="width:75%;" class="related-words"><a href="/en/news/3608779" title="Taiwan will never accept China&#39;s &#39;one country, two systems,&#39; says President Tsai" class="de_remove-link-color popular_font">Taiwan will never accept China&#39;s &#39;one country, two systems,&#39; says President Tsai</a></div></a></div>                <div class="div popular_side"><a href="/en/news/3609989" title="(Image by Ken Lin)"><img src="https://tnimage.taiwannews.com.tw/small/shares/5c2edbd2438d9.jpg" alt="(Image by Ken Lin)" class="img-responsive center-block popular_img">
#                     <div style="width:75%;" class="related-words"><a href="/en/news/3609989" title="Contrary to Xi&#39;s speech, 84% of Taiwanese do not accept &#39;1992 consensus&#39;" class="de_remove-link-color popular_font">Contrary to Xi&#39;s speech, 84% of Taiwanese do not accept &#39;1992 consensus&#39;</a></div></a></div>                <div class="div popular_side"><a href="/en/news/3609258" title="Students at lens factory. (Photo by Ko Chih-en)"><img src="https://tnimage.taiwannews.com.tw/small/shares/5c2d8765de6c7.jpg" alt="Students at lens factory. (Photo by Ko Chih-en)" class="img-responsive center-block popular_img">
#                     <div style="width:75%;" class="related-words"><a href="/en/news/3609258" title="Indonesia freezes Taiwan internship program after students forced to work in factories, eat pork" class="de_remove-link-color popular_font">Indonesia freezes Taiwan internship program after students forced to work in factories, eat pork</a></div></a></div>                <div class="div popular_side"><a href="/en/news/3610020" title="File photo"><img src="https://tnimage.taiwannews.com.tw/small/shares/5c2ee88f49d13.jpg" alt="File photo" class="img-responsive center-block popular_img">
#                     <div style="width:75%;" class="related-words"><a href="/en/news/3610020" title="Hong Kong implores Taiwan, don&#39;t fall for China&#39;s lie of &#39;one country, two systems&#39;" class="de_remove-link-color popular_font">Hong Kong implores Taiwan, don&#39;t fall for China&#39;s lie of &#39;one country, two systems&#39;</a></div></a></div>                <div class="div popular_side"><a href="/en/news/3609169" title=""><img src="https://tnimage.taiwannews.com.tw/small/shares/5c2d74d1aa347.jpg" alt="" class="img-responsive center-block popular_img">
#                     <div style="width:75%;" class="related-words"><a href="/en/news/3609169" title="Contrary to Xi&#39;s speech, only 15% of Taiwanese want unification with China at any stage" class="de_remove-link-color popular_font">Contrary to Xi&#39;s speech, only 15% of Taiwanese want unification with China at any stage</a></div></a></div>                <div class="div popular_side"><a href="/en/news/3610158" title="(Photo from Facebook group 爆料公社)"><img src="https://tnimage.taiwannews.com.tw/small/shares/5c2f2c8e299be.jpg" alt="(Photo from Facebook group 爆料公社)" class="img-responsive center-block popular_img">
#                     <div style="width:75%;" class="related-words"><a href="/en/news/3610158" title="Foreign driver flashes V sign, wife goes ballistic after car accident in northern Taiwan" class="de_remove-link-color popular_font">Foreign driver flashes V sign, wife goes ballistic after car accident in northern Taiwan</a></div></a></div>                <div class="div popular_side"><a href="/en/news/3609517" title=""><img src="https://tnimage.taiwannews.com.tw/small/shares/5c2dd74758afa.jpg" alt="" class="img-responsive center-block popular_img">
#                     <div style="width:75%;" class="related-words"><a href="/en/news/3609517" title="Former US serviceman reveals US troops in Okinawa &#39;there to protect Taiwan&#39;" class="de_remove-link-color popular_font">Former US serviceman reveals US troops in Okinawa &#39;there to protect Taiwan&#39;</a></div></a></div>              </header>
#               <div class="de_divider">              </div>
#               <div class="mod_payment-ad">
#                 <script>
#                   //<!--
#                   google_ad_client = "pub-5521506484906895";
#                   /* 300x250 CICL */
#                   google_ad_slot = "5075971253";
#                   google_ad_width = 300;
#                   google_ad_height = 250;
#                   //-->
#                 </script>
#                 <script src="https://pagead2.googlesyndication.com/pagead/show_ads.js"></script>
#               </div>
#               <div class="mod_payment-ad">
#                 <div class="stru_payment-ad"><ins style="display:inline-block;width:300px;height:600px" data-ad-zone="3228" class="clickforceads"></ins>
#                 </div>
#               </div>
#             </section>
#           </div>
#         </div>
#         <!-- 蓋版廣告 -->
#         <ins style="display:inline-block;width:320px;height:480px;left:0;top:0;" data-ad-zone="8892" class="clickforceads"></ins>
#         <script async type="text/javascript" src="//cdn.doublemax.net/js/init.js"></script>      </div>
#       <footer id="footer">
#         <div class="container-fluid">
#           <div class="mod_footer-left">
#             <ul>
#               <li><a href="/en/page/aboutUs">About Us</a></li>
#               <!--li
#               //|               //a(href="/en/page/privacyPolicy") Privacy Policy
#               //|               -->
#               <li><a href="/en/page/contactUs">Contact Us</a></li>
#               <!--li-->
#               <!--    |               a(href="/guide") Taiwan Guide
#               |               -->
#             </ul>
#           </div>
#           <div class="mod_footer-right">
#             <p>Taiwan News  &copy;  2018 All Rights Reserved.</p>
#           </div>
#         </div>
#       </footer>
#       <!--
#       Bootstrap core JavaScript
#       ==================================================
#       -->
#       <!-- Placed at the end of the document so the pages load faster-->
#       <script src="/js/jquery.min.js"></script>
#       <script src="/js/bootstrap.min.js" type="text/javascript"></script>
#       <script src="/js/swiper.min.js" type="text/javascript"></script>
#       <script src="/js/moretext-1.2.js" type="text/javascript"></script>
#       <script src="/js/slider.js" type="text/javascript"></script>
#       <!--側欄menu-->
#       <script>
#         $(document).ready(function(){
#           $('#sidebar-toggle').click(function() {
#             $(this).toggleClass('active');
#           });
#         });
#
#         $(document).ready(function(){
#
#           var body_width = $(window).width();
#           var page_width = $('#wrapper').width();
#
#           if (body_width >= 1350) {
#             $('#sidebar').css({
#               "width": (body_width - page_width) / 2 +"px "
#             });
#           }
#
#           $(window).resize(function() {
#             var body_resize = $(window).width();
#             var page_resize = $('#wrapper').width();
#             if (body_resize >= 1335) {
#               $('#sidebar').css({
#                 "width": (body_resize - page_resize) / 2 +"px "
#               });
#             }
#             if (body_resize < 1335) {
#               $('#sidebar').css({
#                 "width": 100 +"% "
#               });
#             }
#           });
#
#         });
#
#       </script>
#       <!--解決無法在擬元素上加inline-style-->
#       <script>
#         var addRule = (function(style){
#         var sheet = document.head.appendChild(style).sheet;
#         return function(selector, css){
#           var propText = Object.keys(css).map(function(p){
#               return p+":"+css[p]
#           }).join(";");
#           sheet.insertRule(selector + "{" + propText + "}", sheet.cssRules.length);
#         }
#         })(document.createElement("style"));
#
#         addRule(".de_category-header:before", {
#             background: "#F44336" /*需判斷分類並加上對應的顏色*/
#         });
#
#       </script>
#       <script>
#         $('.swiper-container').each(function () {
#           // detail.jade 中的 swiper 與這邊的設定不同，所以不在這裡初始化
#           if (!$(this).hasClass('detail-jade')){
#             new Swiper(this, {
#               spaceBetween: 0,
#               centeredSlides: true,
#               autoplay: 3000,
#               speed: 1000,
#               loop: $(this).find('.swiper-slide').length > 1,
#               autoplayDisableOnInteraction: false
#             });
#           }
#         });
#
#
#       </script>
#       <script>
#         $('a[data-toggle="tab"]').on('shown.bs.tab', function (e) {
#           var target = $(this).attr('href');
#
#           $(target).css('right','-'+$('#loginModalContent').width()+'px');
#           var right = $(target).offset().right;
#           $(target).css({right:right}).animate({"right":"0px"}, 200);
#         });
#       </script>
#     </div>
#             <script>
#       (function(lang, id) {
#         $.get("/api/v1/pv/" + lang + "/" + id);
#       })(1, 3610689);
#
#     </script>
#     <script>
#       var a2a_config = a2a_config || {};
#
#       a2a_config.locale = "en-US";
#
#     </script>
#     <script type="text/javascript" src="//static.addtoany.com/menu/page.js"></script>
#     <script>
#       var swiper = new Swiper('.swiper-container', {
#           pagination: '.swiper-pagination',
#           paginationClickable: true,
#           nextButton: '.swiper-button-next',
#           prevButton: '.swiper-button-prev',
#           autoplay: 3000,
#           speed: 1000,
#           loop: $(this).find('.swiper-slide').length > 1,
#           autoplayDisableOnInteraction: false
#       });
#
#     </script>
#     <script>
#       (function(d, s, id) {
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) return;
#         js = d.createElement(s); js.id = id;
#         js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.6";
#         fjs.parentNode.insertBefore(js, fjs);
#       }(document, 'script', 'facebook-jssdk'));
#
#     </script>
#     <script type="application/ld+json">
#       {
#         "@context": "http://schema.org",
#         "@type": "NewsArticle",
#         "headline": "Taiwan scientists develop new mosquito trap that could save lives",
#         "mainEntityOfPage": "Taiwan scientists develop new mosquito trap that could save lives",
#         "author": "Ryan Drillsma",
#         "publisher": {
#           "@type": "Organization",
#           "name": "Taiwan News",
#           "logo": {
#             "@type": "ImageObject",
#             "url": "https://www.taiwannews.com.tw/images/websiteSetting/5a3bf6401f8a8.png"
#           }
#         },
#         "image": ["https://tnimage.taiwannews.com.tw/photos/shares/5c302b8c3726b.jpg"],
#         "datePublished": "2019-01-05 12:01:00",
#         "dateModified": "2019-01-05 13:33:55",
#         "description": "The &#39;smart&#39; trap can identify species and disease-carrying capacity immediately"
#       }
#
#     </script>    <script type="application/ld+json">
#       {
#         "@context": "http://schema.org",
#         "@type": "BreadcrumbList",
#         "itemListElement": [
#           {
#             "@type": "ListItem",
#             "position": 1,
#             "name": "Food Safety &amp; Health",
#             "item": "https://www.taiwannews.com.tw/en/cate/16"
#           }
#                   ]
#       }
#     </script>  </body>
#   <script>
#     $('.mod_showad,.mod_sqad,.mod_longad').find('a').on('click', function (e) {
#       $.ajax({
#         type: "POST",
#         url: "https://www.taiwannews.com.tw/api/v1/ad_statistics" + '/' + $(this).data('id'),
#         data: {
#           //
#         },
#         dataType: "json",
#         success: function (data) {
#           //- console.log(data)
#         },
#         error: function (data) {
#           console.log('ad statistic post error');
#           console.log(data);
#         }
#       });
#       ga('send', {
#         'hitType': 'event',
#         'eventCategory': 'ad',
#         'eventAction': 'click',
#         'eventValue': $(this).data('id')
#       });
#     });
#   </script>
# </html>

# %%
from bs4 import BeautifulSoup
import requests
url = "https://www.taiwannews.com.tw/en/news/3610689"
html = requests.get(url).text
soup = BeautifulSoup(html, "lxml")
title = soup.find("h1", class_="article-title")
article = soup.find("article", class_="container-fluid article")
print(title.text)
print(article.text)
# Out:
# Taiwan scientists develop new mosquito trap that could save lives
#
#
#
# Dengue-fever-carrying insects are identified within fractions of a second (By Central News Agency)
# TAIPEI (Taiwan News) — The National Health Research Institutes (NHRI) have developed a new high-tech mosquito trap that can potentially curb the progression of virus epidemics.
# CNA reports NHRI have spent a year and a half developing what they call a “smart” mosquito trap. The trap can detect whether or not a mosquito carries dengue fever within 0.07 seconds of its capture and could be used to identify areas at high risk of an epidemic.
# The institutes held a press conference yesterday (Jan. 5) in which they shared the results of their latest research on the prevention and control of mosquito-borne illnesses.
# During an interview at the conference, NHRI biomedical engineer Liao Lun-de (廖倫德) said crucial research has been carried out over recent years on the dissemination of contagious diseases like dengue fever and zika, with particular focus on carrier mosquitos.
#
# Prior to now, mosquito traps have focused on eradicating the pest without identifying its species or virus-carrying capacity, he commented.
#
# The new mosquito trap combines photoelectric sensors and artificial intelligence technology to identify the unique flying patterns of different mosquitos by using what the institutes dub a kind of “facial-recognition” technology.
#
# Liao said once a mosquito flies into the trap, sensors trigger cameras that capture 10,800 images of the insect, which are used to determine whether it is of a common, harmless variety or a more dangerous, disease-carrying species.
#
# The technology identifies mosquito species with 90 percent accuracy. The cost of each unit is between NT$2000 and NT$4000.
#
# Liao explained that most mosquito traps use sticky paper that kills the insects upon landing and risks them becoming attached to other creatures such as roaches. The new trap contains (rather than kills) the insect so the blood it carries can be examined to see what kind of creature it has bitten, and whether or not it carries disease.
#
# Data collected from trapped mosquitos is uploaded to a system, Liao disclosed, and can be used in combination with GIS technology to predict high-risk areas. This will help enable frontline epidemic prevention units initiate preventative measures to curb the risk of diseases spreading.

# %%
from bs4 import BeautifulSoup
import requests
import os

news_title = ""
news_content = ""
if not os.path.exists("engnews.txt"):
    url = "https://www.taiwannews.com.tw/en/news/3610689"
    html = requests.get(url).text
    soup = BeautifulSoup(html, "lxml")
    title = soup.find("h1", class_="article-title")
    article = soup.find("article", class_="container-fluid article")
    news_title = title.text
    news_content = article.text
    with open("engnews.txt", "w", encoding="utf-8") as f:
        f.write(news_title+"\n")
        f.write(news_content)
else:
    with open("engnews.txt", "r", encoding="utf-8") as f:
        lines = f.readlines()
        news_title = lines[0]
        news_content = lines[1:]
print(news_title)
print(news_content)
# Out:
# Taiwan scientists develop new mosquito trap that could save lives
#
# [' \n', '\n', '  \n', 'Dengue-fever-carrying insects are identified within fractions of a second (By Central News Agency)    \n', 'TAIPEI (Taiwan News) — The National Health Research Institutes (NHRI) have developed a new high-tech mosquito trap that can potentially curb the progression of virus epidemics.\n', 'CNA reports NHRI have spent a year and a half developing what they call a “smart” mosquito trap. The trap can detect whether or not a mosquito carries dengue fever within 0.07 seconds of its capture and could be used to identify areas at high risk of an epidemic.\n', 'The institutes held a press conference yesterday (Jan. 5) in which they shared the results of their latest research on the prevention and control of mosquito-borne illnesses.\n', 'During an interview at the conference, NHRI biomedical engineer Liao Lun-de (廖倫德) said crucial research has been carried out over recent years on the dissemination of contagious diseases like dengue fever and zika, with particular focus on carrier mosquitos.\n', ' \n', 'Prior to now, mosquito traps have focused on eradicating the pest without identifying its species or virus-carrying capacity, he commented.\n', ' \n', 'The new mosquito trap combines photoelectric sensors and artificial intelligence technology to identify the unique flying patterns of different mosquitos by using what the institutes dub a kind of “facial-recognition” technology.\n', ' \n', 'Liao said once a mosquito flies into the trap, sensors trigger cameras that capture 10,800 images of the insect, which are used to determine whether it is of a common, harmless variety or a more dangerous, disease-carrying species.\n', ' \n', 'The technology identifies mosquito species with 90 percent accuracy. The cost of each unit is between NT$2000 and NT$4000.\n', ' \n', 'Liao explained that most mosquito traps use sticky paper that kills the insects upon landing and risks them becoming attached to other creatures such as roaches. The new trap contains (rather than kills) the insect so the blood it carries can be examined to see what kind of creature it has bitten, and whether or not it carries disease.\n', ' \n', 'Data collected from trapped mosquitos is uploaded to a system, Liao disclosed, and can be used in combination with GIS technology to predict high-risk areas. This will help enable frontline epidemic prevention units initiate preventative measures to curb the risk of diseases spreading.\n', '\n']

# %%
from bs4 import BeautifulSoup
import requests
import os

news_title = ""
news_content = ""
if not os.path.exists("chinews.txt"):
    url = "https://www.cna.com.tw/news/aopl/201901050192.aspx"
    html = requests.get(url).text
    soup = BeautifulSoup(html, "lxml")
    title = soup.find("title")
    article = soup.find("div", class_="paragraph")
    news_title = title.text
    news_content = article.text
    with open("chinews.txt", "w", encoding="utf-8") as f:
        f.write(news_title+"\n")
        f.write(news_content)
else:
    with open("chinews.txt", "r", encoding="utf-8") as f:
        lines = f.readlines()
        news_title = lines[0]
        news_content = lines[1:]
print(news_title)
print(news_content)
# Out:
# ['\n', '\t加州保齡球館爆槍擊案 警方：3死4傷 | 國際 | 中央社 CNA\n', '\n', '\n', '（中央社華盛頓5日綜合外電報導）加州警方今天表示，洛杉磯附近托蘭斯市一家保齡球館發生槍擊事件，造成3人死亡、4人受傷。法新社報導，托蘭斯（Torrance）警察局警官哈里斯（Ronald Harris）證實，昨天晚上11時54分接獲通報，三角牆屋保齡球館（Gable House Bowl）有人開槍。他說，所有7名受害者皆為男性，3人當場死亡。目擊者告訴「洛杉磯時報」（The Los Angeles Times），這家保齡球館在槍擊事件前發生打鬥。托蘭斯警察局午夜過後不久，發推文提醒民眾「遠離事發地區」。加州海岸城市托蘭斯位在洛杉磯東南方約32公里南灣地區（South Bay）。（譯者：葉俐緯/核稿：羅苑韶）1080105']

# %%
from bs4 import BeautifulSoup
import requests
import os

news_title = ""
news_content = ""
filename = "chinews.txt"
if not os.path.exists(filename):
    url = "https://www.cna.com.tw/news/aopl/201901050192.aspx"
    html = requests.get(url).text
    soup = BeautifulSoup(html, "lxml")
    title = soup.find("title")
    article = soup.find("div", class_="paragraph")
    news_title = title.text.strip()
    news_content = article.text
    with open(filename, "w", encoding="utf-8") as f:
        f.write(news_title+"\n")
        f.write(news_content)
else:
    with open(filename, "r", encoding="utf-8") as f:
        lines = f.readlines()
        news_title = lines[0]
        news_content = lines[1:]
print(news_title)
print(news_content)
# Out:
# 加州保齡球館爆槍擊案 警方：3死4傷 | 國際 | 中央社 CNA
#
# ['（中央社華盛頓5日綜合外電報導）加州警方今天表示，洛杉磯附近托蘭斯市一家保齡球館發生槍擊事件，造成3人死亡、4人受傷。法新社報導，托蘭斯（Torrance）警察局警官哈里斯（Ronald Harris）證實，昨天晚上11時54分接獲通報，三角牆屋保齡球館（Gable House Bowl）有人開槍。他說，所有7名受害者皆為男性，3人當場死亡。目擊者告訴「洛杉磯時報」（The Los Angeles Times），這家保齡球館在槍擊事件前發生打鬥。托蘭斯警察局午夜過後不久，發推文提醒民眾「遠離事發地區」。加州海岸城市托蘭斯位在洛杉磯東南方約32公里南灣地區（South Bay）。（譯者：葉俐緯/核稿：羅苑韶）1080105']

# %%
with open("engnews.txt", "r", encoding="utf-8") as f:
    print(f.readline())
    print("-->Next")
with open("engnews.txt", "r", encoding="utf-8") as f:
    print(f.read())
    print("-->Next")
with open("engnews.txt", "r", encoding="utf-8") as f:
    print(f.readlines())
# Out:
# Taiwan scientists develop new mosquito trap that could save lives
#
# -->Next
# Taiwan scientists develop new mosquito trap that could save lives
#
#
#
# Dengue-fever-carrying insects are identified within fractions of a second (By Central News Agency)
# TAIPEI (Taiwan News) — The National Health Research Institutes (NHRI) have developed a new high-tech mosquito trap that can potentially curb the progression of virus epidemics.
# CNA reports NHRI have spent a year and a half developing what they call a “smart” mosquito trap. The trap can detect whether or not a mosquito carries dengue fever within 0.07 seconds of its capture and could be used to identify areas at high risk of an epidemic.
# The institutes held a press conference yesterday (Jan. 5) in which they shared the results of their latest research on the prevention and control of mosquito-borne illnesses.
# During an interview at the conference, NHRI biomedical engineer Liao Lun-de (廖倫德) said crucial research has been carried out over recent years on the dissemination of contagious diseases like dengue fever and zika, with particular focus on carrier mosquitos.
#
# Prior to now, mosquito traps have focused on eradicating the pest without identifying its species or virus-carrying capacity, he commented.
#
# The new mosquito trap combines photoelectric sensors and artificial intelligence technology to identify the unique flying patterns of different mosquitos by using what the institutes dub a kind of “facial-recognition” technology.
#
# Liao said once a mosquito flies into the trap, sensors trigger cameras that capture 10,800 images of the insect, which are used to determine whether it is of a common, harmless variety or a more dangerous, disease-carrying species.
#
# The technology identifies mosquito species with 90 percent accuracy. The cost of each unit is between NT$2000 and NT$4000.
#
# Liao explained that most mosquito traps use sticky paper that kills the insects upon landing and risks them becoming attached to other creatures such as roaches. The new trap contains (rather than kills) the insect so the blood it carries can be examined to see what kind of creature it has bitten, and whether or not it carries disease.
#
# Data collected from trapped mosquitos is uploaded to a system, Liao disclosed, and can be used in combination with GIS technology to predict high-risk areas. This will help enable frontline epidemic prevention units initiate preventative measures to curb the risk of diseases spreading.
#
#
# -->Next
# ['Taiwan scientists develop new mosquito trap that could save lives\n', ' \n', '\n', '  \n', 'Dengue-fever-carrying insects are identified within fractions of a second (By Central News Agency)    \n', 'TAIPEI (Taiwan News) — The National Health Research Institutes (NHRI) have developed a new high-tech mosquito trap that can potentially curb the progression of virus epidemics.\n', 'CNA reports NHRI have spent a year and a half developing what they call a “smart” mosquito trap. The trap can detect whether or not a mosquito carries dengue fever within 0.07 seconds of its capture and could be used to identify areas at high risk of an epidemic.\n', 'The institutes held a press conference yesterday (Jan. 5) in which they shared the results of their latest research on the prevention and control of mosquito-borne illnesses.\n', 'During an interview at the conference, NHRI biomedical engineer Liao Lun-de (廖倫德) said crucial research has been carried out over recent years on the dissemination of contagious diseases like dengue fever and zika, with particular focus on carrier mosquitos.\n', ' \n', 'Prior to now, mosquito traps have focused on eradicating the pest without identifying its species or virus-carrying capacity, he commented.\n', ' \n', 'The new mosquito trap combines photoelectric sensors and artificial intelligence technology to identify the unique flying patterns of different mosquitos by using what the institutes dub a kind of “facial-recognition” technology.\n', ' \n', 'Liao said once a mosquito flies into the trap, sensors trigger cameras that capture 10,800 images of the insect, which are used to determine whether it is of a common, harmless variety or a more dangerous, disease-carrying species.\n', ' \n', 'The technology identifies mosquito species with 90 percent accuracy. The cost of each unit is between NT$2000 and NT$4000.\n', ' \n', 'Liao explained that most mosquito traps use sticky paper that kills the insects upon landing and risks them becoming attached to other creatures such as roaches. The new trap contains (rather than kills) the insect so the blood it carries can be examined to see what kind of creature it has bitten, and whether or not it carries disease.\n', ' \n', 'Data collected from trapped mosquitos is uploaded to a system, Liao disclosed, and can be used in combination with GIS technology to predict high-risk areas. This will help enable frontline epidemic prevention units initiate preventative measures to curb the risk of diseases spreading.\n', '\n']

# %%
with open("engnews.txt", "r", encoding="utf-8") as f:
    data = f.read()
print(repr(data))
# Out:
# 'Taiwan scientists develop new mosquito trap that could save lives\n \n\n  \nDengue-fever-carrying insects are identified within fractions of a second (By Central News Agency)    \nTAIPEI (Taiwan News) — The National Health Research Institutes (NHRI) have developed a new high-tech mosquito trap that can potentially curb the progression of virus epidemics.\nCNA reports NHRI have spent a year and a half developing what they call a “smart” mosquito trap. The trap can detect whether or not a mosquito carries dengue fever within 0.07 seconds of its capture and could be used to identify areas at high risk of an epidemic.\nThe institutes held a press conference yesterday (Jan. 5) in which they shared the results of their latest research on the prevention and control of mosquito-borne illnesses.\nDuring an interview at the conference, NHRI biomedical engineer Liao Lun-de (廖倫德) said crucial research has been carried out over recent years on the dissemination of contagious diseases like dengue fever and zika, with particular focus on carrier mosquitos.\n \nPrior to now, mosquito traps have focused on eradicating the pest without identifying its species or virus-carrying capacity, he commented.\n \nThe new mosquito trap combines photoelectric sensors and artificial intelligence technology to identify the unique flying patterns of different mosquitos by using what the institutes dub a kind of “facial-recognition” technology.\n \nLiao said once a mosquito flies into the trap, sensors trigger cameras that capture 10,800 images of the insect, which are used to determine whether it is of a common, harmless variety or a more dangerous, disease-carrying species.\n \nThe technology identifies mosquito species with 90 percent accuracy. The cost of each unit is between NT$2000 and NT$4000.\n \nLiao explained that most mosquito traps use sticky paper that kills the insects upon landing and risks them becoming attached to other creatures such as roaches. The new trap contains (rather than kills) the insect so the blood it carries can be examined to see what kind of creature it has bitten, and whether or not it carries disease.\n \nData collected from trapped mosquitos is uploaded to a system, Liao disclosed, and can be used in combination with GIS technology to predict high-risk areas. This will help enable frontline epidemic prevention units initiate preventative measures to curb the risk of diseases spreading.\n\n'

# %%
with open("engnews.txt", "r", encoding="utf-8") as f:
    data = f.read()
print(data.split())
# Out:
# ['Taiwan', 'scientists', 'develop', 'new', 'mosquito', 'trap', 'that', 'could', 'save', 'lives', 'Dengue-fever-carrying', 'insects', 'are', 'identified', 'within', 'fractions', 'of', 'a', 'second', '(By', 'Central', 'News', 'Agency)', 'TAIPEI', '(Taiwan', 'News)', '—', 'The', 'National', 'Health', 'Research', 'Institutes', '(NHRI)', 'have', 'developed', 'a', 'new', 'high-tech', 'mosquito', 'trap', 'that', 'can', 'potentially', 'curb', 'the', 'progression', 'of', 'virus', 'epidemics.', 'CNA', 'reports', 'NHRI', 'have', 'spent', 'a', 'year', 'and', 'a', 'half', 'developing', 'what', 'they', 'call', 'a', '“smart”', 'mosquito', 'trap.', 'The', 'trap', 'can', 'detect', 'whether', 'or', 'not', 'a', 'mosquito', 'carries', 'dengue', 'fever', 'within', '0.07', 'seconds', 'of', 'its', 'capture', 'and', 'could', 'be', 'used', 'to', 'identify', 'areas', 'at', 'high', 'risk', 'of', 'an', 'epidemic.', 'The', 'institutes', 'held', 'a', 'press', 'conference', 'yesterday', '(Jan.', '5)', 'in', 'which', 'they', 'shared', 'the', 'results', 'of', 'their', 'latest', 'research', 'on', 'the', 'prevention', 'and', 'control', 'of', 'mosquito-borne', 'illnesses.', 'During', 'an', 'interview', 'at', 'the', 'conference,', 'NHRI', 'biomedical', 'engineer', 'Liao', 'Lun-de', '(廖倫德)', 'said', 'crucial', 'research', 'has', 'been', 'carried', 'out', 'over', 'recent', 'years', 'on', 'the', 'dissemination', 'of', 'contagious', 'diseases', 'like', 'dengue', 'fever', 'and', 'zika,', 'with', 'particular', 'focus', 'on', 'carrier', 'mosquitos.', 'Prior', 'to', 'now,', 'mosquito', 'traps', 'have', 'focused', 'on', 'eradicating', 'the', 'pest', 'without', 'identifying', 'its', 'species', 'or', 'virus-carrying', 'capacity,', 'he', 'commented.', 'The', 'new', 'mosquito', 'trap', 'combines', 'photoelectric', 'sensors', 'and', 'artificial', 'intelligence', 'technology', 'to', 'identify', 'the', 'unique', 'flying', 'patterns', 'of', 'different', 'mosquitos', 'by', 'using', 'what', 'the', 'institutes', 'dub', 'a', 'kind', 'of', '“facial-recognition”', 'technology.', 'Liao', 'said', 'once', 'a', 'mosquito', 'flies', 'into', 'the', 'trap,', 'sensors', 'trigger', 'cameras', 'that', 'capture', '10,800', 'images', 'of', 'the', 'insect,', 'which', 'are', 'used', 'to', 'determine', 'whether', 'it', 'is', 'of', 'a', 'common,', 'harmless', 'variety', 'or', 'a', 'more', 'dangerous,', 'disease-carrying', 'species.', 'The', 'technology', 'identifies', 'mosquito', 'species', 'with', '90', 'percent', 'accuracy.', 'The', 'cost', 'of', 'each', 'unit', 'is', 'between', 'NT$2000', 'and', 'NT$4000.', 'Liao', 'explained', 'that', 'most', 'mosquito', 'traps', 'use', 'sticky', 'paper', 'that', 'kills', 'the', 'insects', 'upon', 'landing', 'and', 'risks', 'them', 'becoming', 'attached', 'to', 'other', 'creatures', 'such', 'as', 'roaches.', 'The', 'new', 'trap', 'contains', '(rather', 'than', 'kills)', 'the', 'insect', 'so', 'the', 'blood', 'it', 'carries', 'can', 'be', 'examined', 'to', 'see', 'what', 'kind', 'of', 'creature', 'it', 'has', 'bitten,', 'and', 'whether', 'or', 'not', 'it', 'carries', 'disease.', 'Data', 'collected', 'from', 'trapped', 'mosquitos', 'is', 'uploaded', 'to', 'a', 'system,', 'Liao', 'disclosed,', 'and', 'can', 'be', 'used', 'in', 'combination', 'with', 'GIS', 'technology', 'to', 'predict', 'high-risk', 'areas.', 'This', 'will', 'help', 'enable', 'frontline', 'epidemic', 'prevention', 'units', 'initiate', 'preventative', 'measures', 'to', 'curb', 'the', 'risk', 'of', 'diseases', 'spreading.']

# %%
with open("engnews.txt", "r", encoding="utf-8") as f:
    data = f.read()
data = data.split()
for d in data:
    d.strip()
print(data)
# Out:
# ['Taiwan', 'scientists', 'develop', 'new', 'mosquito', 'trap', 'that', 'could', 'save', 'lives', 'Dengue-fever-carrying', 'insects', 'are', 'identified', 'within', 'fractions', 'of', 'a', 'second', '(By', 'Central', 'News', 'Agency)', 'TAIPEI', '(Taiwan', 'News)', '—', 'The', 'National', 'Health', 'Research', 'Institutes', '(NHRI)', 'have', 'developed', 'a', 'new', 'high-tech', 'mosquito', 'trap', 'that', 'can', 'potentially', 'curb', 'the', 'progression', 'of', 'virus', 'epidemics.', 'CNA', 'reports', 'NHRI', 'have', 'spent', 'a', 'year', 'and', 'a', 'half', 'developing', 'what', 'they', 'call', 'a', '“smart”', 'mosquito', 'trap.', 'The', 'trap', 'can', 'detect', 'whether', 'or', 'not', 'a', 'mosquito', 'carries', 'dengue', 'fever', 'within', '0.07', 'seconds', 'of', 'its', 'capture', 'and', 'could', 'be', 'used', 'to', 'identify', 'areas', 'at', 'high', 'risk', 'of', 'an', 'epidemic.', 'The', 'institutes', 'held', 'a', 'press', 'conference', 'yesterday', '(Jan.', '5)', 'in', 'which', 'they', 'shared', 'the', 'results', 'of', 'their', 'latest', 'research', 'on', 'the', 'prevention', 'and', 'control', 'of', 'mosquito-borne', 'illnesses.', 'During', 'an', 'interview', 'at', 'the', 'conference,', 'NHRI', 'biomedical', 'engineer', 'Liao', 'Lun-de', '(廖倫德)', 'said', 'crucial', 'research', 'has', 'been', 'carried', 'out', 'over', 'recent', 'years', 'on', 'the', 'dissemination', 'of', 'contagious', 'diseases', 'like', 'dengue', 'fever', 'and', 'zika,', 'with', 'particular', 'focus', 'on', 'carrier', 'mosquitos.', 'Prior', 'to', 'now,', 'mosquito', 'traps', 'have', 'focused', 'on', 'eradicating', 'the', 'pest', 'without', 'identifying', 'its', 'species', 'or', 'virus-carrying', 'capacity,', 'he', 'commented.', 'The', 'new', 'mosquito', 'trap', 'combines', 'photoelectric', 'sensors', 'and', 'artificial', 'intelligence', 'technology', 'to', 'identify', 'the', 'unique', 'flying', 'patterns', 'of', 'different', 'mosquitos', 'by', 'using', 'what', 'the', 'institutes', 'dub', 'a', 'kind', 'of', '“facial-recognition”', 'technology.', 'Liao', 'said', 'once', 'a', 'mosquito', 'flies', 'into', 'the', 'trap,', 'sensors', 'trigger', 'cameras', 'that', 'capture', '10,800', 'images', 'of', 'the', 'insect,', 'which', 'are', 'used', 'to', 'determine', 'whether', 'it', 'is', 'of', 'a', 'common,', 'harmless', 'variety', 'or', 'a', 'more', 'dangerous,', 'disease-carrying', 'species.', 'The', 'technology', 'identifies', 'mosquito', 'species', 'with', '90', 'percent', 'accuracy.', 'The', 'cost', 'of', 'each', 'unit', 'is', 'between', 'NT$2000', 'and', 'NT$4000.', 'Liao', 'explained', 'that', 'most', 'mosquito', 'traps', 'use', 'sticky', 'paper', 'that', 'kills', 'the', 'insects', 'upon', 'landing', 'and', 'risks', 'them', 'becoming', 'attached', 'to', 'other', 'creatures', 'such', 'as', 'roaches.', 'The', 'new', 'trap', 'contains', '(rather', 'than', 'kills)', 'the', 'insect', 'so', 'the', 'blood', 'it', 'carries', 'can', 'be', 'examined', 'to', 'see', 'what', 'kind', 'of', 'creature', 'it', 'has', 'bitten,', 'and', 'whether', 'or', 'not', 'it', 'carries', 'disease.', 'Data', 'collected', 'from', 'trapped', 'mosquitos', 'is', 'uploaded', 'to', 'a', 'system,', 'Liao', 'disclosed,', 'and', 'can', 'be', 'used', 'in', 'combination', 'with', 'GIS', 'technology', 'to', 'predict', 'high-risk', 'areas.', 'This', 'will', 'help', 'enable', 'frontline', 'epidemic', 'prevention', 'units', 'initiate', 'preventative', 'measures', 'to', 'curb', 'the', 'risk', 'of', 'diseases', 'spreading.']

# %%
with open("engnews.txt", "r", encoding="utf-8") as f:
    data = f.read()
data = data.replace("(", "")
data = data.replace(")", "")
data = data.replace(",", "")
data = data.replace(".", "")
data = data.replace("“", "")
data = data.replace("”", "")
data = data.split()
print(data)
# Out:
# ['Taiwan', 'scientists', 'develop', 'new', 'mosquito', 'trap', 'that', 'could', 'save', 'lives', 'Dengue-fever-carrying', 'insects', 'are', 'identified', 'within', 'fractions', 'of', 'a', 'second', 'By', 'Central', 'News', 'Agency', 'TAIPEI', 'Taiwan', 'News', '—', 'The', 'National', 'Health', 'Research', 'Institutes', 'NHRI', 'have', 'developed', 'a', 'new', 'high-tech', 'mosquito', 'trap', 'that', 'can', 'potentially', 'curb', 'the', 'progression', 'of', 'virus', 'epidemics', 'CNA', 'reports', 'NHRI', 'have', 'spent', 'a', 'year', 'and', 'a', 'half', 'developing', 'what', 'they', 'call', 'a', 'smart', 'mosquito', 'trap', 'The', 'trap', 'can', 'detect', 'whether', 'or', 'not', 'a', 'mosquito', 'carries', 'dengue', 'fever', 'within', '007', 'seconds', 'of', 'its', 'capture', 'and', 'could', 'be', 'used', 'to', 'identify', 'areas', 'at', 'high', 'risk', 'of', 'an', 'epidemic', 'The', 'institutes', 'held', 'a', 'press', 'conference', 'yesterday', 'Jan', '5', 'in', 'which', 'they', 'shared', 'the', 'results', 'of', 'their', 'latest', 'research', 'on', 'the', 'prevention', 'and', 'control', 'of', 'mosquito-borne', 'illnesses', 'During', 'an', 'interview', 'at', 'the', 'conference', 'NHRI', 'biomedical', 'engineer', 'Liao', 'Lun-de', '廖倫德', 'said', 'crucial', 'research', 'has', 'been', 'carried', 'out', 'over', 'recent', 'years', 'on', 'the', 'dissemination', 'of', 'contagious', 'diseases', 'like', 'dengue', 'fever', 'and', 'zika', 'with', 'particular', 'focus', 'on', 'carrier', 'mosquitos', 'Prior', 'to', 'now', 'mosquito', 'traps', 'have', 'focused', 'on', 'eradicating', 'the', 'pest', 'without', 'identifying', 'its', 'species', 'or', 'virus-carrying', 'capacity', 'he', 'commented', 'The', 'new', 'mosquito', 'trap', 'combines', 'photoelectric', 'sensors', 'and', 'artificial', 'intelligence', 'technology', 'to', 'identify', 'the', 'unique', 'flying', 'patterns', 'of', 'different', 'mosquitos', 'by', 'using', 'what', 'the', 'institutes', 'dub', 'a', 'kind', 'of', 'facial-recognition', 'technology', 'Liao', 'said', 'once', 'a', 'mosquito', 'flies', 'into', 'the', 'trap', 'sensors', 'trigger', 'cameras', 'that', 'capture', '10800', 'images', 'of', 'the', 'insect', 'which', 'are', 'used', 'to', 'determine', 'whether', 'it', 'is', 'of', 'a', 'common', 'harmless', 'variety', 'or', 'a', 'more', 'dangerous', 'disease-carrying', 'species', 'The', 'technology', 'identifies', 'mosquito', 'species', 'with', '90', 'percent', 'accuracy', 'The', 'cost', 'of', 'each', 'unit', 'is', 'between', 'NT$2000', 'and', 'NT$4000', 'Liao', 'explained', 'that', 'most', 'mosquito', 'traps', 'use', 'sticky', 'paper', 'that', 'kills', 'the', 'insects', 'upon', 'landing', 'and', 'risks', 'them', 'becoming', 'attached', 'to', 'other', 'creatures', 'such', 'as', 'roaches', 'The', 'new', 'trap', 'contains', 'rather', 'than', 'kills', 'the', 'insect', 'so', 'the', 'blood', 'it', 'carries', 'can', 'be', 'examined', 'to', 'see', 'what', 'kind', 'of', 'creature', 'it', 'has', 'bitten', 'and', 'whether', 'or', 'not', 'it', 'carries', 'disease', 'Data', 'collected', 'from', 'trapped', 'mosquitos', 'is', 'uploaded', 'to', 'a', 'system', 'Liao', 'disclosed', 'and', 'can', 'be', 'used', 'in', 'combination', 'with', 'GIS', 'technology', 'to', 'predict', 'high-risk', 'areas', 'This', 'will', 'help', 'enable', 'frontline', 'epidemic', 'prevention', 'units', 'initiate', 'preventative', 'measures', 'to', 'curb', 'the', 'risk', 'of', 'diseases', 'spreading']

# %%
with open("engnews.txt", "r", encoding="utf-8") as f:
    data = f.read()
special_chars = list("(),.“”")
for char in special_chars:
    data = data.replace(char, "")
data = data.split()
print(data)
# Out:
# ['Taiwan', 'scientists', 'develop', 'new', 'mosquito', 'trap', 'that', 'could', 'save', 'lives', 'Dengue-fever-carrying', 'insects', 'are', 'identified', 'within', 'fractions', 'of', 'a', 'second', 'By', 'Central', 'News', 'Agency', 'TAIPEI', 'Taiwan', 'News', '—', 'The', 'National', 'Health', 'Research', 'Institutes', 'NHRI', 'have', 'developed', 'a', 'new', 'high-tech', 'mosquito', 'trap', 'that', 'can', 'potentially', 'curb', 'the', 'progression', 'of', 'virus', 'epidemics', 'CNA', 'reports', 'NHRI', 'have', 'spent', 'a', 'year', 'and', 'a', 'half', 'developing', 'what', 'they', 'call', 'a', 'smart', 'mosquito', 'trap', 'The', 'trap', 'can', 'detect', 'whether', 'or', 'not', 'a', 'mosquito', 'carries', 'dengue', 'fever', 'within', '007', 'seconds', 'of', 'its', 'capture', 'and', 'could', 'be', 'used', 'to', 'identify', 'areas', 'at', 'high', 'risk', 'of', 'an', 'epidemic', 'The', 'institutes', 'held', 'a', 'press', 'conference', 'yesterday', 'Jan', '5', 'in', 'which', 'they', 'shared', 'the', 'results', 'of', 'their', 'latest', 'research', 'on', 'the', 'prevention', 'and', 'control', 'of', 'mosquito-borne', 'illnesses', 'During', 'an', 'interview', 'at', 'the', 'conference', 'NHRI', 'biomedical', 'engineer', 'Liao', 'Lun-de', '廖倫德', 'said', 'crucial', 'research', 'has', 'been', 'carried', 'out', 'over', 'recent', 'years', 'on', 'the', 'dissemination', 'of', 'contagious', 'diseases', 'like', 'dengue', 'fever', 'and', 'zika', 'with', 'particular', 'focus', 'on', 'carrier', 'mosquitos', 'Prior', 'to', 'now', 'mosquito', 'traps', 'have', 'focused', 'on', 'eradicating', 'the', 'pest', 'without', 'identifying', 'its', 'species', 'or', 'virus-carrying', 'capacity', 'he', 'commented', 'The', 'new', 'mosquito', 'trap', 'combines', 'photoelectric', 'sensors', 'and', 'artificial', 'intelligence', 'technology', 'to', 'identify', 'the', 'unique', 'flying', 'patterns', 'of', 'different', 'mosquitos', 'by', 'using', 'what', 'the', 'institutes', 'dub', 'a', 'kind', 'of', 'facial-recognition', 'technology', 'Liao', 'said', 'once', 'a', 'mosquito', 'flies', 'into', 'the', 'trap', 'sensors', 'trigger', 'cameras', 'that', 'capture', '10800', 'images', 'of', 'the', 'insect', 'which', 'are', 'used', 'to', 'determine', 'whether', 'it', 'is', 'of', 'a', 'common', 'harmless', 'variety', 'or', 'a', 'more', 'dangerous', 'disease-carrying', 'species', 'The', 'technology', 'identifies', 'mosquito', 'species', 'with', '90', 'percent', 'accuracy', 'The', 'cost', 'of', 'each', 'unit', 'is', 'between', 'NT$2000', 'and', 'NT$4000', 'Liao', 'explained', 'that', 'most', 'mosquito', 'traps', 'use', 'sticky', 'paper', 'that', 'kills', 'the', 'insects', 'upon', 'landing', 'and', 'risks', 'them', 'becoming', 'attached', 'to', 'other', 'creatures', 'such', 'as', 'roaches', 'The', 'new', 'trap', 'contains', 'rather', 'than', 'kills', 'the', 'insect', 'so', 'the', 'blood', 'it', 'carries', 'can', 'be', 'examined', 'to', 'see', 'what', 'kind', 'of', 'creature', 'it', 'has', 'bitten', 'and', 'whether', 'or', 'not', 'it', 'carries', 'disease', 'Data', 'collected', 'from', 'trapped', 'mosquitos', 'is', 'uploaded', 'to', 'a', 'system', 'Liao', 'disclosed', 'and', 'can', 'be', 'used', 'in', 'combination', 'with', 'GIS', 'technology', 'to', 'predict', 'high-risk', 'areas', 'This', 'will', 'help', 'enable', 'frontline', 'epidemic', 'prevention', 'units', 'initiate', 'preventative', 'measures', 'to', 'curb', 'the', 'risk', 'of', 'diseases', 'spreading']

# %%
with open("engnews.txt", "r", encoding="utf-8") as f:
    data = f.read()
data = data.translate({ord('('):None, ord(')'):None, ord('.'):None, ord('“'):None, ord('”'):None})
data = data.split()
print(data)
# Out:
# ['Taiwan', 'scientists', 'develop', 'new', 'mosquito', 'trap', 'that', 'could', 'save', 'lives', 'Dengue-fever-carrying', 'insects', 'are', 'identified', 'within', 'fractions', 'of', 'a', 'second', 'By', 'Central', 'News', 'Agency', 'TAIPEI', 'Taiwan', 'News', '—', 'The', 'National', 'Health', 'Research', 'Institutes', 'NHRI', 'have', 'developed', 'a', 'new', 'high-tech', 'mosquito', 'trap', 'that', 'can', 'potentially', 'curb', 'the', 'progression', 'of', 'virus', 'epidemics', 'CNA', 'reports', 'NHRI', 'have', 'spent', 'a', 'year', 'and', 'a', 'half', 'developing', 'what', 'they', 'call', 'a', 'smart', 'mosquito', 'trap', 'The', 'trap', 'can', 'detect', 'whether', 'or', 'not', 'a', 'mosquito', 'carries', 'dengue', 'fever', 'within', '007', 'seconds', 'of', 'its', 'capture', 'and', 'could', 'be', 'used', 'to', 'identify', 'areas', 'at', 'high', 'risk', 'of', 'an', 'epidemic', 'The', 'institutes', 'held', 'a', 'press', 'conference', 'yesterday', 'Jan', '5', 'in', 'which', 'they', 'shared', 'the', 'results', 'of', 'their', 'latest', 'research', 'on', 'the', 'prevention', 'and', 'control', 'of', 'mosquito-borne', 'illnesses', 'During', 'an', 'interview', 'at', 'the', 'conference,', 'NHRI', 'biomedical', 'engineer', 'Liao', 'Lun-de', '廖倫德', 'said', 'crucial', 'research', 'has', 'been', 'carried', 'out', 'over', 'recent', 'years', 'on', 'the', 'dissemination', 'of', 'contagious', 'diseases', 'like', 'dengue', 'fever', 'and', 'zika,', 'with', 'particular', 'focus', 'on', 'carrier', 'mosquitos', 'Prior', 'to', 'now,', 'mosquito', 'traps', 'have', 'focused', 'on', 'eradicating', 'the', 'pest', 'without', 'identifying', 'its', 'species', 'or', 'virus-carrying', 'capacity,', 'he', 'commented', 'The', 'new', 'mosquito', 'trap', 'combines', 'photoelectric', 'sensors', 'and', 'artificial', 'intelligence', 'technology', 'to', 'identify', 'the', 'unique', 'flying', 'patterns', 'of', 'different', 'mosquitos', 'by', 'using', 'what', 'the', 'institutes', 'dub', 'a', 'kind', 'of', 'facial-recognition', 'technology', 'Liao', 'said', 'once', 'a', 'mosquito', 'flies', 'into', 'the', 'trap,', 'sensors', 'trigger', 'cameras', 'that', 'capture', '10,800', 'images', 'of', 'the', 'insect,', 'which', 'are', 'used', 'to', 'determine', 'whether', 'it', 'is', 'of', 'a', 'common,', 'harmless', 'variety', 'or', 'a', 'more', 'dangerous,', 'disease-carrying', 'species', 'The', 'technology', 'identifies', 'mosquito', 'species', 'with', '90', 'percent', 'accuracy', 'The', 'cost', 'of', 'each', 'unit', 'is', 'between', 'NT$2000', 'and', 'NT$4000', 'Liao', 'explained', 'that', 'most', 'mosquito', 'traps', 'use', 'sticky', 'paper', 'that', 'kills', 'the', 'insects', 'upon', 'landing', 'and', 'risks', 'them', 'becoming', 'attached', 'to', 'other', 'creatures', 'such', 'as', 'roaches', 'The', 'new', 'trap', 'contains', 'rather', 'than', 'kills', 'the', 'insect', 'so', 'the', 'blood', 'it', 'carries', 'can', 'be', 'examined', 'to', 'see', 'what', 'kind', 'of', 'creature', 'it', 'has', 'bitten,', 'and', 'whether', 'or', 'not', 'it', 'carries', 'disease', 'Data', 'collected', 'from', 'trapped', 'mosquitos', 'is', 'uploaded', 'to', 'a', 'system,', 'Liao', 'disclosed,', 'and', 'can', 'be', 'used', 'in', 'combination', 'with', 'GIS', 'technology', 'to', 'predict', 'high-risk', 'areas', 'This', 'will', 'help', 'enable', 'frontline', 'epidemic', 'prevention', 'units', 'initiate', 'preventative', 'measures', 'to', 'curb', 'the', 'risk', 'of', 'diseases', 'spreading']

# %%
with open("engnews.txt", "r", encoding="utf-8") as f:
    data = f.read()
data = data.translate({ord(c):None for c in list("(),.“”")})
data = data.split()
print(data)
# Out:
# ['Taiwan', 'scientists', 'develop', 'new', 'mosquito', 'trap', 'that', 'could', 'save', 'lives', 'Dengue-fever-carrying', 'insects', 'are', 'identified', 'within', 'fractions', 'of', 'a', 'second', 'By', 'Central', 'News', 'Agency', 'TAIPEI', 'Taiwan', 'News', '—', 'The', 'National', 'Health', 'Research', 'Institutes', 'NHRI', 'have', 'developed', 'a', 'new', 'high-tech', 'mosquito', 'trap', 'that', 'can', 'potentially', 'curb', 'the', 'progression', 'of', 'virus', 'epidemics', 'CNA', 'reports', 'NHRI', 'have', 'spent', 'a', 'year', 'and', 'a', 'half', 'developing', 'what', 'they', 'call', 'a', 'smart', 'mosquito', 'trap', 'The', 'trap', 'can', 'detect', 'whether', 'or', 'not', 'a', 'mosquito', 'carries', 'dengue', 'fever', 'within', '007', 'seconds', 'of', 'its', 'capture', 'and', 'could', 'be', 'used', 'to', 'identify', 'areas', 'at', 'high', 'risk', 'of', 'an', 'epidemic', 'The', 'institutes', 'held', 'a', 'press', 'conference', 'yesterday', 'Jan', '5', 'in', 'which', 'they', 'shared', 'the', 'results', 'of', 'their', 'latest', 'research', 'on', 'the', 'prevention', 'and', 'control', 'of', 'mosquito-borne', 'illnesses', 'During', 'an', 'interview', 'at', 'the', 'conference', 'NHRI', 'biomedical', 'engineer', 'Liao', 'Lun-de', '廖倫德', 'said', 'crucial', 'research', 'has', 'been', 'carried', 'out', 'over', 'recent', 'years', 'on', 'the', 'dissemination', 'of', 'contagious', 'diseases', 'like', 'dengue', 'fever', 'and', 'zika', 'with', 'particular', 'focus', 'on', 'carrier', 'mosquitos', 'Prior', 'to', 'now', 'mosquito', 'traps', 'have', 'focused', 'on', 'eradicating', 'the', 'pest', 'without', 'identifying', 'its', 'species', 'or', 'virus-carrying', 'capacity', 'he', 'commented', 'The', 'new', 'mosquito', 'trap', 'combines', 'photoelectric', 'sensors', 'and', 'artificial', 'intelligence', 'technology', 'to', 'identify', 'the', 'unique', 'flying', 'patterns', 'of', 'different', 'mosquitos', 'by', 'using', 'what', 'the', 'institutes', 'dub', 'a', 'kind', 'of', 'facial-recognition', 'technology', 'Liao', 'said', 'once', 'a', 'mosquito', 'flies', 'into', 'the', 'trap', 'sensors', 'trigger', 'cameras', 'that', 'capture', '10800', 'images', 'of', 'the', 'insect', 'which', 'are', 'used', 'to', 'determine', 'whether', 'it', 'is', 'of', 'a', 'common', 'harmless', 'variety', 'or', 'a', 'more', 'dangerous', 'disease-carrying', 'species', 'The', 'technology', 'identifies', 'mosquito', 'species', 'with', '90', 'percent', 'accuracy', 'The', 'cost', 'of', 'each', 'unit', 'is', 'between', 'NT$2000', 'and', 'NT$4000', 'Liao', 'explained', 'that', 'most', 'mosquito', 'traps', 'use', 'sticky', 'paper', 'that', 'kills', 'the', 'insects', 'upon', 'landing', 'and', 'risks', 'them', 'becoming', 'attached', 'to', 'other', 'creatures', 'such', 'as', 'roaches', 'The', 'new', 'trap', 'contains', 'rather', 'than', 'kills', 'the', 'insect', 'so', 'the', 'blood', 'it', 'carries', 'can', 'be', 'examined', 'to', 'see', 'what', 'kind', 'of', 'creature', 'it', 'has', 'bitten', 'and', 'whether', 'or', 'not', 'it', 'carries', 'disease', 'Data', 'collected', 'from', 'trapped', 'mosquitos', 'is', 'uploaded', 'to', 'a', 'system', 'Liao', 'disclosed', 'and', 'can', 'be', 'used', 'in', 'combination', 'with', 'GIS', 'technology', 'to', 'predict', 'high-risk', 'areas', 'This', 'will', 'help', 'enable', 'frontline', 'epidemic', 'prevention', 'units', 'initiate', 'preventative', 'measures', 'to', 'curb', 'the', 'risk', 'of', 'diseases', 'spreading']

# %%
with open("engnews.txt", "r", encoding="utf-8") as f:
    data = f.read()
data = data.translate({ord(c):None for c in list("(),.“”")})
data = data.split()
word_freq = dict()
for word in data:
    if word not in word_freq:
        word_freq[word] = 1
    else:
        word_freq[word] += 1
print(word_freq)
# Out:
# {'Taiwan': 2, 'scientists': 1, 'develop': 1, 'new': 4, 'mosquito': 9, 'trap': 7, 'that': 5, 'could': 2, 'save': 1, 'lives': 1, 'Dengue-fever-carrying': 1, 'insects': 2, 'are': 2, 'identified': 1, 'within': 2, 'fractions': 1, 'of': 14, 'a': 12, 'second': 1, 'By': 1, 'Central': 1, 'News': 2, 'Agency': 1, 'TAIPEI': 1, '—': 1, 'The': 7, 'National': 1, 'Health': 1, 'Research': 1, 'Institutes': 1, 'NHRI': 3, 'have': 3, 'developed': 1, 'high-tech': 1, 'can': 4, 'potentially': 1, 'curb': 2, 'the': 14, 'progression': 1, 'virus': 1, 'epidemics': 1, 'CNA': 1, 'reports': 1, 'spent': 1, 'year': 1, 'and': 9, 'half': 1, 'developing': 1, 'what': 3, 'they': 2, 'call': 1, 'smart': 1, 'detect': 1, 'whether': 3, 'or': 4, 'not': 2, 'carries': 3, 'dengue': 2, 'fever': 2, '007': 1, 'seconds': 1, 'its': 2, 'capture': 2, 'be': 3, 'used': 3, 'to': 9, 'identify': 2, 'areas': 2, 'at': 2, 'high': 1, 'risk': 2, 'an': 2, 'epidemic': 2, 'institutes': 2, 'held': 1, 'press': 1, 'conference': 2, 'yesterday': 1, 'Jan': 1, '5': 1, 'in': 2, 'which': 2, 'shared': 1, 'results': 1, 'their': 1, 'latest': 1, 'research': 2, 'on': 4, 'prevention': 2, 'control': 1, 'mosquito-borne': 1, 'illnesses': 1, 'During': 1, 'interview': 1, 'biomedical': 1, 'engineer': 1, 'Liao': 4, 'Lun-de': 1, '廖倫德': 1, 'said': 2, 'crucial': 1, 'has': 2, 'been': 1, 'carried': 1, 'out': 1, 'over': 1, 'recent': 1, 'years': 1, 'dissemination': 1, 'contagious': 1, 'diseases': 2, 'like': 1, 'zika': 1, 'with': 3, 'particular': 1, 'focus': 1, 'carrier': 1, 'mosquitos': 3, 'Prior': 1, 'now': 1, 'traps': 2, 'focused': 1, 'eradicating': 1, 'pest': 1, 'without': 1, 'identifying': 1, 'species': 3, 'virus-carrying': 1, 'capacity': 1, 'he': 1, 'commented': 1, 'combines': 1, 'photoelectric': 1, 'sensors': 2, 'artificial': 1, 'intelligence': 1, 'technology': 4, 'unique': 1, 'flying': 1, 'patterns': 1, 'different': 1, 'by': 1, 'using': 1, 'dub': 1, 'kind': 2, 'facial-recognition': 1, 'once': 1, 'flies': 1, 'into': 1, 'trigger': 1, 'cameras': 1, '10800': 1, 'images': 1, 'insect': 2, 'determine': 1, 'it': 4, 'is': 3, 'common': 1, 'harmless': 1, 'variety': 1, 'more': 1, 'dangerous': 1, 'disease-carrying': 1, 'identifies': 1, '90': 1, 'percent': 1, 'accuracy': 1, 'cost': 1, 'each': 1, 'unit': 1, 'between': 1, 'NT$2000': 1, 'NT$4000': 1, 'explained': 1, 'most': 1, 'use': 1, 'sticky': 1, 'paper': 1, 'kills': 2, 'upon': 1, 'landing': 1, 'risks': 1, 'them': 1, 'becoming': 1, 'attached': 1, 'other': 1, 'creatures': 1, 'such': 1, 'as': 1, 'roaches': 1, 'contains': 1, 'rather': 1, 'than': 1, 'so': 1, 'blood': 1, 'examined': 1, 'see': 1, 'creature': 1, 'bitten': 1, 'disease': 1, 'Data': 1, 'collected': 1, 'from': 1, 'trapped': 1, 'uploaded': 1, 'system': 1, 'disclosed': 1, 'combination': 1, 'GIS': 1, 'predict': 1, 'high-risk': 1, 'This': 1, 'will': 1, 'help': 1, 'enable': 1, 'frontline': 1, 'units': 1, 'initiate': 1, 'preventative': 1, 'measures': 1, 'spreading': 1}

# %%
import operator
with open("engnews.txt", "r", encoding="utf-8") as f:
    data = f.read()
data = data.translate({ord(c):None for c in list("(),.“”")})
data = data.split()
word_freq = dict()
for word in data:
    if word not in word_freq:
        word_freq[word] = 1
    else:
        word_freq[word] += 1
ordered_freq = sorted(word_freq.items(), key=operator.itemgetter(1), reverse=True)
for w, c in ordered_freq:
    print(w, c)
# Out:
# of 14
# the 14
# a 12
# mosquito 9
# and 9
# to 9
# trap 7
# The 7
# that 5
# new 4
# can 4
# or 4
# on 4
# Liao 4
# technology 4
# it 4
# NHRI 3
# have 3
# what 3
# whether 3
# carries 3
# be 3
# used 3
# with 3
# mosquitos 3
# species 3
# is 3
# Taiwan 2
# could 2
# insects 2
# are 2
# within 2
# News 2
# curb 2
# they 2
# not 2
# dengue 2
# fever 2
# its 2
# capture 2
# identify 2
# areas 2
# at 2
# risk 2
# an 2
# epidemic 2
# institutes 2
# conference 2
# in 2
# which 2
# research 2
# prevention 2
# said 2
# has 2
# diseases 2
# traps 2
# sensors 2
# kind 2
# insect 2
# kills 2
# scientists 1
# develop 1
# save 1
# lives 1
# Dengue-fever-carrying 1
# identified 1
# fractions 1
# second 1
# By 1
# Central 1
# Agency 1
# TAIPEI 1
# — 1
# National 1
# Health 1
# Research 1
# Institutes 1
# developed 1
# high-tech 1
# potentially 1
# progression 1
# virus 1
# epidemics 1
# CNA 1
# reports 1
# spent 1
# year 1
# half 1
# developing 1
# call 1
# smart 1
# detect 1
# 007 1
# seconds 1
# high 1
# held 1
# press 1
# yesterday 1
# Jan 1
# 5 1
# shared 1
# results 1
# their 1
# latest 1
# control 1
# mosquito-borne 1
# illnesses 1
# During 1
# interview 1
# biomedical 1
# engineer 1
# Lun-de 1
# 廖倫德 1
# crucial 1
# been 1
# carried 1
# out 1
# over 1
# recent 1
# years 1
# dissemination 1
# contagious 1
# like 1
# zika 1
# particular 1
# focus 1
# carrier 1
# Prior 1
# now 1
# focused 1
# eradicating 1
# pest 1
# without 1
# identifying 1
# virus-carrying 1
# capacity 1
# he 1
# commented 1
# combines 1
# photoelectric 1
# artificial 1
# intelligence 1
# unique 1
# flying 1
# patterns 1
# different 1
# by 1
# using 1
# dub 1
# facial-recognition 1
# once 1
# flies 1
# into 1
# trigger 1
# cameras 1
# 10800 1
# images 1
# determine 1
# common 1
# harmless 1
# variety 1
# more 1
# dangerous 1
# disease-carrying 1
# identifies 1
# 90 1
# percent 1
# accuracy 1
# cost 1
# each 1
# unit 1
# between 1
# NT$2000 1
# NT$4000 1
# explained 1
# most 1
# use 1
# sticky 1
# paper 1
# upon 1
# landing 1
# risks 1
# them 1
# becoming 1
# attached 1
# other 1
# creatures 1
# such 1
# as 1
# roaches 1
# contains 1
# rather 1
# than 1
# so 1
# blood 1
# examined 1
# see 1
# creature 1
# bitten 1
# disease 1
# Data 1
# collected 1
# from 1
# trapped 1
# uploaded 1
# system 1
# disclosed 1
# combination 1
# GIS 1
# predict 1
# high-risk 1
# This 1
# will 1
# help 1
# enable 1
# frontline 1
# units 1
# initiate 1
# preventative 1
# measures 1
# spreading 1

# %%
import jieba
with open("chinews.txt", "r", encoding="utf-8") as f:
    data = f.read()
print(data, "\n")
data = data.translate({ord(c):None for c in list("(),.“”（）「」，。、：；！|\n/ ")})
words = jieba.cut(data)
for word in words:
    print(word, "/ ", end="")
# Out:
# 加州保齡球館爆槍擊案 警方：3死4傷 | 國際 | 中央社 CNA
# （中央社華盛頓5日綜合外電報導）加州警方今天表示，洛杉磯附近托蘭斯市一家保齡球館發生槍擊事件，造成3人死亡、4人受傷。法新社報導，托蘭斯（Torrance）警察局警官哈里斯（Ronald Harris）證實，昨天晚上11時54分接獲通報，三角牆屋保齡球館（Gable House Bowl）有人開槍。他說，所有7名受害者皆為男性，3人當場死亡。目擊者告訴「洛杉磯時報」（The Los Angeles Times），這家保齡球館在槍擊事件前發生打鬥。托蘭斯警察局午夜過後不久，發推文提醒民眾「遠離事發地區」。加州海岸城市托蘭斯位在洛杉磯東南方約32公里南灣地區（South Bay）。（譯者：葉俐緯/核稿：羅苑韶）1080105
#
# 加州 / 保齡 / 球館 / 爆槍 / 擊案 / 警方 / 3 / 死 / 4 / 傷國際 / 中央社 / CNA / 中央社 / 華盛頓 / 5 / 日 / 綜合 / 外電 / 報導 / 加州 / 警方 / 今天 / 表示 / 洛杉磯 / 附近 / 托蘭斯市 / 一家 / 保齡 / 球館 / 發生 / 槍擊 / 事件 / 造成 / 3 / 人 / 死亡 / 4 / 人 / 受傷 / 法新社 / 報導托蘭斯 / Torrance / 警察局 / 警官 / 哈里斯 / RonaldHarris / 證實 / 昨天晚上 / 11 / 時 / 54 / 分接 / 獲通報 / 三角 / 牆屋 / 保齡 / 球館 / GableHouseBowl / 有人 / 開槍 / 他 / 說 / 所有 / 7 / 名 / 受害者 / 皆 / 為 / 男性 / 3 / 人當場 / 死亡 / 目擊者 / 告訴 / 洛杉磯 / 時報 / TheLosAngelesTimes / 這家 / 保齡 / 球館 / 在 / 槍擊 / 事件 / 前 / 發生 / 打鬥托蘭斯 / 警察局 / 午夜 / 過後 / 不久 / 發推文 / 提醒 / 民眾 / 遠 / 離事 / 發地區 / 加州 / 海岸 / 城市 / 托蘭斯位 / 在 / 洛杉磯 / 東 / 南方 / 約 / 32 / 公里 / 南灣 / 地區 / SouthBay / 譯者 / 葉俐緯核 / 稿羅苑 / 韶 / 1080105 /

# %%
import jieba
with open("chinews.txt", "r", encoding="utf-8") as f:
    data = f.read()
data = data.translate({ord(c):None for c in list("(),.“”（）「」，。、：；！|\n/ ")})
words = jieba.cut(data)
word_freq = dict()
for word in words:
    if word not in word_freq:
        word_freq[word] = 1
    else:
        word_freq[word] += 1
ordered_freq = sorted(word_freq.items(), key=operator.itemgetter(1), reverse=True)
for w, c in ordered_freq:
    print(w, c)
# Out:
# 保齡 4
# 球館 4
# 加州 3
# 3 3
# 洛杉磯 3
# 警方 2
# 4 2
# 中央社 2
# 發生 2
# 槍擊 2
# 事件 2
# 人 2
# 死亡 2
# 警察局 2
# 在 2
# 爆槍 1
# 擊案 1
# 死 1
# 傷國際 1
# CNA 1
# 華盛頓 1
# 5 1
# 日 1
# 綜合 1
# 外電 1
# 報導 1
# 今天 1
# 表示 1
# 附近 1
# 托蘭斯市 1
# 一家 1
# 造成 1
# 受傷 1
# 法新社 1
# 報導托蘭斯 1
# Torrance 1
# 警官 1
# 哈里斯 1
# RonaldHarris 1
# 證實 1
# 昨天晚上 1
# 11 1
# 時 1
# 54 1
# 分接 1
# 獲通報 1
# 三角 1
# 牆屋 1
# GableHouseBowl 1
# 有人 1
# 開槍 1
# 他 1
# 說 1
# 所有 1
# 7 1
# 名 1
# 受害者 1
# 皆 1
# 為 1
# 男性 1
# 人當場 1
# 目擊者 1
# 告訴 1
# 時報 1
# TheLosAngelesTimes 1
# 這家 1
# 前 1
# 打鬥托蘭斯 1
# 午夜 1
# 過後 1
# 不久 1
# 發推文 1
# 提醒 1
# 民眾 1
# 遠 1
# 離事 1
# 發地區 1
# 海岸 1
# 城市 1
# 托蘭斯位 1
# 東 1
# 南方 1
# 約 1
# 32 1
# 公里 1
# 南灣 1
# 地區 1
# SouthBay 1
# 譯者 1
# 葉俐緯核 1
# 稿羅苑 1
# 韶 1
# 1080105 1

# %%
from collections import Counter
import jieba
with open("chinews.txt", "r", encoding="utf-8") as f:
    data = f.read()
data = data.translate({ord(c):None for c in list("(),.“”（）「」，。、：；！|\n/ ")})
words = jieba.cut(data)
for w, c in Counter(words).most_common():
    if c > 1:
        print(w, c)
# Out:
# 保齡 4
# 球館 4
# 加州 3
# 3 3
# 洛杉磯 3
# 警方 2
# 4 2
# 中央社 2
# 發生 2
# 槍擊 2
# 事件 2
# 人 2
# 死亡 2
# 警察局 2
# 在 2

# %%
s = "   this is a sample sentance. this is a cat\n "
print(s.capitalize())
print(s.upper())
print(s.upper().casefold())
print(s.count("a"))
print(s.endswith("ce."))
print(s.find("this"))
print(s.split())
print("#".join(s.split()))
print(s.strip())
print(s.lstrip())
print(s.rstrip())
print(s.rfind("is"))
print(s.zfill(50))
# Out:
#    this is a sample sentance. this is a cat
#
#    THIS IS A SAMPLE SENTANCE. THIS IS A CAT
#
#    this is a sample sentance. this is a cat
#
# 5
# False
# 3
# ['this', 'is', 'a', 'sample', 'sentance.', 'this', 'is', 'a', 'cat']
# this#is#a#sample#sentance.#this#is#a#cat
# this is a sample sentance. this is a cat
# this is a sample sentance. this is a cat
#
#    this is a sample sentance. this is a cat
# 35
# 00000   this is a sample sentance. this is a cat

# %%
with open("ksvote.txt", "r", encoding="utf-8") as f:
    ksvote = f.readlines()
print(ksvote)
# Out:
# ['892,545\n', '742,239\n', '7,998\n', '14,125']

# %%
with open("ksvote.txt", "r", encoding="utf-8") as f:
    ksvote = f.readlines()
num_ksvote = list()
for line in ksvote:
    num_ksvote.append(int(line.strip().replace(",","")))
print(num_ksvote)
# Out:
# [892545, 742239, 7998, 14125]

# %%
with open("ksvote.txt", "r", encoding="utf-8") as f:
    ksvote = f.readlines()
num_ksvote = [int(line.strip().replace(",","")) for line in ksvote]
print(num_ksvote)
# Out:
# [892545, 742239, 7998, 14125]

# %%
s = list("3874950382")
print(s)
print(sum(s))
# Out:
# ['3', '8', '7', '4', '9', '5', '0', '3', '8', '2']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-f6c373997b36> in <module>
#       1 s = list("3874950382")
#       2 print(s)
# ----> 3 print(sum(s))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
s = list("3874950382")
print(s)
numbers = list()
for c in s:
    numbers.append(int(c))
print(sum(numbers))
# Out:
# ['3', '8', '7', '4', '9', '5', '0', '3', '8', '2']
# 49

# %%
s = list("3874950382")
print(s)
print(sum(map(int, s)))
# Out:
# ['3', '8', '7', '4', '9', '5', '0', '3', '8', '2']
# 49

# %%
def draw_bar(n):
    return "*"*n

s = [2, 5, 4, 7, 5, 4]
for bar in map(draw_bar, s):
    print(bar)
# Out:
# **
# *****
# ****
# *******
# *****
# ****

# %%
def fixtype(n):
    return int(n.strip().replace(",",""))

with open("ksvote.txt", "r", encoding="utf-8") as f:
    ksvote = f.readlines()
num_ksvote = map(fixtype, ksvote)
for vote in num_ksvote:
    print(vote)
# Out:
# 892545
# 742239
# 7998
# 14125

# %%
s = [2, 5, 4, 7, 5, 4]
for bar in map(lambda n: "*"*n, s):
    print(bar)
# Out:
# **
# *****
# ****
# *******
# *****
# ****

# %%
with open("ksvote.txt", "r", encoding="utf-8") as f:
    ksvote = f.readlines()
num_ksvote = map(lambda n:int(n.strip().replace(",","")), ksvote)
for vote in num_ksvote:
    print(vote)
# Out:
# 892545
# 742239
# 7998
# 14125
