# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical 
from sklearn import preprocessing

np.random.seed(5)

# %%
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/iris.csv")

# %%
label_encoder = preprocessing.LabelEncoder()
df["target"] = label_encoder.fit_transform(df["target"])

# %%
dataset = df.values
np.random.shuffle(dataset)
X = dataset[:,0:4].astype(float)
Y = to_categorical(dataset[:,4])

# %%
scaler = preprocessing.StandardScaler()
X = scaler.fit_transform(X)

# %%
X_train, Y_train = X[:120], Y[:120]
X_test, Y_test = X[120:], Y[120:]

# %%
model = Sequential()
model.add(Dense(6, input_shape=(4,), activation="relu"))
model.add(Dense(6, activation="relu"))
model.add(Dense(3, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 30
#
#  dense_1 (Dense)             (None, 6)                 42
#
#  dense_2 (Dense)             (None, 3)                 21
#
# =================================================================
# Total params: 93
# Trainable params: 93
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="categorical_crossentropy", optimizer="adam",
              metrics=["accuracy"])

# %%
model.fit(X_train, Y_train, epochs=100, batch_size=5)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 2s 3ms/step - loss: 1.5692 - accuracy: 0.3583
# Epoch 2/100
# 24/24 [==============================] - 0s 4ms/step - loss: 1.4310 - accuracy: 0.3500
# Epoch 3/100
# 24/24 [==============================] - 0s 6ms/step - loss: 1.3183 - accuracy: 0.3500
# Epoch 4/100
# 24/24 [==============================] - 0s 3ms/step - loss: 1.2158 - accuracy: 0.3667
# Epoch 5/100
# 24/24 [==============================] - 0s 4ms/step - loss: 1.1309 - accuracy: 0.4167
# Epoch 6/100
# 24/24 [==============================] - 0s 6ms/step - loss: 1.0578 - accuracy: 0.4917
# Epoch 7/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.9910 - accuracy: 0.5417
# Epoch 8/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.9336 - accuracy: 0.5500
# Epoch 9/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.8747 - accuracy: 0.5583
# Epoch 10/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.8255 - accuracy: 0.5500
# Epoch 11/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7798 - accuracy: 0.5667
# Epoch 12/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7391 - accuracy: 0.6750
# Epoch 13/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7016 - accuracy: 0.7833
# Epoch 14/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6693 - accuracy: 0.8750
# Epoch 15/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6415 - accuracy: 0.9083
# Epoch 16/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6151 - accuracy: 0.9083
# Epoch 17/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5927 - accuracy: 0.9083
# Epoch 18/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.5732 - accuracy: 0.9167
# Epoch 19/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5577 - accuracy: 0.9167
# Epoch 20/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5436 - accuracy: 0.9083
# Epoch 21/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5317 - accuracy: 0.9083
# Epoch 22/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5177 - accuracy: 0.9083
# Epoch 23/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5059 - accuracy: 0.9083
# Epoch 24/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4949 - accuracy: 0.9083
# Epoch 25/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4837 - accuracy: 0.9167
# Epoch 26/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4714 - accuracy: 0.9250
# Epoch 27/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4610 - accuracy: 0.9333
# Epoch 28/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4523 - accuracy: 0.9333
# Epoch 29/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4410 - accuracy: 0.9333
# Epoch 30/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.4314 - accuracy: 0.9333
# Epoch 31/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4230 - accuracy: 0.9333
# Epoch 32/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.4132 - accuracy: 0.9333
# Epoch 33/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4108 - accuracy: 0.9333
# Epoch 34/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3952 - accuracy: 0.9417
# Epoch 35/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3879 - accuracy: 0.9417
# Epoch 36/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3777 - accuracy: 0.9417
# Epoch 37/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3695 - accuracy: 0.9417
# Epoch 38/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3619 - accuracy: 0.9417
# Epoch 39/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3536 - accuracy: 0.9583
# Epoch 40/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.3458 - accuracy: 0.9583
# Epoch 41/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.3408 - accuracy: 0.9417
# Epoch 42/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3332 - accuracy: 0.9417
# Epoch 43/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3246 - accuracy: 0.9583
# Epoch 44/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3198 - accuracy: 0.9583
# Epoch 45/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3136 - accuracy: 0.9583
# Epoch 46/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3078 - accuracy: 0.9583
# Epoch 47/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3007 - accuracy: 0.9500
# Epoch 48/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2945 - accuracy: 0.9583
# Epoch 49/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2890 - accuracy: 0.9583
# Epoch 50/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2837 - accuracy: 0.9583
# Epoch 51/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2788 - accuracy: 0.9583
# Epoch 52/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2728 - accuracy: 0.9583
# Epoch 53/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2683 - accuracy: 0.9500
# Epoch 54/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2629 - accuracy: 0.9583
# Epoch 55/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2597 - accuracy: 0.9500
# Epoch 56/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2552 - accuracy: 0.9583
# Epoch 57/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2493 - accuracy: 0.9500
# Epoch 58/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2477 - accuracy: 0.9583
# Epoch 59/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2439 - accuracy: 0.9583
# Epoch 60/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2376 - accuracy: 0.9583
# Epoch 61/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2338 - accuracy: 0.9667
# Epoch 62/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2304 - accuracy: 0.9583
# Epoch 63/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2278 - accuracy: 0.9500
# Epoch 64/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2234 - accuracy: 0.9583
# Epoch 65/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2218 - accuracy: 0.9500
# Epoch 66/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2171 - accuracy: 0.9500
# Epoch 67/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2153 - accuracy: 0.9583
# Epoch 68/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2091 - accuracy: 0.9583
# Epoch 69/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2075 - accuracy: 0.9583
# Epoch 70/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2038 - accuracy: 0.9583
# Epoch 71/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2004 - accuracy: 0.9583
# Epoch 72/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1980 - accuracy: 0.9583
# Epoch 73/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1951 - accuracy: 0.9583
# Epoch 74/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1926 - accuracy: 0.9583
# Epoch 75/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1900 - accuracy: 0.9583
# Epoch 76/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1894 - accuracy: 0.9583
# Epoch 77/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1833 - accuracy: 0.9583
# Epoch 78/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1813 - accuracy: 0.9583
# Epoch 79/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1789 - accuracy: 0.9583
# Epoch 80/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1795 - accuracy: 0.9583
# Epoch 81/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1749 - accuracy: 0.9583
# Epoch 82/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1732 - accuracy: 0.9583
# Epoch 83/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1734 - accuracy: 0.9583
# Epoch 84/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1690 - accuracy: 0.9500
# Epoch 85/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1660 - accuracy: 0.9583
# Epoch 86/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1643 - accuracy: 0.9583
# Epoch 87/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1645 - accuracy: 0.9583
# Epoch 88/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1612 - accuracy: 0.9583
# Epoch 89/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1588 - accuracy: 0.9583
# Epoch 90/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1577 - accuracy: 0.9583
# Epoch 91/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1583 - accuracy: 0.9583
# Epoch 92/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1570 - accuracy: 0.9417
# Epoch 93/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1512 - accuracy: 0.9583
# Epoch 94/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1498 - accuracy: 0.9583
# Epoch 95/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1477 - accuracy: 0.9583
# Epoch 96/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1466 - accuracy: 0.9583
# Epoch 97/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1443 - accuracy: 0.9583
# Epoch 98/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1431 - accuracy: 0.9583
# Epoch 99/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1427 - accuracy: 0.9583
# Epoch 100/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1407 - accuracy: 0.9583

# %%
loss, accuracy = model.evaluate(X_test, Y_test)
print("Accuracy = {:.2f}".format(accuracy))
# Out:
# 1/1 [==============================] - 0s 140ms/step - loss: 0.1502 - accuracy: 0.9667
# Accuracy = 0.97

# %%
Y_pred = np.argmax(model.predict(X_test), axis=-1)
print(Y_pred)
Y_target = dataset[:,4][120:].astype(int)
print(Y_target)
# Out:
# [2 1 2 0 2 0 2 0 1 0 2 2 1 2 2 2 1 0 1 0 0 1 2 0 2 0 1 2 2 1]
# [2 1 2 0 2 0 2 0 1 0 2 2 0 2 2 2 1 0 1 0 0 1 2 0 2 0 1 2 2 1]
