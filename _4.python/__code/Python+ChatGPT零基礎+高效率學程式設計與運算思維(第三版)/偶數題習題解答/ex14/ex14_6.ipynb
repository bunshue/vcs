# %%
# ex14_6.ipynb
fn = 'out14_3_1.txt'         # 設定欲開啟的檔案
with open(fn, encoding='cp950') as file_Obj:  
    obj_list = file_Obj.readlines()  

str_Obj = ''                # 先設為空字串
for line in obj_list:       # 將各行字串存入
    str_Obj += line.rstrip()

print(str_Obj)              # 列印檔案字串
