# %%
# ch10_3.ipynb 
math = {'Kevin', 'Peter', 'Eric'}       # 數學夏令營成員
physics = {'Peter', 'Nelson', 'Tom'}    # 物理夏令營成員
both1 = math & physics
print("同時參加數學與物理夏令營的成員 ",both1)
both2 = math.intersection(physics)
print("同時參加數學與物理夏令營的成員 ",both2)
