# %%
# ch11_16.ipynb
def mydata(n):
    print(f"函  數 id(n) = {id(n)}, {n}")
    n[0] = 5
    print(f"函  數 id(n) = {id(n)}, {n}")

x = [1, 2]
print(f"主程式 id(x) = {id(x)}, {x}")
mydata(x)
print(f"主程式 id(x) = {id(x)}, {x}")
