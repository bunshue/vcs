# %%
# ch11_15.ipynb
def mydata(n):
    print(f"副程式 id(n) = {id(n)}, {n}")
    n = 5
    print(f"副程式 id(n) = {id(n)}, {n}")

x = 1
print(f"主程式 id(x) = {id(x)}, {x}")
mydata(x)
print(f"主程式 id(x) = {id(x)}, {x}")
