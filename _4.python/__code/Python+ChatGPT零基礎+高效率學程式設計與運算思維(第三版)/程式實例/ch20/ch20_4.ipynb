# %%
# ch20_4.ipynb
import matplotlib.pyplot as plt

squares = [0, 1, 4, 9, 16, 25, 36, 49, 64]
plt.plot(squares, lw=5)     # squares是y軸的值, 線條寬度是5
plt.title('Test Chart')
plt.xlabel('Value')
plt.ylabel('Square')
plt.show()
