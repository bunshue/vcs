# %%
# ch2_3.ipynb
a = b = c = 10
x = a + b + c + 12
print(x)
# 續行方法1
y = a +\
    b +\
    c +\
    12
print(y)
# 續行方法2
z = ( a +     # 此處可以加上註解  
      b +
      c +
      12 )
print(z)
# Out:
# 42
# 42
# 42
