# %%
# ch16_18.ipynb
import re
# 測試1搜尋不在[aeiouAEIOU]的字元
msg = 'A party tonight.'
pattern = '[^aeiouAEIOU]'           
txt = re.findall(pattern,msg)      # 傳回搜尋結果
print(txt)
# 測試2搜尋不在[2-5.]的字元
msg = '2 dogs,3 pigs'
pattern = '[^2-5.]'
txt = re.findall(pattern,msg)      # 傳回搜尋結果
print(txt)
