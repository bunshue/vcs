# %%
# ch8_6.ipynb
keys = ('magic', 'xaab', 9099)  # 定義元組元素是字串與數字
list_keys = list(keys)          # 將元組改為串列
list_keys.append('secret')      # 因為是串列所以可以增加元素
print(f"類型 : {type(keys)}, 內容 : {keys}")
print(f"類型 : {type(list_keys)}, 內容 : {list_keys}")
