# %%
# ch9_11.ipynb
fruits = {'西瓜':15, '香蕉':20, '水蜜桃':25, '蘋果':18}
noodles = {'牛肉麵':100, '肉絲麵':80, '陽春麵':60}
empty_dict = {}
print(f"fruits字典元素數量     = {len(fruits)}")
print(f"noodles字典元素數量    = {len(noodles)}")
print(f"empty_dict字典元素數量 = {len(empty_dict)}")
