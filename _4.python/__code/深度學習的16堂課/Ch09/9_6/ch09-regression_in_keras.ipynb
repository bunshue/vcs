# %% [markdown]
# #### 9.6 改試試迴歸 (Regression) 範例

# %%
import numpy as np
from tensorflow.keras.datasets import boston_housing
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import BatchNormalization

# %% [markdown]
# #### 9.6.1 載入資料集

# %%
(X_train, y_train), (X_test, y_test) = boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57344/57026 [==============================] - 0s 0us/step
# 65536/57026 [==================================] - 0s 0us/step

# %%
X_train.shape
# Out:
# (404, 13)

# %%
X_test.shape
# Out:
# (102, 13)

# %%
X_train[0]
# Out:
# array([  1.23247,   0.     ,   8.14   ,   0.     ,   0.538  ,   6.142  ,
#         91.7    ,   3.9769 ,   4.     , 307.     ,  21.     , 396.9    ,
#         18.72   ])

# %%
y_train[0]
# Out:
# 15.2

# %% [markdown]
# #### 9.6.2 神經網路的架構

# %%
model = Sequential()

model.add(Dense(32, input_dim=13, activation='relu'))
model.add(BatchNormalization())

model.add(Dense(16, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(1, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                448
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32)                128
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16)                64
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 1,185
# Trainable params: 1,089
# Non-trainable params: 96
# _________________________________________________________________

# %% [markdown]
# #### 9.6.3 編譯、訓練模型

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
#註：由於神經網路的初始權重參數是隨機設定的, 參雜了隨機性, 因此底下 (或您重跑一次) 的結果不會與書中完全一樣, 但模型的能力是相近的
model.fit(X_train, y_train, 
          batch_size=8, epochs=32, verbose=1, 
          validation_data=(X_test, y_test))
# Out:
# Epoch 1/32
# 51/51 [==============================] - 0s 3ms/step - loss: 47.7289 - val_loss: 54.4794
# Epoch 2/32
# 51/51 [==============================] - 0s 2ms/step - loss: 41.8294 - val_loss: 27.3211
# Epoch 3/32
# 51/51 [==============================] - 0s 2ms/step - loss: 43.4715 - val_loss: 29.7052
# Epoch 4/32
# 51/51 [==============================] - 0s 2ms/step - loss: 44.9643 - val_loss: 58.0492
# Epoch 5/32
# 51/51 [==============================] - 0s 2ms/step - loss: 44.8526 - val_loss: 24.2941
# Epoch 6/32
# 51/51 [==============================] - 0s 2ms/step - loss: 47.5056 - val_loss: 29.8707
# Epoch 7/32
# 51/51 [==============================] - 0s 2ms/step - loss: 38.5279 - val_loss: 40.4831
# Epoch 8/32
# 51/51 [==============================] - 0s 2ms/step - loss: 37.8144 - val_loss: 39.1249
# Epoch 9/32
# 51/51 [==============================] - 0s 2ms/step - loss: 38.6014 - val_loss: 36.7240
# Epoch 10/32
# 51/51 [==============================] - 0s 2ms/step - loss: 44.4404 - val_loss: 37.2530
# Epoch 11/32
# 51/51 [==============================] - 0s 2ms/step - loss: 37.4264 - val_loss: 37.0141
# Epoch 12/32
# 51/51 [==============================] - 0s 2ms/step - loss: 41.2629 - val_loss: 29.2519
# Epoch 13/32
# 51/51 [==============================] - 0s 3ms/step - loss: 34.0539 - val_loss: 34.6767
# Epoch 14/32
# 51/51 [==============================] - 0s 3ms/step - loss: 36.7715 - val_loss: 44.4690
# Epoch 15/32
# 51/51 [==============================] - 0s 3ms/step - loss: 34.4800 - val_loss: 35.5721
# Epoch 16/32
# 51/51 [==============================] - 0s 3ms/step - loss: 34.7815 - val_loss: 39.5700
# Epoch 17/32
# 51/51 [==============================] - 0s 4ms/step - loss: 40.8599 - val_loss: 68.7650
# Epoch 18/32
# 51/51 [==============================] - 0s 3ms/step - loss: 37.8769 - val_loss: 33.6091
# Epoch 19/32
# 51/51 [==============================] - 0s 3ms/step - loss: 36.4160 - val_loss: 69.8666
# Epoch 20/32
# 51/51 [==============================] - 0s 3ms/step - loss: 43.2561 - val_loss: 30.6261
# Epoch 21/32
# 51/51 [==============================] - 0s 2ms/step - loss: 46.7797 - val_loss: 90.5725
# Epoch 22/32
# 51/51 [==============================] - 0s 3ms/step - loss: 33.6304 - val_loss: 127.0154
# Epoch 23/32
# 51/51 [==============================] - 0s 3ms/step - loss: 42.6456 - val_loss: 37.4990
# Epoch 24/32
# 51/51 [==============================] - 0s 3ms/step - loss: 35.8036 - val_loss: 42.7005
# Epoch 25/32
# 51/51 [==============================] - 0s 2ms/step - loss: 36.9505 - val_loss: 34.9684
# Epoch 26/32
# 51/51 [==============================] - 0s 2ms/step - loss: 36.2142 - val_loss: 31.8827
# Epoch 27/32
# 51/51 [==============================] - 0s 2ms/step - loss: 43.4036 - val_loss: 32.3461
# Epoch 28/32
# 51/51 [==============================] - 0s 2ms/step - loss: 43.0803 - val_loss: 45.7779
# Epoch 29/32
# 51/51 [==============================] - 0s 2ms/step - loss: 38.9140 - val_loss: 33.5518
# Epoch 30/32
# 51/51 [==============================] - 0s 2ms/step - loss: 35.9944 - val_loss: 37.4578
# Epoch 31/32
# 51/51 [==============================] - 0s 2ms/step - loss: 34.8042 - val_loss: 35.4671
# Epoch 32/32
# 51/51 [==============================] - 0s 2ms/step - loss: 42.1369 - val_loss: 50.4363

# %% [markdown]
# ####9.6.4 實際進行預測

# %%
X_test[42]
# Out:
# array([  9.32909,   0.     ,  18.1    ,   0.     ,   0.713  ,   6.185  ,
#         98.7    ,   2.2616 ,  24.     , 666.     ,  20.2    , 396.9    ,
#         18.13   ])

# %%
y_test[42]
# Out:
# 14.1

# %%
model.predict(np.reshape(X_test[42], [1, 13]))
# Out:
# array([[24.17145]], dtype=float32)
