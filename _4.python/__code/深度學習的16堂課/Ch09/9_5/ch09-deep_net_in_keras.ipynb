# %% [markdown]
# #### 9.5 實作：用 tf.Keras 建構深度神經網路

# %% [markdown]
# #### 9.5.1 匯入模組

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout # new!
from tensorflow.keras.layers import BatchNormalization # new!
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD

# %% [markdown]
# #### 9.5.2 神經網路的構造

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
X_train = X_train.reshape(60000, 784).astype('float32')
X_test = X_test.reshape(10000, 784).astype('float32')

# %%
X_train /= 255
X_test /= 255

# %%
n_classes = 10
y_train = to_categorical(y_train, n_classes)
y_test = to_categorical(y_test, n_classes)

# %%
model = Sequential()

model.add(Dense(64, activation='relu', input_shape=(784,)))
model.add(BatchNormalization())

model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())

model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                50240
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64)                256
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                650
# =================================================================
# Total params: 59,978
# Trainable params: 59,594
# Non-trainable params: 384
# _________________________________________________________________

# %% [markdown]
# #### 9.5.3 設定優化器 (編譯模型)

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# #### 訓練模型!

# %%
model.fit(X_train, y_train, batch_size=128, epochs=20, verbose=1, validation_data=(X_test, y_test))
#註：由於神經網路的初始權重參數是隨機設定的, 參雜了隨機性, 因此底下 (或您重跑一次) 的結果會與書中有小差異
# Out:
# Epoch 1/20
# 469/469 [==============================] - 4s 5ms/step - loss: 0.3849 - accuracy: 0.8852 - val_loss: 0.1575 - val_accuracy: 0.9513
# Epoch 2/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1554 - accuracy: 0.9535 - val_loss: 0.1335 - val_accuracy: 0.9585
# Epoch 3/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1114 - accuracy: 0.9666 - val_loss: 0.0994 - val_accuracy: 0.9686
# Epoch 4/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0893 - accuracy: 0.9717 - val_loss: 0.0937 - val_accuracy: 0.9712
# Epoch 5/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0759 - accuracy: 0.9761 - val_loss: 0.0968 - val_accuracy: 0.9707
# Epoch 6/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0649 - accuracy: 0.9797 - val_loss: 0.1069 - val_accuracy: 0.9683
# Epoch 7/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0556 - accuracy: 0.9821 - val_loss: 0.0886 - val_accuracy: 0.9745
# Epoch 8/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0504 - accuracy: 0.9837 - val_loss: 0.0960 - val_accuracy: 0.9738
# Epoch 9/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0470 - accuracy: 0.9847 - val_loss: 0.0858 - val_accuracy: 0.9748
# Epoch 10/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0415 - accuracy: 0.9867 - val_loss: 0.0913 - val_accuracy: 0.9755
# Epoch 11/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0378 - accuracy: 0.9875 - val_loss: 0.0868 - val_accuracy: 0.9765
# Epoch 12/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0356 - accuracy: 0.9881 - val_loss: 0.0872 - val_accuracy: 0.9773
# Epoch 13/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0328 - accuracy: 0.9891 - val_loss: 0.0885 - val_accuracy: 0.9758
# Epoch 14/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0279 - accuracy: 0.9907 - val_loss: 0.0961 - val_accuracy: 0.9729
# Epoch 15/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0313 - accuracy: 0.9891 - val_loss: 0.0814 - val_accuracy: 0.9798
# Epoch 16/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0264 - accuracy: 0.9915 - val_loss: 0.0875 - val_accuracy: 0.9765
# Epoch 17/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0246 - accuracy: 0.9918 - val_loss: 0.0969 - val_accuracy: 0.9745
# Epoch 18/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0257 - accuracy: 0.9910 - val_loss: 0.0905 - val_accuracy: 0.9775
# Epoch 19/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0238 - accuracy: 0.9919 - val_loss: 0.0841 - val_accuracy: 0.9783
# Epoch 20/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0215 - accuracy: 0.9924 - val_loss: 0.0853 - val_accuracy: 0.9773
# Exception ignored in: <function IteratorResourceDeleter.__del__ at 0x7f844f58f830>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py", line 546, in __del__
#     handle=self._handle, deleter=self._deleter)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_dataset_ops.py", line 1264, in delete_iterator
#     _ctx, "DeleteIterator", name, handle, deleter)
# KeyboardInterrupt:
