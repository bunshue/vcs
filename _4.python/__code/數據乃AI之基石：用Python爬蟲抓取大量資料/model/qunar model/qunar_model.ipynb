# %%
########################################################################
#                                                                      #
#        去哪儿网 旅游天数、酒店评分、酒店等级 vs 路线价格 建模        #
#                                                                      #
########################################################################

# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm


df = pd.read_csv("D:/qunar_routes.csv")
print (df.head())
print (df.info())

df["天数"]=df.路线信息.str.extract('(\d+)天\d+晚').apply(lambda x: int(x))
df["酒店评分"]=df.酒店信息.str.extract('(\d\.\d)分').apply(lambda x: float(x))
df["酒店等级"]=df.酒店信息.str.extract('\n(.*)')
df["价格"]=df.路线信息.str.extract('(\d+)起/人').apply(lambda x: int(x))
print (df.head())
print (df.info())

class_map = {"其他":0,"经济型":1,"舒适型":2,"高档型":3,"豪华型":4}
df["酒店等级"]=df["酒店等级"].map(class_map)

# 对变量画直方图，查看是否有异常值
fig, axes = plt.subplots(1, 3, figsize=(12, 4))
df["酒店等级"].plot(ax=axes[0], kind='hist', title="酒店等级")
df["酒店评分"].plot(ax=axes[1], kind='hist', title="酒店评分")
df["价格"].plot(ax=axes[2], kind='hist', title="价格")

#提取自变量X,因变量y
X,y = df.ix[:,4:-1].values, df.ix[:,-1].values

# 拟合OLS线性回归模型 
ols = sm.OLS(y,X)
result = ols.fit()
print (result.summary())

y_pred = result.predict(X)
ratio = y_pred/y
df["性价比"] = ratio
df.sort_values("性价比", ascending=False)
# Out:
#   出发地 目的地                                               路线信息       酒店信息
# 0  杭州  丽江  机酒自由行\n丽江5日自由行,入住丽江添富太和休闲度假酒店+接送机,品古城文化,享至尊服务,...  4.4分\n高档型
# 1  杭州  丽江  机酒自由行\n丽江6日自由行,入住丽江添富太和休闲度假酒店+接送机,品古城文化,享至尊服务,...  4.4分\n高档型
# 2  杭州  丽江  机酒自由行\n丽江+香格里拉 丽江+香格里拉6日自由行,机票+特色客栈,丽江往返+接机\n特...  4.4分\n经济型
# 3  杭州  丽江  机酒自由行\n丽江+大理 丽江、大理双城6天自由行,3晚丽江特色客栈,2晚大理洱海边客栈,赠...  4.4分\n经济型
# 4  杭州  丽江  机酒自由行\n丽江5日自由行,入住丽江听心祥和院+接送机\n5天4晚|天天出发|飞机|舒适游...  4.7分\n高档型
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
# 出发地     120 non-null object
# 目的地     120 non-null object
# 路线信息    120 non-null object
# 酒店信息    120 non-null object
# dtypes: object(4)
# memory usage: 3.8+ KB
# None
#   出发地 目的地                                               路线信息       酒店信息  天数  \
# 0  杭州  丽江  机酒自由行\n丽江5日自由行,入住丽江添富太和休闲度假酒店+接送机,品古城文化,享至尊服务,...  4.4分\n高档型   5
# 1  杭州  丽江  机酒自由行\n丽江6日自由行,入住丽江添富太和休闲度假酒店+接送机,品古城文化,享至尊服务,...  4.4分\n高档型   6
# 2  杭州  丽江  机酒自由行\n丽江+香格里拉 丽江+香格里拉6日自由行,机票+特色客栈,丽江往返+接机\n特...  4.4分\n经济型   6
# 3  杭州  丽江  机酒自由行\n丽江+大理 丽江、大理双城6天自由行,3晚丽江特色客栈,2晚大理洱海边客栈,赠...  4.4分\n经济型   6
# 4  杭州  丽江  机酒自由行\n丽江5日自由行,入住丽江听心祥和院+接送机\n5天4晚|天天出发|飞机|舒适游...  4.7分\n高档型   5
#
#    酒店评分 酒店等级    价格
# 0   4.4  高档型  1888
# 1   4.4  高档型  1872
# 2   4.4  经济型  1517
# 3   4.4  经济型  1612
# 4   4.7  高档型  1740
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 8 columns):
# 出发地     120 non-null object
# 目的地     120 non-null object
# 路线信息    120 non-null object
# 酒店信息    120 non-null object
# 天数      120 non-null int64
# 酒店评分    120 non-null float64
# 酒店等级    120 non-null object
# 价格      120 non-null int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 7.6+ KB
# None
# D:\Anaconda3\lib\site-packages\ipykernel\__main__.py:18: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
# D:\Anaconda3\lib\site-packages\ipykernel\__main__.py:19: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
# D:\Anaconda3\lib\site-packages\ipykernel\__main__.py:20: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
# D:\Anaconda3\lib\site-packages\ipykernel\__main__.py:21: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.886
# Model:                            OLS   Adj. R-squared:                  0.883
# Method:                 Least Squares   F-statistic:                     302.2
# Date:                Tue, 30 May 2017   Prob (F-statistic):           6.47e-55
# Time:                        13:42:13   Log-Likelihood:                -1026.0
# No. Observations:                 120   AIC:                             2058.
# Df Residuals:                     117   BIC:                             2066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1           243.8182     71.514      3.409      0.001       102.188   385.448
# x2           140.5419     96.623      1.455      0.148       -50.815   331.899
# x3           592.0773     81.942      7.226      0.000       429.796   754.359
# ==============================================================================
# Omnibus:                       50.959   Durbin-Watson:                   1.822
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              168.149
# Skew:                           1.526   Prob(JB):                     3.07e-37
# Kurtosis:                       7.932   Cond. No.                         8.33
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#     出发地 目的地                                               路线信息       酒店信息  天数  \
# 11   杭州  丽江  自由行\n昆明+大理+丽江+香格里拉 云南旅游新模式，分离试旅游。丽江自由行，云南/大理/丽...  4.1分\n高档型  10
# 4    杭州  丽江  机酒自由行\n丽江5日自由行,入住丽江听心祥和院+接送机\n5天4晚|天天出发|飞机|舒适游...  4.7分\n高档型   5
# 1    杭州  丽江  机酒自由行\n丽江6日自由行,入住丽江添富太和休闲度假酒店+接送机,品古城文化,享至尊服务,...  4.4分\n高档型   6
# 0    杭州  丽江  机酒自由行\n丽江5日自由行,入住丽江添富太和休闲度假酒店+接送机,品古城文化,享至尊服务,...  4.4分\n高档型   5
# 79   杭州  丽江  机酒自由行\n昆明+丽江+香格里拉 杭州飞昆明5日+N天自由休闲游，任意组合丽江/香格里拉/...  4.8分\n舒适型   5
# 2    杭州  丽江  机酒自由行\n丽江+香格里拉 丽江+香格里拉6日自由行,机票+特色客栈,丽江往返+接机\n特...  4.4分\n经济型   6
# 119  杭州  丽江  自由行\n昆明+大理+丽江 双廊精选双飞昆明大理丽江自由行3+N天随意搭配+旅游达人推荐吃喝...  4.1分\n高档型   6
# 118  杭州  丽江  自由行\n直飞丽江5天4晚自由行+N天自由行+特色客栈+接送机服务+20公里免费用车\n新城...  4.1分\n高档型   5
# 3    杭州  丽江  机酒自由行\n丽江+大理 丽江、大理双城6天自由行,3晚丽江特色客栈,2晚大理洱海边客栈,赠...  4.4分\n经济型   6
# 35   杭州  丽江  自由行\n<双飞往返丽江>丽江一地+机场接送 5天自由行 管家式服务（内附完整攻略）\n大研...  4.9分\n舒适型   5
# 106  杭州  丽江  自由行\n丽江+大理+香格里拉 <双飞往返丽江>丽江、香格里拉、泸沽湖、大理9天自由行管家式...  4.9分\n舒适型   9
# 5    杭州  丽江  机酒自由行\n丽江+泸沽湖6日自由行,机票+特色客栈,丽江往返+接机\n特色客栈\n6天5晚...  4.4分\n经济型   6
# 114  杭州  丽江  自由行\n丽江+大理 不要蓝瘦、香菇，真纯玩，0购物+580元赠送，大理、丽江各一天自由活动...  4.4分\n高档型   7
# 6    杭州  丽江  机酒自由行\n丽江+大理 丽江、大理6天5晚自由行,丽江进大理出,不走回头路\n6天5晚|飞...  4.4分\n经济型   6
# 113  杭州  丽江  自由行\n丽江+香格里拉 <双飞往返丽江>丽江+香格里拉+泸沽湖7天自由行 管家式服务（内附...  4.9分\n舒适型   7
# 71   杭州  丽江  自由行\n丽江+大理 <双飞往返丽江> 丽江+泸沽湖+大理7天自由行 管家式服务（内附完整攻...  4.9分\n舒适型   7
# 104  杭州  丽江  自由行\n丽江+大理+香格里拉 纯玩+不限年龄+洱海骑行+直飞丽江，大理、丽江、香格里拉8日...  4.4分\n高档型   8
# 64   杭州  丽江  自由行\n<飞机往返丽江> 丽江+大理+香格里拉3天自由行+管家式服务（内附游玩攻略）\n多...   4.9分\n其他   3
# 70   杭州  丽江  自由行\n飞机往返丽江3天2晚 丽江古城+拉市海+管家服务+行程定制（附游玩攻略）\n大研古...   4.9分\n其他   3
# 42   杭州  丽江  机酒自由行\n丽江+大理 毕业季行色双廊拉市海骑行 玉龙雪山 丽江 大理小资双飞5日游接送机...   4.7分\n其他   5
# 39   杭州  丽江  自由行\n昆明+大理+丽江+西双版纳 昆明大理丽江西双版纳9日私家团 赠洱海旅拍 住四星酒店...  4.2分\n高档型   9
# 82   杭州  丽江  自由行\n丽江+大理+香格里拉 云南私家团大理+丽江+香格里拉7日6晚杨丽萍艺术酒店悦榕庄洲...  4.7分\n豪华型   7
#
#      酒店评分  酒店等级     价格       性价比
# 11    4.1     3   2180  2.197539
# 4     4.7     3   1740  2.101075
# 1     4.4     3   1872  2.060644
# 0     4.4     3   1888  1.914040
# 79    4.8     2   1680  1.832052
# 2     4.4     1   1517  1.762275
# 119   4.1     3   2199  1.735045
# 118   4.1     3   2110  1.692675
# 3     4.4     1   1612  1.658419
# 35    4.9     2   1866  1.656967
# 106   4.9     2   2488  1.634716
# 5     4.4     1   1669  1.601780
# 114   4.4     3   2580  1.589668
# 6     4.4     1   1703  1.569801
# 113   4.9     2   2366  1.512907
# 71    4.9     2   2366  1.512907
# 104   4.4     3   2990  1.453232
# 92    4.5     4   2998  1.407551
# 12    3.5     4   3100  1.394553
# 9     3.5     4   3100  1.394553
# 74    4.9     2   2220  1.392748
# 105   4.9     2   2940  1.383393
# 51    4.9     2   2070  1.375885
# 31    4.9     2   2250  1.374178
# 32    4.3     3   2800  1.372668
# 115   4.9     2   2610  1.371470
# 112   4.5     4   3280  1.360871
# 52    4.9     2   2670  1.340651
# 87    4.9     2   2670  1.340651
# 108   4.9     2   2490  1.339646
# ..    ...   ...    ...       ...
# 80    4.5     0   2340  0.791252
# 89    4.9     0   2740  0.785243
# 96    4.9     0   3080  0.777722
# 10    4.5     0   2100  0.765577
# 72    4.4     4   6480  0.761920
# 33    3.9     4   6080  0.760387
# 22    4.6     4   5580  0.758762
# 34    4.1     0   2380  0.754333
# 37    4.7     2   4720  0.752421
# 97    4.9     0   2880  0.747071
# 29    4.9     0   2580  0.739437
# 58    4.9     0   2599  0.734031
# 75    4.5     4   5780  0.730076
# 57    4.4     4   6580  0.713286
# 77    4.6     4   6280  0.713011
# 116   4.9     0   3020  0.712439
# 95    4.9     0   2680  0.711846
# 30    4.8     4   6380  0.706241
# 86    4.9     0   2380  0.699130
# 100   4.6     4   6880  0.686269
# 107   4.9     0   2858  0.667511
# 78    4.6     4   6380  0.663620
# 60    4.4     0   3150  0.660728
# 28    4.7     4   7580  0.656913
# 25    4.7     4   8280  0.601377
# 64    4.9     0   2380  0.596685
# 70    4.9     0   2380  0.596685
# 42    4.7     0   3180  0.591081
# 39    4.2     3   8580  0.531570
# 82    4.7     4  11080  0.427399
#
# [120 rows x 9 columns]
